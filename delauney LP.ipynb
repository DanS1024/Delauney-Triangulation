# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
# import pygame as pg
from scipy.spatial import Delaunay
import time
from geompreds import orient2d, incircle
import gmsh
import sys
from bisect import bisect
from collections import deque

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
class TriangularMesh:
    def __init__(self, vertices=None, faces=None, halfedges=None):
        self.vertices = [] if vertices == None else vertices
        self.faces = set() if faces == None else faces
        self.halfedges = set() if halfedges == None else halfedges
        self.version = int(sys.version.split('.')[1]) >= 10

    def sort_vertices(self):
        self.vertices.sort(key=lambda x: x.Hilbert)

    def add_triangle(self, vertices, halfedges=None, out=False):
        halfedges = [Halfedge() for _ in range(3)] if halfedges is None else halfedges
        face = Face(halfedge=halfedges[0])
        for i in range(3):
            halfedges[i].next = halfedges[i-2]
            halfedges[i].prev = halfedges[i-1]
            halfedges[i].vertex = vertices[i]
            halfedges[i].facet = face
            vertices[i].halfedge = halfedges[i]
        self.halfedges.update(halfedges)
        self.faces.add(face)
        if out:
            return halfedges
        # return halfedges
    
    # def rem_halfedge(self, halfedge):
    #     self.halfedges.remove(halfedge)
    #     del halfedge
    
    # def add_Hvertex(self, coords, halfedge, Hilbert, index=None):
    #     if self.version:
    #         ind = bisect(self.vertices, Vertex(Hilbert=Hilbert), key=lambda x: x.Hilbert)
    #         self.vertices.insert(ind, Vertex(coords, halfedge, Hilbert, index))
    #     else:
    #         self.vertices.append(Vertex(coords, halfedge, Hilbert, index))
    #         self.vertices.sort(key=lambda x: x.Hilbert)
    #         ind = self.vertices.index(Vertex(coords, halfedge, Hilbert, index))
    #     return ind
    
    # def add_Hvertices(self, vertices):
    #     self.vertices += vertices
    #     self.vertices.sort(key=lambda x: x.Hilbert)
    #     return list(filter(lambda i: self.vertices[i] in vertices, range(len(self.vertices))))
    
    def add_mesh(self, mesh):
        self.vertices += mesh.vertices
        self.faces.update(mesh.faces)
        self.halfedges.update(mesh.halfedges)

    def rem_mesh(self, mesh):
        # self.vertices.difference_update(mesh.vertices)
        self.faces.difference_update(mesh.faces)
        self.halfedges.difference_update(mesh.halfedges)

    def __repr__(self):
        return f"Vertices: {len(self.vertices)}, Faces: {len(self.faces)}, Halfedges: {len(self.halfedges)}"

class Vertex:
    def __init__(self, coords=None, halfedge=None, Hilbert=None, next=None, prev=None, index=None):
        self.coords = coords
        self.halfedge = halfedge
        self.Hilbert = Hilbert
        self.next = next
        self.prev = prev
        self.index = index

    def __repr__(self):
        return f"({self.coords[0]:.4g}, {self.coords[1]:.4g})"

class Face:
    def __init__(self, halfedge=None, visited=False, index=None):
        self.halfedge = halfedge # halfedge going ccw around this facet
        self.visited = visited
        self.index = index
    
    def __repr__(self):
        return f"[{self.halfedge.vertex} {self.halfedge.next.vertex} {self.halfedge.prev.vertex}]"

class Halfedge:
    def __init__(self, next=None, prev=None, twin=None, vertex=None, facet=None, index=None):
        self.next = next
        self.prev = prev
        self.twin = twin
        self.vertex = vertex
        self.facet = facet
        self.index = index

    def __repr__(self):
        return f"{self.vertex} -> {self.next.vertex}"

# %%
input_file = '' if '-i' not in sys.argv else sys.argv[sys.argv.index('-i') + 1]
output_file = 'triangles.dat' if '-o' not in sys.argv else sys.argv[sys.argv.index('-o') + 1]

# %%
points = np.random.rand(2, 10000).T if input_file == '' else np.loadtxt(input_file, skiprows=1)
N = len(points)
border = [min(points[:, 0]), max(points[:, 0]), min(points[:, 1]), max(points[:, 1])]

# %%
start = time.time()
tri = Delaunay(points)
print('Time:', time.time() - start)
# Out:
# Time: 0.047945261001586914

# %%
# expected result
plt.triplot(points[:,0], points[:,1], tri.simplices, 'r-', linewidth=0.5)
plt.plot(points[:,0], points[:,1], 'ko', markersize=2)
plt.show()

# %%
def Hilbert(point, depth, O, R, B):
    point, O, R, B = map(np.array, [point, O, R, B])
    index = [0] * depth
    for i in range(depth):
        dotR = np.dot(point-O, R) > 0.
        dotB = np.dot(point-O, B) > 0.
        R /= 2.
        B /= 2.
        if dotR:
            if dotB:
                index[i] = 2
                O += R + B
            else:
                index[i] = 3
                O += R - B
                R, B = B, R
        else:
            if dotB:
                index[i] = 1
                O -= R - B
            else:
                index[i] = 0
                O -= R + B
                R, B = B, R
    return index

# %%
def Ball(boundary, p):
    # connect p to all vertices of the cavity
    new_mesh = TriangularMesh(vertices=[p])
    hedges = sorted(boundary.halfedges, key=lambda hedge: hedge.next.vertex.coords)
    next_bdry_hedges = sorted(boundary.halfedges, key=lambda hedge: hedge.vertex.coords)
    for hedge in hedges:
        new_mesh.add_triangle([p, hedge.vertex, hedge.next.vertex], [Halfedge(), hedge, Halfedge()])
    for i, hedge in enumerate(hedges):
        hedge.next.twin = next_bdry_hedges[i].next.next
        next_bdry_hedges[i].next.next.twin = hedge.next

    return new_mesh

# %%
def check_triangle(halfedge, p):
    # print(halfedge.vertex.coords)
    # print(halfedge.next.vertex.coords)
    # print(halfedge.prev.vertex.coords)
    a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
    res = incircle(a, b, c, p.coords)
    if np.isnan(res):
        # number of None in [a, b, c]
        k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
        if k == 0:
            # do orient2d test instead
            a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
            # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
            res1 = orient2d(a, b, p.coords)
            return res1 >= 0
        elif k == 1:
            # find index of non infinite point in [a, b, c]
            d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
            quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
            if np.isnan(quadrant[1]):
                return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
            else:
                return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
        else:
            print('Error: 3 infinite points in triangle')
            print(a, b, c)

    return res >= 0

# %%
def check_vertex(vertex, p):
    halfedge = vertex.halfedge
    if not halfedge:
        # print('no edge for vertex', vertex)
        return None
    while True:
        if check_triangle(halfedge, p):
            return halfedge
        if halfedge.twin == None:
            break
        halfedge = halfedge.twin.next # clockwise
        if halfedge == vertex.halfedge:
            break
        if halfedge.vertex != vertex:
            print('not good', halfedge, halfedge.vertex, vertex)
            break
    return None

# %%
def expand(init_hedge, p):
    interior = TriangularMesh(faces={init_hedge.facet})
    boundary = TriangularMesh()

    visited = []
    stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
    while stack:
        hedge = stack.popleft()
        if hedge.twin == None:
            boundary.halfedges.add(hedge)
            # boundary.vertices.append(hedge.vertex)
            continue
        if hedge.twin.facet.visited or not check_triangle(hedge.twin, p):
            boundary.halfedges.add(hedge)
            # boundary.vertices.append(hedge.vertex)
            continue
        hedge.twin.facet.visited = True
        visited.append(hedge.twin.facet)
        interior.halfedges.update({hedge, hedge.twin})
        interior.faces.add(hedge.twin.facet)

        stack.append(hedge.twin.next)
        stack.append(hedge.twin.prev)

    for face in visited:
        face.visited = False
    
    # print('inbdr', boundary.vertices)
    return interior, boundary

# %%
def Cavity(mesh, p, ind):
    # find a triangle containing p
    # def check_triangle(halfedge):
    #     # print(halfedge.vertex.coords)
    #     # print(halfedge.next.vertex.coords)
    #     # print(halfedge.prev.vertex.coords)
    #     a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
    #     res = incircle(a, b, c, p.coords)
    #     if np.isnan(res):
    #         # number of None in [a, b, c]
    #         k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
    #         if k == 0:
    #             # do orient2d test instead
    #             a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
    #             # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
    #             res1 = orient2d(a, b, p.coords)
    #             return res1 >= 0
    #         elif k == 1:
    #             # find index of non infinite point in [a, b, c]
    #             d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
    #             quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
    #             if np.isnan(quadrant[1]):
    #                 return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
    #             else:
    #                 return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
    #         else:
    #             print('Error: 3 infinite points in triangle')
    #             print(a, b, c)

    #     return res >= 0

    # def check_vertex(vertex):
    #     halfedge = vertex.halfedge
    #     if not halfedge:
    #         # print('no edge for vertex', vertex)
    #         return None
    #     while True:
    #         if check_triangle(halfedge):
    #             return halfedge
    #         if halfedge.twin == None:
    #             break
    #         halfedge = halfedge.twin.next # clockwise
    #         if halfedge == vertex.halfedge:
    #             break
    #         if halfedge.vertex != vertex:
    #             print('not good', halfedge, halfedge.vertex, vertex)
    #             break
    #     return None
    
    # def expand(init_hedge):
    #     interior = TriangularMesh(faces={init_hedge.facet})
    #     boundary = TriangularMesh()

    #     visited = []
    #     stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
    #     while stack:
    #         hedge = stack.popleft()
    #         if hedge.twin == None:
    #             boundary.halfedges.add(hedge)
    #             # boundary.vertices.append(hedge.vertex)
    #             continue
    #         if hedge.twin.facet.visited or not check_triangle(hedge.twin, p):
    #             boundary.halfedges.add(hedge)
    #             # boundary.vertices.append(hedge.vertex)
    #             continue
    #         hedge.twin.facet.visited = True
    #         visited.append(hedge.twin.facet)
    #         interior.halfedges.update({hedge, hedge.twin})
    #         interior.faces.add(hedge.twin.facet)

    #         stack.append(hedge.twin.next)
    #         stack.append(hedge.twin.prev)

    #     for face in visited:
    #         face.visited = False
        
    #     # print('inbdr', boundary.vertices)
    #     return interior, boundary
    
    i = 3
    while True:
        u = mesh.vertices[(ind + (-1)**i * i // 2)%len(mesh.vertices)]
        init_hedge = check_vertex(u, p)
        # print(u.coords)
        if init_hedge:
            break
        i += 2
    
    # print(init_hedge.vertex.coords, init_hedge.next.vertex.coords, init_hedge.prev.vertex.coords)

    res = expand(init_hedge, p)
    return res

# %%
depth = 8
O, R, B = (0.5, 0.5), (0.5, 0), (0, 0.5)
mesh = TriangularMesh()
for p in points:
    mesh.vertices.append(Vertex(tuple(p.tolist()), Hilbert=Hilbert(p, depth, O, R, B)))

# %%
# add points at +-infinity
infite_pts = [(np.inf, np.inf), (-np.inf, np.inf), (-np.inf, -np.inf), (np.inf, -np.inf)] # keep order!
mesh.vertices += list(map(lambda x: Vertex(x, Hilbert=[-1]*depth), infite_pts))
mesh.sort_vertices()
for p in mesh.vertices:
    print(p.coords, p.Hilbert)
# Out:
# (inf, inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (-inf, inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (-inf, -inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (inf, -inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (4.717840118784178e-05, 0.01367675026260684) [0, 0, 0, 0, 0, 0, 1, 1]
# (0.02300352853522758, 0.001388153518130597) [0, 0, 0, 0, 0, 1, 0, 3]
# (0.02583964281862472, 0.0030109915912749363) [0, 0, 0, 0, 0, 1, 1, 0]
# (0.024461777724504308, 0.016660224523016853) [0, 0, 0, 0, 0, 2, 1, 0]
# (0.022779728069945104, 0.027231701834453892) [0, 0, 0, 0, 0, 2, 3, 3]
# (0.0038823394178014725, 0.03201463998081011) [0, 0, 0, 0, 1, 0, 0, 0]
# (0.00417857766117069, 0.031491115226013555) [0, 0, 0, 0, 1, 0, 0, 3]
# (0.0036395025444533324, 0.04945059552544828) [0, 0, 0, 0, 1, 1, 0, 0]
# (0.000961783315486131, 0.05637913278160056) [0, 0, 0, 0, 1, 1, 1, 0]
# (0.009878065321033747, 0.050520841646076065) [0, 0, 0, 0, 1, 1, 3, 0]
# (0.012518528169783827, 0.05284675807179384) [0, 0, 0, 0, 1, 1, 3, 2]
# (0.012825233964081861, 0.05387067422691605) [0, 0, 0, 0, 1, 1, 3, 2]
# (0.022631540018758667, 0.05389331029388189) [0, 0, 0, 0, 1, 2, 0, 2]
# (0.02678309505500509, 0.055167946682746494) [0, 0, 0, 0, 1, 2, 2, 0]
# (0.04023159588797143, 0.04087790574234107) [0, 0, 0, 0, 2, 0, 2, 0]
# (0.0446755271575735, 0.04322642199958748) [0, 0, 0, 0, 2, 0, 2, 2]
# (0.03592007337216807, 0.04343684234472622) [0, 0, 0, 0, 2, 0, 3, 2]
# (0.0379536056352755, 0.05969089670736483) [0, 0, 0, 0, 2, 1, 1, 2]
# (0.05530029633293565, 0.05205125810211031) [0, 0, 0, 0, 2, 2, 3, 3]
# (0.0501853524226501, 0.04415164773624647) [0, 0, 0, 0, 2, 3, 3, 1]
# (0.03949957275431093, 0.0008194562699083141) [0, 0, 0, 0, 3, 0, 3, 0]
# (0.048634390753541146, 0.01738563434024898) [0, 0, 0, 0, 3, 2, 0, 0]
# (0.06214170712117506, 0.01720963291289823) [0, 0, 0, 0, 3, 2, 1, 1]
# (0.03807077510165069, 0.017022370967606504) [0, 0, 0, 0, 3, 3, 0, 1]
# (0.033345814404862506, 0.02709883431284521) [0, 0, 0, 0, 3, 3, 1, 0]
# (0.07152425501629123, 0.004329227775156763) [0, 0, 0, 1, 0, 0, 1, 3]
# (0.07201223158914061, 0.008648263798383682) [0, 0, 0, 1, 0, 0, 2, 0]
# (0.06875367207820804, 0.01381443901455448) [0, 0, 0, 1, 0, 0, 3, 2]
# (0.06380378776956308, 0.022884550026951223) [0, 0, 0, 1, 0, 1, 0, 3]
# (0.06316724021446829, 0.02767060034814861) [0, 0, 0, 1, 0, 1, 1, 1]
# (0.0760084711433262, 0.026871880088293554) [0, 0, 0, 1, 0, 1, 2, 3]
# (0.08755916294065758, 0.02712950316555407) [0, 0, 0, 1, 0, 2, 2, 0]
# (0.09129254139345111, 0.01631416006090558) [0, 0, 0, 1, 0, 2, 3, 1]
# (0.08493637878879734, 0.003260838824505785) [0, 0, 0, 1, 0, 3, 0, 3]
# (0.09513993722155734, 0.013985006715641513) [0, 0, 0, 1, 1, 0, 1, 1]
# (0.10882723049284437, 0.0032349180733511895) [0, 0, 0, 1, 1, 0, 3, 1]
# (0.1120153238380005, 0.007474441024100886) [0, 0, 0, 1, 1, 1, 0, 1]
# (0.11860385924392824, 0.0017294498048326945) [0, 0, 0, 1, 1, 1, 1, 0]
# (0.12169662168099693, 0.017498271181507374) [0, 0, 0, 1, 1, 2, 1, 1]
# (0.12239947309082377, 0.024782338611561316) [0, 0, 0, 1, 1, 2, 2, 1]
# (0.11308021660475509, 0.027869838881740883) [0, 0, 0, 1, 1, 2, 3, 1]
# (0.09658414391867987, 0.02188714053850116) [0, 0, 0, 1, 1, 3, 0, 3]
# (0.09765128194731731, 0.035657195751378934) [0, 0, 0, 1, 2, 0, 0, 3]
# (0.11918680715984198, 0.03692481121612046) [0, 0, 0, 1, 2, 1, 1, 3]
# (0.12080629887516003, 0.04246158679713219) [0, 0, 0, 1, 2, 1, 2, 0]
# (0.11518914504566458, 0.040887879950228134) [0, 0, 0, 1, 2, 1, 3, 3]
# (0.1157255403628824, 0.04206870120926931) [0, 0, 0, 1, 2, 1, 3, 3]
# (0.1144589848065164, 0.04947071955448057) [0, 0, 0, 1, 2, 2, 0, 3]
# (0.11759438983840831, 0.054379414786046354) [0, 0, 0, 1, 2, 2, 1, 3]
# (0.11282197201332844, 0.059136204322067454) [0, 0, 0, 1, 2, 2, 3, 1]
# (0.06318447693539786, 0.03481132428017475) [0, 0, 0, 1, 3, 0, 0, 0]
# (0.06955319914020408, 0.05354160400805319) [0, 0, 0, 1, 3, 1, 0, 2]
# (0.07609872759861414, 0.057385189534133074) [0, 0, 0, 1, 3, 1, 2, 3]
# (0.08425817388381729, 0.05258265857342481) [0, 0, 0, 1, 3, 2, 0, 2]
# (0.0824984687478093, 0.05405806791577139) [0, 0, 0, 1, 3, 2, 0, 2]
# (0.08550836205278112, 0.035141701069829834) [0, 0, 0, 1, 3, 3, 0, 3]
# (0.08674955835942999, 0.033806962157724385) [0, 0, 0, 1, 3, 3, 1, 0]
# (0.09355060832071493, 0.0385059961099703) [0, 0, 0, 1, 3, 3, 1, 2]
# (0.0897188118125386, 0.04136370124869271) [0, 0, 0, 1, 3, 3, 2, 0]
# (0.0833798443603474, 0.040212994228794874) [0, 0, 0, 1, 3, 3, 3, 3]
# (0.06500229870146823, 0.08306497869697171) [0, 0, 0, 2, 0, 1, 0, 3]
# (0.0728457766561591, 0.08558912101888316) [0, 0, 0, 2, 0, 1, 3, 3]
# (0.08633738801307655, 0.08406670876222522) [0, 0, 0, 2, 0, 2, 3, 3]
# (0.09050626917096827, 0.07292223562192224) [0, 0, 0, 2, 0, 3, 2, 1]
# (0.0925499758023991, 0.07286822171257046) [0, 0, 0, 2, 0, 3, 2, 1]
# (0.09046107824665095, 0.07766115228318016) [0, 0, 0, 2, 0, 3, 2, 2]
# (0.10488579977730716, 0.07591358821429417) [0, 0, 0, 2, 1, 0, 2, 1]
# (0.10682530403730739, 0.06525492185030723) [0, 0, 0, 2, 1, 0, 3, 1]
# (0.11314336040464545, 0.0696681782878853) [0, 0, 0, 2, 1, 1, 0, 1]
# (0.11713342390581738, 0.06789841626196036) [0, 0, 0, 2, 1, 1, 0, 2]
# (0.10973768563432007, 0.07284309140542855) [0, 0, 0, 2, 1, 1, 3, 0]
# (0.11134722100292371, 0.08492239850695715) [0, 0, 0, 2, 1, 2, 0, 1]
# (0.11439208601647788, 0.08512595994583994) [0, 0, 0, 2, 1, 2, 0, 2]
# (0.12092626347874658, 0.0892855036506236) [0, 0, 0, 2, 1, 2, 2, 0]
# (0.10123730279581122, 0.08086478016523857) [0, 0, 0, 2, 1, 3, 0, 1]
# (0.09972421480555582, 0.08611549680873831) [0, 0, 0, 2, 1, 3, 1, 3]
# (0.09717477628714377, 0.09593581237221582) [0, 0, 0, 2, 2, 0, 0, 0]
# (0.09966864230349548, 0.09564659149374943) [0, 0, 0, 2, 2, 0, 0, 1]
# (0.09466482634479245, 0.10907873888144182) [0, 0, 0, 2, 2, 0, 1, 1]
# (0.1010640340984732, 0.10231083009525566) [0, 0, 0, 2, 2, 0, 1, 3]
# (0.11429554592198166, 0.0993858706838493) [0, 0, 0, 2, 2, 1, 0, 2]
# (0.11626649793407962, 0.0956335602735614) [0, 0, 0, 2, 2, 1, 0, 3]
# (0.1247975083187689, 0.10328581423295524) [0, 0, 0, 2, 2, 1, 2, 1]
# (0.12462905704256988, 0.10457170253094672) [0, 0, 0, 2, 2, 1, 2, 1]
# (0.12379312235590567, 0.10196866047228992) [0, 0, 0, 2, 2, 1, 2, 1]
# (0.11554504999070259, 0.10215975472747163) [0, 0, 0, 2, 2, 1, 3, 3]
# (0.11914746068532, 0.1220219458514814) [0, 0, 0, 2, 2, 2, 2, 3]
# (0.0977934503237764, 0.11182310568280207) [0, 0, 0, 2, 2, 3, 0, 1]
# (0.10199711645154463, 0.11510379821506878) [0, 0, 0, 2, 2, 3, 3, 3]
# (0.07606648517455916, 0.1072738414311889) [0, 0, 0, 2, 3, 0, 2, 2]
# (0.0695078178979629, 0.12412576875335868) [0, 0, 0, 2, 3, 1, 1, 2]
# (0.07579675340095782, 0.12277042219175849) [0, 0, 0, 2, 3, 1, 2, 2]
# (0.08249227015547911, 0.12088590208525107) [0, 0, 0, 2, 3, 2, 1, 3]
# (0.08897544309418426, 0.12397053664934676) [0, 0, 0, 2, 3, 2, 2, 1]
# (0.09075870566076782, 0.12215878857731377) [0, 0, 0, 2, 3, 2, 2, 2]
# (0.08405911296497615, 0.0999559515929841) [0, 0, 0, 2, 3, 3, 0, 2]
# (0.08354248249903884, 0.10075954543554966) [0, 0, 0, 2, 3, 3, 0, 2]
# (0.08313731993125151, 0.09448091831985517) [0, 0, 0, 2, 3, 3, 0, 3]
# (0.08674353847900462, 0.09898968398529928) [0, 0, 0, 2, 3, 3, 1, 3]
# (0.09365662201054825, 0.10445955722205735) [0, 0, 0, 2, 3, 3, 2, 1]
# (0.0071073684449992625, 0.06858067060900308) [0, 0, 0, 3, 0, 0, 0, 2]
# (0.014570012102691265, 0.07099981563765856) [0, 0, 0, 3, 0, 0, 2, 3]
# (0.014357640907079916, 0.06930723459897448) [0, 0, 0, 3, 0, 0, 3, 2]
# (0.011460645821134707, 0.06743819144648444) [0, 0, 0, 3, 0, 0, 3, 3]
# (0.020437402682071948, 0.06422768295551073) [0, 0, 0, 3, 0, 1, 0, 3]
# (0.01985677290912813, 0.06594089795515656) [0, 0, 0, 3, 0, 1, 0, 3]
# (0.030239192455575825, 0.07061411904629389) [0, 0, 0, 3, 0, 1, 2, 1]
# (0.020285930593607282, 0.08111390145511255) [0, 0, 0, 3, 0, 2, 0, 3]
# (0.015798309188621573, 0.08739867453224881) [0, 0, 0, 3, 0, 2, 3, 0]
# (0.007541070099058245, 0.09146724471550582) [0, 0, 0, 3, 0, 3, 1, 2]
# (0.011504100876735257, 0.09250534161518842) [0, 0, 0, 3, 0, 3, 2, 1]
# (0.005465249044086518, 0.09770367719989737) [0, 0, 0, 3, 1, 0, 0, 2]
# (0.01168040771370249, 0.10064779765358789) [0, 0, 0, 3, 1, 0, 1, 3]
# (0.01343569580205961, 0.10256291688141073) [0, 0, 0, 3, 1, 0, 2, 1]
# (0.014538172935347649, 0.10485240220184622) [0, 0, 0, 3, 1, 0, 2, 1]
# (0.008049736506037242, 0.1083510303175621) [0, 0, 0, 3, 1, 0, 2, 3]
# (0.004431977405382814, 0.10820642662971414) [0, 0, 0, 3, 1, 0, 3, 2]
# (0.002339036315412879, 0.1093968981445751) [0, 0, 0, 3, 1, 1, 0, 0]
# (0.00770480492627601, 0.11273093157401415) [0, 0, 0, 3, 1, 1, 0, 1]
# (0.014975094602614814, 0.10963931933770332) [0, 0, 0, 3, 1, 1, 3, 1]
# (0.009414395121474795, 0.11565325338370858) [0, 0, 0, 3, 1, 1, 3, 3]
# (0.022841140376822944, 0.1239316149500671) [0, 0, 0, 3, 1, 2, 1, 2]
# (0.020634664965171634, 0.11823927032602244) [0, 0, 0, 3, 1, 2, 1, 3]
# (0.02573963614257324, 0.12297157797369451) [0, 0, 0, 3, 1, 2, 2, 1]
# (0.02682808952091098, 0.10043321170321884) [0, 0, 0, 3, 1, 3, 1, 3]
# (0.02507687582907292, 0.10092948387318346) [0, 0, 0, 3, 1, 3, 1, 3]
# (0.02987040112132333, 0.10289913935239936) [0, 0, 0, 3, 1, 3, 2, 1]
# (0.030796213714895826, 0.10227109377116939) [0, 0, 0, 3, 1, 3, 2, 1]
# (0.018948914425666374, 0.10552207941285285) [0, 0, 0, 3, 1, 3, 3, 1]
# (0.03316272693578404, 0.09486231376670473) [0, 0, 0, 3, 2, 0, 0, 0]
# (0.03197791263570671, 0.09646412139515692) [0, 0, 0, 3, 2, 0, 0, 0]
# (0.03793168436948846, 0.09887898837365783) [0, 0, 0, 3, 2, 0, 0, 2]
# (0.042984125676819196, 0.09913117080771838) [0, 0, 0, 3, 2, 0, 1, 2]
# (0.044452400588800955, 0.10861077783565254) [0, 0, 0, 3, 2, 0, 2, 2]
# (0.0362433379428565, 0.11457318007317396) [0, 0, 0, 3, 2, 1, 0, 2]
# (0.04352224102350699, 0.12262186053339974) [0, 0, 0, 3, 2, 1, 2, 2]
# (0.05402554516310876, 0.11537843667394365) [0, 0, 0, 3, 2, 2, 0, 2]
# (0.060893455267532426, 0.12273246733016485) [0, 0, 0, 3, 2, 2, 2, 2]
# (0.055113931322927634, 0.09617224147407566) [0, 0, 0, 3, 2, 3, 1, 0]
# (0.062154245199334324, 0.10137382309023912) [0, 0, 0, 3, 2, 3, 1, 2]
# (0.057158200413207516, 0.09794049585788134) [0, 0, 0, 3, 2, 3, 1, 3]
# (0.043466195481651315, 0.07778028907935308) [0, 0, 0, 3, 3, 0, 2, 2]
# (0.04425691873173121, 0.06610583992686092) [0, 0, 0, 3, 3, 0, 3, 1]
# (0.05546984577570324, 0.07538259578360063) [0, 0, 0, 3, 3, 1, 2, 3]
# (0.04983103117486232, 0.07516465730903865) [0, 0, 0, 3, 3, 1, 3, 1]
# (0.051681676893066464, 0.07381085110274577) [0, 0, 0, 3, 3, 1, 3, 3]
# (0.05380723640016383, 0.07919901037661226) [0, 0, 0, 3, 3, 2, 0, 3]
# (0.061911291534009094, 0.07991413167171257) [0, 0, 0, 3, 3, 2, 1, 1]
# (0.06001425922921477, 0.08358369226922746) [0, 0, 0, 3, 3, 2, 1, 2]
# (0.048588465252776936, 0.08769834549030353) [0, 0, 0, 3, 3, 2, 3, 0]
# (0.03618103398211636, 0.08442117226669621) [0, 0, 0, 3, 3, 3, 0, 2]
# (0.03265585175810415, 0.08595502969086044) [0, 0, 0, 3, 3, 3, 1, 0]
# (0.031653812553584015, 0.0900820787935418) [0, 0, 0, 3, 3, 3, 1, 1]
# (0.046633178063503755, 0.08944112397449844) [0, 0, 0, 3, 3, 3, 2, 3]
# (0.004781755464530302, 0.13012088238722774) [0, 0, 1, 0, 0, 0, 0, 2]
# (0.011869917098275562, 0.13517142776068536) [0, 0, 1, 0, 0, 0, 2, 1]
# (0.004129489650008478, 0.15514337165664005) [0, 0, 1, 0, 0, 1, 1, 2]
# (0.015339459474610684, 0.14419135516665282) [0, 0, 1, 0, 0, 1, 3, 1]
# (0.011604535714005326, 0.14762309733163037) [0, 0, 1, 0, 0, 1, 3, 3]
# (0.019256073135372587, 0.15578040708099894) [0, 0, 1, 0, 0, 2, 1, 1]
# (0.029538643958000432, 0.15272849145119283) [0, 0, 1, 0, 0, 2, 2, 2]
# (0.01820177090019559, 0.12853205693524672) [0, 0, 1, 0, 0, 3, 0, 0]
# (0.03035762639404105, 0.1373922364523792) [0, 0, 1, 0, 0, 3, 2, 2]
# (0.04468826823977534, 0.12589968990083544) [0, 0, 1, 0, 1, 0, 3, 1]
# (0.04752353290869782, 0.13944820976255168) [0, 0, 1, 0, 1, 1, 3, 1]
# (0.03450407913020448, 0.15227270585929487) [0, 0, 1, 0, 1, 3, 1, 0]
# (0.037853516058419356, 0.15155294082838366) [0, 0, 1, 0, 1, 3, 1, 3]
# (0.04166452447094249, 0.15308614405591892) [0, 0, 1, 0, 1, 3, 2, 1]
# (0.04252217332383901, 0.14291417611498258) [0, 0, 1, 0, 1, 3, 3, 0]
# (0.031584673464007174, 0.15856200507143592) [0, 0, 1, 0, 2, 0, 0, 0]
# (0.03714790482058006, 0.16381226184647957) [0, 0, 1, 0, 2, 0, 0, 2]
# (0.03297895708580023, 0.16637685366862776) [0, 0, 1, 0, 2, 0, 1, 0]
# (0.04476432150318321, 0.16337538010144514) [0, 0, 1, 0, 2, 0, 3, 2]
# (0.0571212881777865, 0.16304272794418107) [0, 0, 1, 0, 2, 1, 1, 3]
# (0.05020059327328097, 0.16922510645181454) [0, 0, 1, 0, 2, 1, 3, 1]
# (0.05151268649081164, 0.17132134850912584) [0, 0, 1, 0, 2, 1, 3, 2]
# (0.058118550748105235, 0.1832436402615959) [0, 0, 1, 0, 2, 2, 2, 0]
# (0.0021815498294485147, 0.16590837921848378) [0, 0, 1, 0, 3, 0, 3, 0]
# (0.002107521666541934, 0.18084436710870633) [0, 0, 1, 0, 3, 1, 1, 0]
# (0.00789896686416569, 0.18189936632253112) [0, 0, 1, 0, 3, 1, 2, 0]
# (0.016244089328668943, 0.17492018913532148) [0, 0, 1, 0, 3, 2, 0, 0]
# (0.022662192816425564, 0.17948310279851187) [0, 0, 1, 0, 3, 2, 0, 2]
# (0.01624794646619243, 0.15938071340759852) [0, 0, 1, 0, 3, 3, 0, 0]
# (0.023627626562335746, 0.1598992853048774) [0, 0, 1, 0, 3, 3, 1, 0]
# (0.03022759251613505, 0.16169932281678356) [0, 0, 1, 0, 3, 3, 1, 2]
# (0.024676434959375326, 0.1691676798106302) [0, 0, 1, 0, 3, 3, 2, 3]
# (0.006005171259448994, 0.19861891511301533) [0, 0, 1, 1, 0, 0, 1, 3]
# (0.01035052942319048, 0.19547728096901618) [0, 0, 1, 1, 0, 0, 2, 0]
# (0.012865150742045084, 0.2031185113064684) [0, 0, 1, 1, 0, 0, 2, 2]
# (0.015516463791869217, 0.19876098430343014) [0, 0, 1, 1, 0, 0, 2, 3]
# (0.012289891351187077, 0.18999325569296388) [0, 0, 1, 1, 0, 0, 3, 1]
# (0.016303820652172063, 0.1942335425134737) [0, 0, 1, 1, 0, 1, 0, 1]
# (0.02727728089855308, 0.1898114606336443) [0, 0, 1, 1, 0, 1, 1, 0]
# (0.026664561513222163, 0.19924718749199) [0, 0, 1, 1, 0, 1, 2, 3]
# (0.017820604926477412, 0.20346163839767062) [0, 0, 1, 1, 0, 2, 0, 0]
# (0.02520362354284522, 0.21391814544514576) [0, 0, 1, 1, 0, 2, 2, 0]
# (0.02423101752010348, 0.21608690061952063) [0, 0, 1, 1, 0, 2, 2, 3]
# (0.015680704483832075, 0.21371818522403296) [0, 0, 1, 1, 0, 2, 3, 0]
# (0.016523219201441286, 0.2161189257457261) [0, 0, 1, 1, 0, 2, 3, 1]
# (0.004441277912263342, 0.20440811016731086) [0, 0, 1, 1, 0, 3, 0, 1]
# (0.00277509145527155, 0.21463587219041447) [0, 0, 1, 1, 0, 3, 1, 0]
# (0.013361711082065852, 0.2096088878517849) [0, 0, 1, 1, 0, 3, 3, 2]
# (0.012133567612822471, 0.20932634643750714) [0, 0, 1, 1, 0, 3, 3, 2]
# (0.015520143270123632, 0.2193509503372313) [0, 0, 1, 1, 1, 0, 1, 1]
# (0.008764270485208225, 0.2334612173345869) [0, 0, 1, 1, 1, 0, 2, 3]
# (0.01557019076739774, 0.24299636225260934) [0, 0, 1, 1, 1, 1, 2, 3]
# (0.030787983802974983, 0.24791724052596675) [0, 0, 1, 1, 1, 2, 2, 2]
# (0.01908124295611402, 0.23354278194485067) [0, 0, 1, 1, 1, 3, 3, 1]
# (0.045981527294279734, 0.22779503850512306) [0, 0, 1, 1, 2, 0, 2, 1]
# (0.03220948762286169, 0.23842446382636695) [0, 0, 1, 1, 2, 1, 0, 3]
# (0.038585175792273274, 0.24693594368454663) [0, 0, 1, 1, 2, 1, 1, 2]
# (0.035810289618236846, 0.24783371603930793) [0, 0, 1, 1, 2, 1, 1, 2]
# (0.03642415842814517, 0.24889869180774804) [0, 0, 1, 1, 2, 1, 1, 2]
# (0.036521149154021715, 0.24286705373876505) [0, 0, 1, 1, 2, 1, 1, 3]
# (0.046383067718264503, 0.2445109979349459) [0, 0, 1, 1, 2, 1, 2, 3]
# (0.049991140548568125, 0.24317097961060052) [0, 0, 1, 1, 2, 2, 1, 0]
# (0.05450245386335739, 0.24790706162961407) [0, 0, 1, 1, 2, 2, 1, 2]
# (0.04743959865279568, 0.18868891682656386) [0, 0, 1, 1, 3, 1, 0, 0]
# (0.058258992379165986, 0.18988676876561594) [0, 0, 1, 1, 3, 1, 1, 0]
# (0.057464932535249647, 0.19515191543769284) [0, 0, 1, 1, 3, 1, 1, 3]
# (0.05497333513694136, 0.2148927367745066) [0, 0, 1, 1, 3, 2, 2, 3]
# (0.031734032023857384, 0.21040706543443588) [0, 0, 1, 1, 3, 3, 0, 3]
# (0.035775108878632444, 0.2161869524622868) [0, 0, 1, 1, 3, 3, 1, 2]
# (0.035773316681060874, 0.21381354098626082) [0, 0, 1, 1, 3, 3, 1, 3]
# (0.04679945934330154, 0.21858203228754702) [0, 0, 1, 1, 3, 3, 2, 2]
# (0.045258901135298624, 0.2092570198973175) [0, 0, 1, 1, 3, 3, 3, 2]
# (0.06967455304201353, 0.20178677012864232) [0, 0, 1, 2, 0, 0, 1, 2]
# (0.07441129181512407, 0.1956937777333887) [0, 0, 1, 2, 0, 0, 2, 3]
# (0.07132258831363192, 0.18833740877719385) [0, 0, 1, 2, 0, 0, 3, 0]
# (0.09172686138475517, 0.18965485702494644) [0, 0, 1, 2, 0, 1, 1, 1]
# (0.09103388896227382, 0.19206279598133968) [0, 0, 1, 2, 0, 1, 1, 2]
# (0.08863440485377139, 0.20079377783896668) [0, 0, 1, 2, 0, 1, 2, 3]
# (0.08345613944553099, 0.19589796469527543) [0, 0, 1, 2, 0, 1, 3, 3]
# (0.08042410393723154, 0.20833349275298063) [0, 0, 1, 2, 0, 2, 0, 1]
# (0.09261195460707128, 0.20894282072369819) [0, 0, 1, 2, 0, 2, 1, 2]
# (0.08696612304728657, 0.21027308828695535) [0, 0, 1, 2, 0, 2, 1, 3]
# (0.09116852057147062, 0.2187457469023879) [0, 0, 1, 2, 0, 2, 2, 2]
# (0.07754285807610906, 0.21120440091672077) [0, 0, 1, 2, 0, 3, 2, 3]
# (0.07469167323561343, 0.23411337845094793) [0, 0, 1, 2, 1, 0, 2, 2]
# (0.07352727846160989, 0.2319255658672269) [0, 0, 1, 2, 1, 0, 2, 3]
# (0.07352082030293416, 0.24808242203255237) [0, 0, 1, 2, 1, 1, 2, 1]
# (0.07423980391252183, 0.23959585295955943) [0, 0, 1, 2, 1, 1, 3, 2]
# (0.08584315942302556, 0.24842844598774083) [0, 0, 1, 2, 1, 2, 1, 2]
# (0.0831459229482443, 0.24632955615811725) [0, 0, 1, 2, 1, 2, 1, 2]
# (0.08665108692710544, 0.24272653912451303) [0, 0, 1, 2, 1, 2, 2, 0]
# (0.09261423081461118, 0.2448086189339832) [0, 0, 1, 2, 1, 2, 2, 3]
# (0.08831896526568295, 0.2405061695119688) [0, 0, 1, 2, 1, 2, 3, 3]
# (0.08937523821340909, 0.2212552880228026) [0, 0, 1, 2, 1, 3, 1, 0]
# (0.08158674271434074, 0.23220701027592983) [0, 0, 1, 2, 1, 3, 3, 1]
# (0.08266955472958426, 0.23116854496869932) [0, 0, 1, 2, 1, 3, 3, 2]
# (0.0823270484369597, 0.23232095302770095) [0, 0, 1, 2, 1, 3, 3, 2]
# (0.09719650085488873, 0.22263949002633276) [0, 0, 1, 2, 2, 0, 0, 0]
# (0.09382872152928734, 0.22654052133601854) [0, 0, 1, 2, 2, 0, 0, 1]
# (0.10083037927556004, 0.22366450865419796) [0, 0, 1, 2, 2, 0, 0, 2]
# (0.10205352622865993, 0.22176958009639247) [0, 0, 1, 2, 2, 0, 1, 0]
# (0.1084830390383209, 0.22475098766511659) [0, 0, 1, 2, 2, 0, 1, 2]
# (0.09943737072681091, 0.22733654814481208) [0, 0, 1, 2, 2, 0, 3, 3]
# (0.11685385533330417, 0.24174671390280378) [0, 0, 1, 2, 2, 2, 0, 2]
# (0.11131661729414355, 0.24316169042371205) [0, 0, 1, 2, 2, 2, 1, 0]
# (0.11680335473934367, 0.24579624240754427) [0, 0, 1, 2, 2, 2, 1, 3]
# (0.12008221674548214, 0.24876716894266127) [0, 0, 1, 2, 2, 2, 2, 1]
# (0.1239529450354867, 0.23969716318279355) [0, 0, 1, 2, 2, 2, 3, 2]
# (0.12035401169952298, 0.24050466874230803) [0, 0, 1, 2, 2, 2, 3, 3]
# (0.1247319217224766, 0.22821007628247858) [0, 0, 1, 2, 2, 3, 2, 1]
# (0.1239932402001489, 0.23188952476086677) [0, 0, 1, 2, 2, 3, 2, 2]
# (0.11345228132085783, 0.2340227511452576) [0, 0, 1, 2, 2, 3, 3, 2]
# (0.10023674097002278, 0.19700460335943615) [0, 0, 1, 2, 3, 0, 1, 3]
# (0.11543046411648539, 0.19390315386000778) [0, 0, 1, 2, 3, 1, 0, 2]
# (0.11654664990019648, 0.20220303256893102) [0, 0, 1, 2, 3, 1, 3, 2]
# (0.09467615465658652, 0.21368736240357733) [0, 0, 1, 2, 3, 3, 1, 0]
# (0.09548116000786866, 0.21722137144168963) [0, 0, 1, 2, 3, 3, 1, 1]
# (0.10089144190636656, 0.21098299675130305) [0, 0, 1, 2, 3, 3, 1, 3]
# (0.10608412864085004, 0.2181553460242286) [0, 0, 1, 2, 3, 3, 2, 2]
# (0.0715466591838757, 0.13445859084005862) [0, 0, 1, 3, 0, 0, 2, 0]
# (0.07110020766817726, 0.13477741965493206) [0, 0, 1, 3, 0, 0, 2, 0]
# (0.07302118876309305, 0.14002442300825302) [0, 0, 1, 3, 0, 0, 2, 3]
# (0.06749144774889071, 0.13441369753704202) [0, 0, 1, 3, 0, 0, 3, 3]
# (0.06686283708043717, 0.1427100079257455) [0, 0, 1, 3, 0, 1, 0, 1]
# (0.06719286604152286, 0.14590305645319723) [0, 0, 1, 3, 0, 1, 0, 2]
# (0.06438417552873876, 0.15332433904191822) [0, 0, 1, 3, 0, 1, 1, 1]
# (0.06727058956255338, 0.15419496760007467) [0, 0, 1, 3, 0, 1, 1, 2]
# (0.07604467895617606, 0.14305674984559613) [0, 0, 1, 3, 0, 1, 3, 1]
# (0.07525336917379577, 0.1461129240289556) [0, 0, 1, 3, 0, 1, 3, 2]
# (0.07586369901179968, 0.14818912561225717) [0, 0, 1, 3, 0, 1, 3, 2]
# (0.08970740111707065, 0.15477481191769538) [0, 0, 1, 3, 0, 2, 2, 1]
# (0.08991073146810857, 0.1509962792832663) [0, 0, 1, 3, 0, 2, 2, 3]
# (0.08470169142711403, 0.13024976774645158) [0, 0, 1, 3, 0, 3, 0, 2]
# (0.09366017142453653, 0.13642509727711727) [0, 0, 1, 3, 0, 3, 2, 1]
# (0.09226210995811268, 0.13764862943378542) [0, 0, 1, 3, 0, 3, 2, 2]
# (0.09781638229733203, 0.1279709682811424) [0, 0, 1, 3, 1, 0, 0, 1]
# (0.0991631423037167, 0.13765640697623127) [0, 0, 1, 3, 1, 0, 1, 2]
# (0.10589829657628169, 0.1390367534190068) [0, 0, 1, 3, 1, 0, 2, 2]
# (0.10398392141495261, 0.12672369446662657) [0, 0, 1, 3, 1, 0, 3, 0]
# (0.1239228173450202, 0.12769900609202534) [0, 0, 1, 3, 1, 1, 1, 1]
# (0.11057775001174952, 0.14164484634482788) [0, 0, 1, 3, 1, 2, 0, 0]
# (0.10946961056272608, 0.15197508074589805) [0, 0, 1, 3, 1, 2, 3, 0]
# (0.10064979692551246, 0.146020543608266) [0, 0, 1, 3, 1, 3, 0, 2]
# (0.10529495946815026, 0.1474513427876072) [0, 0, 1, 3, 1, 3, 3, 3]
# (0.11905725384961874, 0.16094968567134538) [0, 0, 1, 3, 2, 1, 1, 3]
# (0.11130153467122594, 0.17769059899588335) [0, 0, 1, 3, 2, 2, 0, 1]
# (0.06425086711472461, 0.15907763969993194) [0, 0, 1, 3, 3, 0, 0, 0]
# (0.07521985528071695, 0.16283519357832932) [0, 0, 1, 3, 3, 0, 1, 2]
# (0.08148197228928322, 0.17189675459953235) [0, 0, 1, 3, 3, 2, 0, 0]
# (0.09313788849956484, 0.17509278753833224) [0, 0, 1, 3, 3, 2, 3, 1]
# (0.08497865585175479, 0.15985540962657185) [0, 0, 1, 3, 3, 3, 0, 3]
# (0.08055737212416669, 0.16878658154472492) [0, 0, 1, 3, 3, 3, 3, 1]
# (0.08501774347730096, 0.17025553297352236) [0, 0, 1, 3, 3, 3, 3, 2]
# (0.12727043248633985, 0.129200381231643) [0, 0, 2, 0, 0, 0, 0, 1]
# (0.12780855272427272, 0.13096446033514864) [0, 0, 2, 0, 0, 0, 0, 1]
# (0.12584698239516812, 0.14395122547680317) [0, 0, 2, 0, 0, 1, 0, 0]
# (0.12700324480793201, 0.14152339458575036) [0, 0, 2, 0, 0, 1, 0, 0]
# (0.1404984279631969, 0.14258818870420065) [0, 0, 2, 0, 0, 1, 3, 1]
# (0.1409697580322593, 0.15152510972888056) [0, 0, 2, 0, 0, 2, 1, 0]
# (0.14136692258433659, 0.15487773508823977) [0, 0, 2, 0, 0, 2, 1, 1]
# (0.1531034145053154, 0.14911547781772183) [0, 0, 2, 0, 0, 2, 2, 3]
# (0.1498333155562377, 0.1425781555001855) [0, 0, 2, 0, 0, 2, 3, 0]
# (0.15459187898278115, 0.12796736908784323) [0, 0, 2, 0, 0, 3, 1, 1]
# (0.14074444398285124, 0.13445199294404497) [0, 0, 2, 0, 0, 3, 3, 0]
# (0.14742267605932902, 0.13790572244985388) [0, 0, 2, 0, 0, 3, 3, 2]
# (0.14607976093101815, 0.1394971715726273) [0, 0, 2, 0, 0, 3, 3, 2]
# (0.1578674914167839, 0.12608456564211512) [0, 0, 2, 0, 1, 0, 0, 0]
# (0.1608872271765206, 0.13736468001113034) [0, 0, 2, 0, 1, 0, 1, 2]
# (0.16019885377031307, 0.13727661839019967) [0, 0, 2, 0, 1, 0, 1, 2]
# (0.1838926609906375, 0.12825307190066904) [0, 0, 2, 0, 1, 1, 1, 1]
# (0.18186076129136564, 0.14653506641095881) [0, 0, 2, 0, 1, 2, 1, 3]
# (0.18419901849300746, 0.1546911864045285) [0, 0, 2, 0, 1, 2, 2, 2]
# (0.17625575065897403, 0.1490997199812465) [0, 0, 2, 0, 1, 2, 3, 3]
# (0.16247445961605078, 0.14742398809194457) [0, 0, 2, 0, 1, 3, 0, 2]
# (0.1651363889459614, 0.14798045749954536) [0, 0, 2, 0, 1, 3, 3, 3]
# (0.16283298884650155, 0.16400867890743198) [0, 0, 2, 0, 2, 0, 0, 2]
# (0.17009612769245963, 0.16187600656089207) [0, 0, 2, 0, 2, 0, 3, 2]
# (0.18263495671172092, 0.15648905025579563) [0, 0, 2, 0, 2, 1, 1, 0]
# (0.1785688881043459, 0.1684034480102754) [0, 0, 2, 0, 2, 1, 3, 2]
# (0.16118738207263006, 0.1839377311927869) [0, 0, 2, 0, 2, 3, 1, 2]
# (0.166609948800721, 0.18367276475785643) [0, 0, 2, 0, 2, 3, 2, 1]
# (0.16822420283021278, 0.18361983349055566) [0, 0, 2, 0, 2, 3, 2, 2]
# (0.16519612184497268, 0.17371747212729327) [0, 0, 2, 0, 2, 3, 3, 0]
# (0.12830753172747378, 0.16025195247119195) [0, 0, 2, 0, 3, 0, 0, 1]
# (0.13058484115042923, 0.16525524982628892) [0, 0, 2, 0, 3, 0, 3, 3]
# (0.14519794484248527, 0.17819072284166027) [0, 0, 2, 0, 3, 2, 0, 2]
# (0.1448178382872779, 0.17992828139170358) [0, 0, 2, 0, 3, 2, 1, 3]
# (0.15110206282266458, 0.18058558688480342) [0, 0, 2, 0, 3, 2, 2, 0]
# (0.14921784204845623, 0.18706528415828905) [0, 0, 2, 0, 3, 2, 2, 1]
# (0.14770992315118314, 0.16758740266266026) [0, 0, 2, 0, 3, 3, 3, 3]
# (0.15461711480873086, 0.20303664123162724) [0, 0, 2, 1, 0, 1, 2, 2]
# (0.14315201437242497, 0.20166060664322305) [0, 0, 2, 1, 0, 1, 3, 1]
# (0.14860458234496243, 0.21297694957058855) [0, 0, 2, 1, 0, 2, 2, 0]
# (0.15157720237725847, 0.21615140352667683) [0, 0, 2, 1, 0, 2, 2, 3]
# (0.13127471014012826, 0.21511943012254708) [0, 0, 2, 1, 0, 3, 1, 2]
# (0.12777103818296343, 0.22549700039326193) [0, 0, 2, 1, 1, 0, 0, 1]
# (0.12509807088784364, 0.23672413265902592) [0, 0, 2, 1, 1, 1, 0, 0]
# (0.12955894710096927, 0.23691068420984662) [0, 0, 2, 1, 1, 1, 0, 1]
# (0.12708372523636702, 0.23952350190694338) [0, 0, 2, 1, 1, 1, 0, 3]
# (0.13192200164446066, 0.24771298059516889) [0, 0, 2, 1, 1, 1, 1, 2]
# (0.1329343907784748, 0.2450808130678941) [0, 0, 2, 1, 1, 1, 2, 0]
# (0.1358636544255616, 0.24862599186689327) [0, 0, 2, 1, 1, 1, 2, 1]
# (0.1386351063423834, 0.23472129676172904) [0, 0, 2, 1, 1, 1, 3, 1]
# (0.13989290527989684, 0.2378616831564987) [0, 0, 2, 1, 1, 1, 3, 1]
# (0.1395491106259541, 0.24089675530774113) [0, 0, 2, 1, 1, 1, 3, 2]
# (0.14264234472031656, 0.23983941097069095) [0, 0, 2, 1, 1, 2, 0, 3]
# (0.15169376092149944, 0.23861604260025748) [0, 0, 2, 1, 1, 2, 3, 3]
# (0.1419115925479758, 0.22543636863898742) [0, 0, 2, 1, 1, 3, 0, 1]
# (0.16387864337265146, 0.22104861207510917) [0, 0, 2, 1, 2, 0, 0, 3]
# (0.16928586823683334, 0.2262434410893045) [0, 0, 2, 1, 2, 0, 1, 2]
# (0.16119088618801258, 0.23700673672224326) [0, 0, 2, 1, 2, 1, 0, 1]
# (0.15741240993900218, 0.24284503810780245) [0, 0, 2, 1, 2, 1, 1, 0]
# (0.16967121419973907, 0.24083511256803136) [0, 0, 2, 1, 2, 1, 3, 2]
# (0.1737152007954833, 0.24463039536662845) [0, 0, 2, 1, 2, 2, 1, 0]
# (0.18218122823842042, 0.24835925262583836) [0, 0, 2, 1, 2, 2, 2, 1]
# (0.1774027183923107, 0.22184536798168042) [0, 0, 2, 1, 2, 3, 0, 3]
# (0.18013297811072615, 0.23193356882477234) [0, 0, 2, 1, 2, 3, 2, 3]
# (0.16264307300566339, 0.19933361719149367) [0, 0, 2, 1, 3, 0, 1, 2]
# (0.16486471075341913, 0.1981807216078596) [0, 0, 2, 1, 3, 0, 2, 0]
# (0.16491312231142763, 0.19624112333587085) [0, 0, 2, 1, 3, 0, 2, 0]
# (0.17568817327129072, 0.1884762400267549) [0, 0, 2, 1, 3, 1, 0, 0]
# (0.17432491869771283, 0.1945703467128701) [0, 0, 2, 1, 3, 1, 0, 1]
# (0.17643621386303088, 0.19308425648885374) [0, 0, 2, 1, 3, 1, 0, 2]
# (0.17968482292961974, 0.19059515313355402) [0, 0, 2, 1, 3, 1, 0, 3]
# (0.18588481553253067, 0.19360820752292485) [0, 0, 2, 1, 3, 1, 1, 2]
# (0.18130631753906967, 0.19246062345744774) [0, 0, 2, 1, 3, 1, 1, 3]
# (0.1766890125947771, 0.20506091393510162) [0, 0, 2, 1, 3, 2, 0, 3]
# (0.18301117782256748, 0.2048477214125739) [0, 0, 2, 1, 3, 2, 1, 0]
# (0.16619278305221652, 0.20641580770109524) [0, 0, 2, 1, 3, 3, 3, 0]
# (0.16839462842192554, 0.20386691018064595) [0, 0, 2, 1, 3, 3, 3, 1]
# (0.18942242000145748, 0.19324933892168095) [0, 0, 2, 2, 0, 0, 0, 3]
# (0.1933221202324228, 0.19550287054352922) [0, 0, 2, 2, 0, 0, 1, 3]
# (0.2029604678780852, 0.19042002196792684) [0, 0, 2, 2, 0, 0, 3, 1]
# (0.2160401089992109, 0.18784928038903892) [0, 0, 2, 2, 0, 1, 1, 1]
# (0.21302804599695924, 0.1966415207416803) [0, 0, 2, 2, 0, 1, 2, 0]
# (0.21583527923284151, 0.1963566805256518) [0, 0, 2, 2, 0, 1, 2, 1]
# (0.20916205616573424, 0.20061249759067235) [0, 0, 2, 2, 0, 1, 3, 2]
# (0.19047468331740514, 0.21556943226975012) [0, 0, 2, 2, 0, 3, 1, 1]
# (0.19113601792188673, 0.21838504045573126) [0, 0, 2, 2, 0, 3, 1, 1]
# (0.196026469166809, 0.21426383468716648) [0, 0, 2, 2, 0, 3, 2, 0]
# (0.20131942592735763, 0.221232932804581) [0, 0, 2, 2, 1, 0, 1, 1]
# (0.20026979952629587, 0.22191427627012583) [0, 0, 2, 2, 1, 0, 1, 1]
# (0.20294218615543702, 0.2247687975619157) [0, 0, 2, 2, 1, 0, 1, 2]
# (0.2030476881151848, 0.23800949908442237) [0, 0, 2, 2, 1, 1, 3, 1]
# (0.20391220483318262, 0.23938429522169913) [0, 0, 2, 2, 1, 2, 0, 3]
# (0.20926229948942354, 0.2482352190329168) [0, 0, 2, 2, 1, 2, 1, 2]
# (0.21256585516409865, 0.24547065536860158) [0, 0, 2, 2, 1, 2, 2, 0]
# (0.21210748179029948, 0.23794541659845614) [0, 0, 2, 2, 1, 2, 3, 0]
# (0.2165416036983262, 0.23687658001284684) [0, 0, 2, 2, 1, 2, 3, 1]
# (0.2058864986944261, 0.22299882895390544) [0, 0, 2, 2, 1, 3, 0, 1]
# (0.21417975001759826, 0.22449964073941497) [0, 0, 2, 2, 1, 3, 1, 3]
# (0.20709696263568, 0.2337026678423112) [0, 0, 2, 2, 1, 3, 3, 2]
# (0.22803611724232342, 0.22379937999236477) [0, 0, 2, 2, 2, 0, 1, 3]
# (0.23220069035146484, 0.2330758671237828) [0, 0, 2, 2, 2, 0, 2, 2]
# (0.21913216395491364, 0.2350168855831246) [0, 0, 2, 2, 2, 1, 0, 0]
# (0.23323894013419522, 0.2345447101069673) [0, 0, 2, 2, 2, 1, 3, 1]
# (0.24253312237396174, 0.24807269853318992) [0, 0, 2, 2, 2, 2, 2, 1]
# (0.24922322171318234, 0.23679360048169462) [0, 0, 2, 2, 2, 2, 3, 1]
# (0.23912347772280462, 0.22200500278067625) [0, 0, 2, 2, 2, 3, 0, 3]
# (0.2477640281574206, 0.22594007573549169) [0, 0, 2, 2, 2, 3, 1, 2]
# (0.22511193311767974, 0.19369885431255984) [0, 0, 2, 2, 3, 0, 0, 2]
# (0.22088177266082254, 0.19390638702111995) [0, 0, 2, 2, 3, 0, 0, 3]
# (0.22045933671643436, 0.19662904257402325) [0, 0, 2, 2, 3, 0, 1, 0]
# (0.2353706254475093, 0.1936286579641857) [0, 0, 2, 2, 3, 1, 0, 1]
# (0.24892193114019256, 0.18769247546816448) [0, 0, 2, 2, 3, 1, 1, 1]
# (0.2465673704374628, 0.19398305159075413) [0, 0, 2, 2, 3, 1, 1, 2]
# (0.24955560454587333, 0.20997887622284905) [0, 0, 2, 2, 3, 2, 1, 2]
# (0.24860553016270304, 0.2117179711085143) [0, 0, 2, 2, 3, 2, 2, 1]
# (0.24456187137846597, 0.21668690485329145) [0, 0, 2, 2, 3, 2, 2, 3]
# (0.23546948404251977, 0.21377731619518703) [0, 0, 2, 2, 3, 2, 3, 0]
# (0.2248952255891271, 0.20866169114083366) [0, 0, 2, 2, 3, 3, 0, 2]
# (0.22206223448703089, 0.21800235029898019) [0, 0, 2, 2, 3, 3, 1, 1]
# (0.22650437326327255, 0.21168424309980827) [0, 0, 2, 2, 3, 3, 1, 3]
# (0.19107908384343486, 0.13165789032574404) [0, 0, 2, 3, 0, 0, 0, 1]
# (0.1900202237828903, 0.13222562765557666) [0, 0, 2, 3, 0, 0, 0, 1]
# (0.1938227762277991, 0.1255386853932532) [0, 0, 2, 3, 0, 0, 0, 3]
# (0.1881220790395235, 0.14549048229186556) [0, 0, 2, 3, 0, 1, 0, 3]
# (0.18850016173870454, 0.15238231896397503) [0, 0, 2, 3, 0, 1, 1, 1]
# (0.19795710000040112, 0.154711522766098) [0, 0, 2, 3, 0, 1, 2, 1]
# (0.2044374134585114, 0.14148210163277186) [0, 0, 2, 3, 0, 2, 0, 0]
# (0.2102759917357997, 0.14094400335786805) [0, 0, 2, 3, 0, 2, 0, 1]
# (0.20709632256481258, 0.1521301376511207) [0, 0, 2, 3, 0, 2, 1, 3]
# (0.20319201034080603, 0.13517079752680938) [0, 0, 2, 3, 0, 3, 3, 0]
# (0.21952683151605812, 0.1334806501173713) [0, 0, 2, 3, 1, 0, 1, 0]
# (0.23422243279063826, 0.1329946765944412) [0, 0, 2, 3, 1, 0, 2, 3]
# (0.2399540666926816, 0.1274010187758443) [0, 0, 2, 3, 1, 1, 0, 3]
# (0.2465165582239378, 0.13378049846621032) [0, 0, 2, 3, 1, 1, 2, 1]
# (0.24069863078748188, 0.1474990412312267) [0, 0, 2, 3, 1, 2, 0, 2]
# (0.23830057424923956, 0.1456035494838407) [0, 0, 2, 3, 1, 2, 0, 2]
# (0.23637117480015146, 0.1509618836368639) [0, 0, 2, 3, 1, 2, 3, 0]
# (0.2343031016753464, 0.15281548344613738) [0, 0, 2, 3, 1, 3, 2, 2]
# (0.23298570526734796, 0.15196173715270078) [0, 0, 2, 3, 1, 3, 2, 3]
# (0.22762204381363882, 0.14219628846312682) [0, 0, 2, 3, 1, 3, 3, 0]
# (0.23001639792831652, 0.14492840882284408) [0, 0, 2, 3, 1, 3, 3, 3]
# (0.22675066235169838, 0.1716488272502299) [0, 0, 2, 3, 2, 0, 2, 1]
# (0.243820216552893, 0.1695549174792098) [0, 0, 2, 3, 2, 1, 2, 3]
# (0.24152819431153305, 0.1693140425765135) [0, 0, 2, 3, 2, 1, 3, 2]
# (0.23932820776075436, 0.18225234273442947) [0, 0, 2, 3, 2, 2, 3, 3]
# (0.23007992619993245, 0.18172236698908506) [0, 0, 2, 3, 2, 3, 2, 0]
# (0.22812707097566642, 0.1752694916289016) [0, 0, 2, 3, 2, 3, 3, 0]
# (0.23012518037910834, 0.1775123120147839) [0, 0, 2, 3, 2, 3, 3, 3]
# (0.18794723817964099, 0.16264951200447708) [0, 0, 2, 3, 3, 0, 0, 1]
# (0.20195342196103594, 0.1572359856224339) [0, 0, 2, 3, 3, 0, 1, 1]
# (0.1976196190747037, 0.16971974953436397) [0, 0, 2, 3, 3, 0, 2, 3]
# (0.1915055832135817, 0.17874555490935673) [0, 0, 2, 3, 3, 1, 0, 2]
# (0.19233068344411341, 0.17600220987486992) [0, 0, 2, 3, 3, 1, 0, 2]
# (0.20000552606216293, 0.17919036761722396) [0, 0, 2, 3, 3, 1, 3, 2]
# (0.2137147116446365, 0.1805803531942437) [0, 0, 2, 3, 3, 2, 2, 0]
# (0.2179390564277145, 0.179836144293003) [0, 0, 2, 3, 3, 2, 2, 3]
# (0.21515821511837263, 0.1810789580889447) [0, 0, 2, 3, 3, 2, 2, 3]
# (0.20637523835019567, 0.15938081157971884) [0, 0, 2, 3, 3, 3, 0, 0]
# (0.21474605324939633, 0.16135226815352743) [0, 0, 2, 3, 3, 3, 1, 3]
# (0.12770477493367371, 0.00773626584080056) [0, 0, 3, 0, 0, 0, 0, 3]
# (0.12520529969920957, 0.007488620779565691) [0, 0, 3, 0, 0, 0, 0, 3]
# (0.13844365637557865, 0.012743323658313543) [0, 0, 3, 0, 0, 0, 2, 2]
# (0.13707886633890753, 0.014161328349079239) [0, 0, 3, 0, 0, 0, 2, 2]
# (0.14816625153781993, 0.005282709021306564) [0, 0, 3, 0, 0, 1, 0, 2]
# (0.15029495143335414, 0.00222021788908755) [0, 0, 3, 0, 0, 1, 1, 0]
# (0.15312278526823841, 0.00763012822859277) [0, 0, 3, 0, 0, 1, 1, 2]
# (0.15578067598762713, 0.021136205619695758) [0, 0, 3, 0, 0, 2, 1, 2]
# (0.15520441841855526, 0.02506673182764818) [0, 0, 3, 0, 0, 2, 2, 1]
# (0.14134886906014865, 0.03015557567136884) [0, 0, 3, 0, 0, 2, 3, 1]
# (0.13132875492176277, 0.04254314645624613) [0, 0, 3, 0, 1, 0, 3, 3]
# (0.125798639283478, 0.051961419559168) [0, 0, 3, 0, 1, 1, 0, 3]
# (0.12806621584669386, 0.05891592638896692) [0, 0, 3, 0, 1, 1, 1, 1]
# (0.13051630818125393, 0.058992927375695725) [0, 0, 3, 0, 1, 1, 1, 2]
# (0.14740598193074017, 0.05102739181147209) [0, 0, 3, 0, 1, 2, 0, 2]
# (0.1494160452529616, 0.06170495533619813) [0, 0, 3, 0, 1, 2, 2, 1]
# (0.1532444505850813, 0.04844063242796526) [0, 0, 3, 0, 1, 2, 3, 1]
# (0.15758107998970683, 0.037668447706779795) [0, 0, 3, 0, 2, 0, 0, 1]
# (0.1637145407952958, 0.03227368577912937) [0, 0, 3, 0, 2, 0, 0, 3]
# (0.15746693876548779, 0.050457330623765784) [0, 0, 3, 0, 2, 1, 0, 0]
# (0.15768628915669824, 0.05030430406599318) [0, 0, 3, 0, 2, 1, 0, 0]
# (0.1609890935502456, 0.04958589114056933) [0, 0, 3, 0, 2, 1, 0, 1]
# (0.17001879242075213, 0.05533342228073024) [0, 0, 3, 0, 2, 1, 2, 3]
# (0.1810349144814506, 0.05617977551012654) [0, 0, 3, 0, 2, 2, 2, 0]
# (0.16046545082671704, 0.003945541560481214) [0, 0, 3, 0, 3, 0, 0, 2]
# (0.18706446831452894, 0.010566194666007278) [0, 0, 3, 0, 3, 1, 2, 1]
# (0.18712768414654346, 0.008286115554745788) [0, 0, 3, 0, 3, 1, 2, 1]
# (0.18329911093818074, 0.017213313966856436) [0, 0, 3, 0, 3, 2, 1, 0]
# (0.18734305594203682, 0.021181430572452586) [0, 0, 3, 0, 3, 2, 1, 2]
# (0.1671280179727178, 0.01768662122108078) [0, 0, 3, 0, 3, 3, 3, 0]
# (0.19075167967423878, 0.003491365287899284) [0, 0, 3, 1, 0, 0, 0, 0]
# (0.19673027297823298, 0.003186994080592198) [0, 0, 3, 1, 0, 0, 1, 0]
# (0.18868495555812748, 0.010158548068353035) [0, 0, 3, 1, 0, 0, 3, 0]
# (0.1913502976307454, 0.0220487164917188) [0, 0, 3, 1, 0, 1, 0, 3]
# (0.19132503322577077, 0.02698132712956325) [0, 0, 3, 1, 0, 1, 1, 0]
# (0.1904197559741726, 0.02871404397888766) [0, 0, 3, 1, 0, 1, 1, 1]
# (0.19494381613514022, 0.030819772213962593) [0, 0, 3, 1, 0, 1, 1, 2]
# (0.19356526125394358, 0.031215941194105645) [0, 0, 3, 1, 0, 1, 1, 2]
# (0.20604268760781297, 0.02290593668711327) [0, 0, 3, 1, 0, 2, 0, 3]
# (0.214826524021134, 0.01654221583455573) [0, 0, 3, 1, 0, 2, 3, 0]
# (0.21486861042630734, 0.0070345639373993185) [0, 0, 3, 1, 0, 3, 1, 2]
# (0.23127549337902065, 0.010490880348294818) [0, 0, 3, 1, 1, 0, 2, 3]
# (0.23280235424194562, 0.010364536387084122) [0, 0, 3, 1, 1, 0, 2, 3]
# (0.22706464954933103, 0.003390957663742422) [0, 0, 3, 1, 1, 0, 3, 0]
# (0.2429105541107197, 0.0041461543905462195) [0, 0, 3, 1, 1, 1, 1, 3]
# (0.2476091934910618, 0.011901850956983262) [0, 0, 3, 1, 1, 1, 2, 2]
# (0.23684497380933733, 0.018725162265325834) [0, 0, 3, 1, 1, 2, 0, 0]
# (0.22369017619898401, 0.022542271808113412) [0, 0, 3, 1, 1, 3, 0, 2]
# (0.22622875261509023, 0.031042995481384672) [0, 0, 3, 1, 1, 3, 1, 2]
# (0.22941973895840595, 0.017774597717306384) [0, 0, 3, 1, 1, 3, 3, 0]
# (0.22211924170065556, 0.03275617590719415) [0, 0, 3, 1, 2, 0, 0, 0]
# (0.22954171389867584, 0.042285376857214896) [0, 0, 3, 1, 2, 0, 2, 0]
# (0.23027139128242624, 0.03765911277358702) [0, 0, 3, 1, 2, 0, 3, 3]
# (0.23971736984416192, 0.03593068921703535) [0, 0, 3, 1, 2, 1, 0, 2]
# (0.24324533369479628, 0.04087881998934639) [0, 0, 3, 1, 2, 1, 2, 0]
# (0.2375368560627933, 0.04338631554749417) [0, 0, 3, 1, 2, 1, 3, 1]
# (0.24597957181818209, 0.05029500140964871) [0, 0, 3, 1, 2, 2, 1, 0]
# (0.24954629332531653, 0.05497791330489221) [0, 0, 3, 1, 2, 2, 2, 1]
# (0.24778532305598278, 0.06143159457376435) [0, 0, 3, 1, 2, 2, 2, 2]
# (0.22460301945396022, 0.05035143346638893) [0, 0, 3, 1, 2, 3, 0, 1]
# (0.22430748699576653, 0.049138509494016325) [0, 0, 3, 1, 2, 3, 0, 1]
# (0.19724144926429732, 0.035008629102411204) [0, 0, 3, 1, 3, 0, 1, 0]
# (0.18810611527090026, 0.04049594901433429) [0, 0, 3, 1, 3, 0, 3, 0]
# (0.18771117177893715, 0.04796294620171371) [0, 0, 3, 1, 3, 1, 0, 0]
# (0.19295567961875948, 0.05489109646066248) [0, 0, 3, 1, 3, 1, 1, 3]
# (0.19980542292969683, 0.06130806832739866) [0, 0, 3, 1, 3, 1, 2, 2]
# (0.2021149217510596, 0.06076876258734498) [0, 0, 3, 1, 3, 1, 2, 2]
# (0.1993551923458552, 0.05681808391881016) [0, 0, 3, 1, 3, 1, 2, 3]
# (0.20714363554596837, 0.05121483801246618) [0, 0, 3, 1, 3, 2, 0, 2]
# (0.21181318802988502, 0.048789093518700755) [0, 0, 3, 1, 3, 2, 3, 0]
# (0.21526716555049075, 0.054448747418672006) [0, 0, 3, 1, 3, 2, 3, 2]
# (0.20222385276222665, 0.06282369150504785) [0, 0, 3, 2, 0, 0, 1, 1]
# (0.19862183955444623, 0.0933972336924731) [0, 0, 3, 2, 0, 1, 2, 1]
# (0.197157115363095, 0.0824097165565133) [0, 0, 3, 2, 0, 1, 3, 3]
# (0.20614004716399026, 0.08046758414129007) [0, 0, 3, 2, 0, 2, 0, 0]
# (0.20367539578725435, 0.08531812702573949) [0, 0, 3, 2, 0, 2, 0, 3]
# (0.21687937256217804, 0.07098543814862712) [0, 0, 3, 2, 0, 3, 2, 1]
# (0.20346169268768677, 0.07449740877290512) [0, 0, 3, 2, 0, 3, 3, 1]
# (0.22594388456600178, 0.0700691163824666) [0, 0, 3, 2, 1, 0, 0, 2]
# (0.2307475926886181, 0.06613705846475093) [0, 0, 3, 2, 1, 0, 3, 1]
# (0.23933764380056022, 0.06959056377393213) [0, 0, 3, 2, 1, 1, 0, 2]
# (0.2404781385076621, 0.07654825441865087) [0, 0, 3, 2, 1, 1, 3, 2]
# (0.24486008888648847, 0.08874824896233624) [0, 0, 3, 2, 1, 2, 2, 0]
# (0.24674991385400624, 0.09111471910468183) [0, 0, 3, 2, 1, 2, 2, 2]
# (0.22151090486136515, 0.08174172865412233) [0, 0, 3, 2, 1, 3, 0, 0]
# (0.22653078732873755, 0.08322005817379785) [0, 0, 3, 2, 1, 3, 0, 2]
# (0.22173424562934363, 0.08281779941408596) [0, 0, 3, 2, 1, 3, 0, 3]
# (0.22195800510419306, 0.08681339682948197) [0, 0, 3, 2, 1, 3, 1, 0]
# (0.2298049183752937, 0.07879844074434994) [0, 0, 3, 2, 1, 3, 3, 0]
# (0.23292590392539314, 0.08337113545003505) [0, 0, 3, 2, 1, 3, 3, 2]
# (0.23267563973942662, 0.08338801071468493) [0, 0, 3, 2, 1, 3, 3, 2]
# (0.23416356810669015, 0.10849574345603752) [0, 0, 3, 2, 2, 0, 2, 2]
# (0.24233669478726538, 0.09975385087517641) [0, 0, 3, 2, 2, 1, 1, 3]
# (0.23783601704153268, 0.10206888520239443) [0, 0, 3, 2, 2, 1, 3, 0]
# (0.2380673930170344, 0.10824340302999857) [0, 0, 3, 2, 2, 1, 3, 1]
# (0.23910550930206498, 0.11027159011686494) [0, 0, 3, 2, 2, 2, 0, 3]
# (0.2232133963137849, 0.11940841824388804) [0, 0, 3, 2, 2, 3, 1, 3]
# (0.20018678615263008, 0.10176997838512869) [0, 0, 3, 2, 3, 0, 2, 1]
# (0.20302124635215602, 0.10361734990659643) [0, 0, 3, 2, 3, 0, 2, 1]
# (0.21383565688117956, 0.12048382714055372) [0, 0, 3, 2, 3, 2, 2, 0]
# (0.21260905055026447, 0.11044780960412282) [0, 0, 3, 2, 3, 2, 3, 0]
# (0.20439783656073718, 0.09828981999095909) [0, 0, 3, 2, 3, 3, 0, 1]
# (0.21132019698235682, 0.0945838359391068) [0, 0, 3, 2, 3, 3, 1, 0]
# (0.21549034206779172, 0.09442297382452025) [0, 0, 3, 2, 3, 3, 1, 1]
# (0.21138489621126888, 0.10052594269112414) [0, 0, 3, 2, 3, 3, 1, 3]
# (0.21749930822660213, 0.1092867009436217) [0, 0, 3, 2, 3, 3, 2, 2]
# (0.21029599011069267, 0.10727961397667207) [0, 0, 3, 2, 3, 3, 3, 2]
# (0.13060072385685062, 0.06284131541969651) [0, 0, 3, 3, 0, 0, 0, 1]
# (0.1342807449130522, 0.07101519197120898) [0, 0, 3, 3, 0, 0, 2, 0]
# (0.13691575561063551, 0.06578400229438608) [0, 0, 3, 3, 0, 0, 3, 1]
# (0.14829901176268334, 0.06377305151535217) [0, 0, 3, 3, 0, 1, 0, 3]
# (0.1266527780476111, 0.07977606493215383) [0, 0, 3, 3, 0, 3, 0, 0]
# (0.12624152788536258, 0.08279069694387298) [0, 0, 3, 3, 0, 3, 0, 3]
# (0.12599075550206373, 0.08271927822062497) [0, 0, 3, 3, 0, 3, 0, 3]
# (0.14057679931180223, 0.09312622094889145) [0, 0, 3, 3, 0, 3, 2, 2]
# (0.1275525708489188, 0.0955220235886699) [0, 0, 3, 3, 1, 0, 0, 0]
# (0.13004445591872882, 0.09691326263666977) [0, 0, 3, 3, 1, 0, 0, 3]
# (0.13021727599925836, 0.11391146885698666) [0, 0, 3, 3, 1, 1, 0, 2]
# (0.1447120668008831, 0.1102284389499566) [0, 0, 3, 3, 1, 2, 0, 1]
# (0.14138161828326168, 0.11636583253956434) [0, 0, 3, 3, 1, 2, 0, 3]
# (0.14078404592039673, 0.12132572921904694) [0, 0, 3, 3, 1, 2, 1, 1]
# (0.1537415840656775, 0.12496062365915228) [0, 0, 3, 3, 1, 2, 2, 2]
# (0.14255577910876815, 0.09515281540279619) [0, 0, 3, 3, 1, 3, 0, 0]
# (0.1554569553526879, 0.10932615272962454) [0, 0, 3, 3, 1, 3, 2, 2]
# (0.1516124233227928, 0.10863851128284785) [0, 0, 3, 3, 1, 3, 2, 3]
# (0.14147398382586585, 0.10842189283455173) [0, 0, 3, 3, 1, 3, 3, 1]
# (0.14661006832345613, 0.10890794163428341) [0, 0, 3, 3, 1, 3, 3, 2]
# (0.16244331366844644, 0.10907935631110488) [0, 0, 3, 3, 2, 0, 3, 2]
# (0.16077444171928856, 0.10352856928818) [0, 0, 3, 3, 2, 0, 3, 3]
# (0.16281700729583137, 0.11018550202053135) [0, 0, 3, 3, 2, 1, 0, 1]
# (0.1654512303525919, 0.1228728499871774) [0, 0, 3, 3, 2, 1, 2, 1]
# (0.1695689910978787, 0.12187021931646691) [0, 0, 3, 3, 2, 1, 2, 2]
# (0.17738508799748653, 0.11597304156762112) [0, 0, 3, 3, 2, 2, 0, 2]
# (0.17677504981563008, 0.11713720061513155) [0, 0, 3, 3, 2, 2, 0, 2]
# (0.1803490933445333, 0.11880248924644976) [0, 0, 3, 3, 2, 2, 2, 0]
# (0.18735158748674718, 0.11249707153309318) [0, 0, 3, 3, 2, 2, 3, 1]
# (0.1861983773791689, 0.09469998463846063) [0, 0, 3, 3, 2, 3, 1, 1]
# (0.15877992056680656, 0.06573054248829446) [0, 0, 3, 3, 3, 0, 0, 0]
# (0.16108494036898213, 0.07668924581006653) [0, 0, 3, 3, 3, 0, 1, 2]
# (0.16398445269215622, 0.07350925175136847) [0, 0, 3, 3, 3, 0, 1, 3]
# (0.16763403012657074, 0.07602457010112529) [0, 0, 3, 3, 3, 0, 2, 1]
# (0.17149444511803502, 0.07754376975776489) [0, 0, 3, 3, 3, 0, 2, 2]
# (0.17106407593590145, 0.07286077903105792) [0, 0, 3, 3, 3, 0, 2, 3]
# (0.16748804203129608, 0.06977837203573511) [0, 0, 3, 3, 3, 0, 3, 3]
# (0.1851319484069578, 0.0681951949109878) [0, 0, 3, 3, 3, 1, 1, 2]
# (0.16004193879743323, 0.082636485800899) [0, 0, 3, 3, 3, 3, 0, 3]
# (0.2571520138549124, 0.007567142175020081) [0, 1, 0, 0, 0, 0, 0, 2]
# (0.2583032163320148, 0.0032539715854079665) [0, 1, 0, 0, 0, 0, 1, 0]
# (0.262637198282477, 0.011533328890595662) [0, 1, 0, 0, 0, 0, 2, 1]
# (0.2645542598884578, 0.014533885399176438) [0, 1, 0, 0, 0, 0, 2, 2]
# (0.27542491481983344, 0.030880349115457006) [0, 1, 0, 0, 0, 2, 2, 1]
# (0.271623509803226, 0.004744446833902294) [0, 1, 0, 0, 0, 3, 0, 2]
# (0.27991949653591364, 0.0036211331579484307) [0, 1, 0, 0, 0, 3, 1, 1]
# (0.2799143744550916, 0.002983139567850235) [0, 1, 0, 0, 0, 3, 1, 1]
# (0.2774836272151313, 0.007577511478353061) [0, 1, 0, 0, 0, 3, 1, 2]
# (0.2744369229668182, 0.014476937868621809) [0, 1, 0, 0, 0, 3, 2, 3]
# (0.2825673605622593, 0.0011827605704469724) [0, 1, 0, 0, 1, 0, 0, 0]
# (0.28646788722980054, 0.013817660856637048) [0, 1, 0, 0, 1, 0, 1, 2]
# (0.291578379128809, 0.009559132438733742) [0, 1, 0, 0, 1, 0, 2, 0]
# (0.2950560496180159, 0.004553626966224078) [0, 1, 0, 0, 1, 0, 3, 2]
# (0.3095327043522318, 0.01374591508998424) [0, 1, 0, 0, 1, 1, 2, 2]
# (0.30035494342188007, 0.011912881377123985) [0, 1, 0, 0, 1, 1, 3, 1]
# (0.30346865862147543, 0.01350539093393166) [0, 1, 0, 0, 1, 1, 3, 2]
# (0.29881109876416256, 0.01849551612663003) [0, 1, 0, 0, 1, 2, 0, 0]
# (0.307856381770401, 0.031165439345075208) [0, 1, 0, 0, 1, 2, 2, 3]
# (0.2825032300053437, 0.020238931933924786) [0, 1, 0, 0, 1, 3, 0, 3]
# (0.2914043181226541, 0.01729158867724412) [0, 1, 0, 0, 1, 3, 3, 0]
# (0.2937400132154766, 0.022631120673777705) [0, 1, 0, 0, 1, 3, 3, 2]
# (0.2853064418860788, 0.044846399894379774) [0, 1, 0, 0, 2, 0, 1, 2]
# (0.28754895983099604, 0.04556020279438022) [0, 1, 0, 0, 2, 0, 1, 2]
# (0.2940138837008811, 0.031802939658656326) [0, 1, 0, 0, 2, 0, 3, 1]
# (0.3041078984424651, 0.037699359249679265) [0, 1, 0, 0, 2, 1, 0, 2]
# (0.3082408088020142, 0.044221209211160684) [0, 1, 0, 0, 2, 1, 2, 3]
# (0.3006296646913095, 0.04113127680892048) [0, 1, 0, 0, 2, 1, 3, 0]
# (0.3053269282448603, 0.04697165547865456) [0, 1, 0, 0, 2, 2, 1, 0]
# (0.30536371429352216, 0.050820745779885934) [0, 1, 0, 0, 2, 2, 1, 3]
# (0.2824335983159857, 0.05521147218040401) [0, 1, 0, 0, 2, 3, 1, 0]
# (0.28594078537180423, 0.05553608931057241) [0, 1, 0, 0, 2, 3, 1, 3]
# (0.2901565355892223, 0.05883333895596343) [0, 1, 0, 0, 2, 3, 2, 1]
# (0.2901287492505735, 0.04920122144340877) [0, 1, 0, 0, 2, 3, 3, 0]
# (0.296554488934788, 0.050496590970005695) [0, 1, 0, 0, 2, 3, 3, 1]
# (0.2516310062894037, 0.03704893881541005) [0, 1, 0, 0, 3, 0, 0, 1]
# (0.2656060899948579, 0.03922537101781831) [0, 1, 0, 0, 3, 0, 2, 1]
# (0.26509861497331166, 0.05292450883131716) [0, 1, 0, 0, 3, 1, 3, 2]
# (0.26625390384573544, 0.04741510125258763) [0, 1, 0, 0, 3, 2, 0, 0]
# (0.271500547485394, 0.05334617921064011) [0, 1, 0, 0, 3, 2, 0, 2]
# (0.2729078975861172, 0.05389713200429458) [0, 1, 0, 0, 3, 2, 0, 2]
# (0.26871554297183753, 0.05729252170173804) [0, 1, 0, 0, 3, 2, 1, 0]
# (0.27968735406394263, 0.04221925029376816) [0, 1, 0, 0, 3, 3, 2, 1]
# (0.26890407760098123, 0.04503634206179108) [0, 1, 0, 0, 3, 3, 3, 1]
# (0.26199699475640836, 0.07408741872532243) [0, 1, 0, 1, 0, 0, 2, 3]
# (0.26759136382598925, 0.07409648240202105) [0, 1, 0, 1, 0, 1, 3, 0]
# (0.2661158245609154, 0.07382068526203811) [0, 1, 0, 1, 0, 1, 3, 0]
# (0.27236105616190864, 0.08575806273726583) [0, 1, 0, 1, 0, 2, 0, 2]
# (0.27597666951150923, 0.07839695505677746) [0, 1, 0, 1, 0, 2, 1, 0]
# (0.26468355058441106, 0.09189470567503566) [0, 1, 0, 1, 0, 3, 2, 2]
# (0.2526688660586184, 0.097827063461567) [0, 1, 0, 1, 1, 0, 0, 1]
# (0.2547539806210657, 0.09815415985994724) [0, 1, 0, 1, 1, 0, 0, 2]
# (0.25505887641454905, 0.1112612418546779) [0, 1, 0, 1, 1, 1, 0, 1]
# (0.25402578024569455, 0.11469539022787567) [0, 1, 0, 1, 1, 1, 0, 2]
# (0.25701162136824784, 0.11821715801961175) [0, 1, 0, 1, 1, 1, 1, 3]
# (0.26050896781161903, 0.11242703885677474) [0, 1, 0, 1, 1, 1, 3, 0]
# (0.2589664493588324, 0.11664817174211317) [0, 1, 0, 1, 1, 1, 3, 3]
# (0.27341293996353067, 0.11455385394731632) [0, 1, 0, 1, 1, 2, 0, 2]
# (0.2670187414853986, 0.11666614087020122) [0, 1, 0, 1, 1, 2, 0, 3]
# (0.268124248371416, 0.09625474579199689) [0, 1, 0, 1, 1, 3, 0, 0]
# (0.28100663980036467, 0.10815807462342342) [0, 1, 0, 1, 1, 3, 2, 2]
# (0.28844153601039324, 0.09540314339105682) [0, 1, 0, 1, 2, 0, 0, 3]
# (0.29335790736381984, 0.09482430828064525) [0, 1, 0, 1, 2, 0, 1, 1]
# (0.294106615390878, 0.0956214722259272) [0, 1, 0, 1, 2, 0, 1, 1]
# (0.284527327467201, 0.10348939070675178) [0, 1, 0, 1, 2, 0, 3, 0]
# (0.28686690837967965, 0.11085073579495641) [0, 1, 0, 1, 2, 1, 0, 1]
# (0.29055814734700547, 0.11278663055672056) [0, 1, 0, 1, 2, 1, 3, 0]
# (0.3019761064783828, 0.11988657255249191) [0, 1, 0, 1, 2, 2, 1, 3]
# (0.308319927816774, 0.12404598215190032) [0, 1, 0, 1, 2, 2, 2, 1]
# (0.30781623573666195, 0.10853421408935171) [0, 1, 0, 1, 2, 3, 2, 3]
# (0.2858941279632793, 0.07236574326600242) [0, 1, 0, 1, 3, 0, 1, 3]
# (0.29390568230101344, 0.07139276294236185) [0, 1, 0, 1, 3, 0, 2, 3]
# (0.30008400783263134, 0.06274531786371396) [0, 1, 0, 1, 3, 1, 0, 0]
# (0.3018527760002132, 0.07011648626889477) [0, 1, 0, 1, 3, 1, 0, 2]
# (0.30740129309184705, 0.08034556348195376) [0, 1, 0, 1, 3, 2, 1, 0]
# (0.3051755691063961, 0.08368240301039087) [0, 1, 0, 1, 3, 2, 1, 3]
# (0.30034953301372636, 0.09046765435098081) [0, 1, 0, 1, 3, 2, 3, 1]
# (0.2992986002778213, 0.09332217106398522) [0, 1, 0, 1, 3, 2, 3, 1]
# (0.3013939231767043, 0.09009466115777853) [0, 1, 0, 1, 3, 2, 3, 2]
# (0.285685656695136, 0.08102863981118347) [0, 1, 0, 1, 3, 3, 0, 1]
# (0.31713858366444847, 0.06299761917442759) [0, 1, 0, 2, 0, 0, 0, 1]
# (0.3244701398980595, 0.07507365264963817) [0, 1, 0, 2, 0, 0, 2, 2]
# (0.327826628058402, 0.07341200188144115) [0, 1, 0, 2, 0, 0, 2, 3]
# (0.3261189566818231, 0.06667171476161171) [0, 1, 0, 2, 0, 0, 3, 2]
# (0.3225651904084571, 0.06946185231285729) [0, 1, 0, 2, 0, 0, 3, 3]
# (0.3394712068279041, 0.07298505145943279) [0, 1, 0, 2, 0, 1, 2, 0]
# (0.33768821455819265, 0.07303679064475932) [0, 1, 0, 2, 0, 1, 2, 0]
# (0.3359040234474746, 0.07808656923298307) [0, 1, 0, 2, 0, 1, 3, 2]
# (0.3250910316133818, 0.09816741691609676) [0, 1, 0, 2, 1, 0, 1, 2]
# (0.32514071618216556, 0.09898451400290387) [0, 1, 0, 2, 1, 0, 1, 2]
# (0.3146994383894466, 0.1068171876729922) [0, 1, 0, 2, 1, 0, 3, 1]
# (0.3317127058974617, 0.11273298778210639) [0, 1, 0, 2, 1, 2, 0, 0]
# ...
# (0.6975277902557964, 0.4571274539071346) [3, 3, 2, 2, 0, 3, 3, 3]
# (0.7007900511797619, 0.47444066723784717) [3, 3, 2, 2, 1, 0, 1, 2]
# (0.690379044222224, 0.4947423600412547) [3, 3, 2, 2, 1, 1, 1, 0]
# (0.7044555686111587, 0.4867399250664993) [3, 3, 2, 2, 1, 2, 0, 0]
# (0.7078427387764744, 0.48454950452796774) [3, 3, 2, 2, 1, 2, 0, 1]
# (0.7108999603948074, 0.4860405951825909) [3, 3, 2, 2, 1, 2, 0, 1]
# (0.7095731169165285, 0.4893890024404146) [3, 3, 2, 2, 1, 2, 0, 2]
# (0.7037774463519892, 0.49235141057174814) [3, 3, 2, 2, 1, 2, 1, 0]
# (0.709741632687363, 0.4974024372089302) [3, 3, 2, 2, 1, 2, 1, 2]
# (0.713460065929862, 0.49391817340462163) [3, 3, 2, 2, 1, 2, 2, 0]
# (0.7039062458982205, 0.47619109726288567) [3, 3, 2, 2, 1, 3, 0, 1]
# (0.7233545300488105, 0.46884764481042385) [3, 3, 2, 2, 2, 0, 0, 3]
# (0.7310269105174225, 0.4778199679533176) [3, 3, 2, 2, 2, 0, 2, 1]
# (0.7253736510309435, 0.4900272866419082) [3, 3, 2, 2, 2, 1, 0, 2]
# (0.7274820709309525, 0.49516671250535427) [3, 3, 2, 2, 2, 1, 2, 0]
# (0.731399349971657, 0.4964681521816696) [3, 3, 2, 2, 2, 1, 2, 2]
# (0.7345714621928189, 0.4845321456820656) [3, 3, 2, 2, 2, 2, 0, 0]
# (0.7393674437256402, 0.4965362022311395) [3, 3, 2, 2, 2, 2, 1, 2]
# (0.7390298032673283, 0.4944055478210988) [3, 3, 2, 2, 2, 2, 1, 3]
# (0.7474474281259966, 0.47501615332517555) [3, 3, 2, 2, 2, 3, 1, 2]
# (0.7445086772453965, 0.4825885119853084) [3, 3, 2, 2, 2, 3, 2, 3]
# (0.7220408806246316, 0.44477801339043765) [3, 3, 2, 2, 3, 0, 0, 3]
# (0.733873323290354, 0.4443248243360747) [3, 3, 2, 2, 3, 0, 3, 2]
# (0.747208976435021, 0.4388893155522865) [3, 3, 2, 2, 3, 1, 1, 1]
# (0.7378534288728039, 0.4545260908748372) [3, 3, 2, 2, 3, 2, 0, 0]
# (0.7350596860818766, 0.4571839854642433) [3, 3, 2, 2, 3, 2, 0, 1]
# (0.7437447635587899, 0.46294859584437276) [3, 3, 2, 2, 3, 2, 2, 0]
# (0.7493312361222252, 0.4671087792840177) [3, 3, 2, 2, 3, 2, 2, 2]
# (0.741431014088214, 0.4611559147716313) [3, 3, 2, 2, 3, 2, 3, 3]
# (0.7219181792620937, 0.46313730831911015) [3, 3, 2, 2, 3, 3, 1, 0]
# (0.6995924539009264, 0.3799131339250186) [3, 3, 2, 3, 0, 0, 1, 2]
# (0.6996256471580529, 0.38897507990871094) [3, 3, 2, 3, 0, 0, 2, 2]
# (0.6891488079370732, 0.3921516679582169) [3, 3, 2, 3, 0, 1, 0, 0]
# (0.688154917319565, 0.39372935349476545) [3, 3, 2, 3, 0, 1, 0, 0]
# (0.694450966619861, 0.3990281571858536) [3, 3, 2, 3, 0, 1, 1, 3]
# (0.6950152471236719, 0.399626533479264) [3, 3, 2, 3, 0, 1, 1, 3]
# (0.7014354604453338, 0.40204173354350636) [3, 3, 2, 3, 0, 1, 2, 3]
# (0.7045998045637367, 0.3918140626519466) [3, 3, 2, 3, 0, 2, 0, 0]
# (0.7051043332439202, 0.3937968532676681) [3, 3, 2, 3, 0, 2, 0, 0]
# (0.7053422208749193, 0.40490626090039206) [3, 3, 2, 3, 0, 2, 1, 1]
# (0.7104941646317606, 0.40164467197697673) [3, 3, 2, 3, 0, 2, 1, 3]
# (0.7071245612522334, 0.38023417009884874) [3, 3, 2, 3, 0, 3, 0, 2]
# (0.7081344540295903, 0.3886976122632184) [3, 3, 2, 3, 0, 3, 3, 2]
# (0.7291120248654662, 0.38705769429374903) [3, 3, 2, 3, 1, 0, 2, 1]
# (0.7332386454457588, 0.37931118588080515) [3, 3, 2, 3, 1, 0, 3, 2]
# (0.7422468381621359, 0.38117510085118533) [3, 3, 2, 3, 1, 1, 1, 3]
# (0.7499505997435907, 0.38447973494736676) [3, 3, 2, 3, 1, 1, 2, 1]
# (0.7353884202370518, 0.3961552802481707) [3, 3, 2, 3, 1, 2, 0, 1]
# (0.7370390158107799, 0.39837080093430755) [3, 3, 2, 3, 1, 2, 0, 1]
# (0.7422850660287823, 0.3925975840457856) [3, 3, 2, 3, 1, 2, 1, 0]
# (0.746000644365256, 0.4048831973342115) [3, 3, 2, 3, 1, 2, 2, 3]
# (0.7228001866361736, 0.3915273417153444) [3, 3, 2, 3, 1, 3, 0, 1]
# (0.7229907983518408, 0.39583126425980597) [3, 3, 2, 3, 1, 3, 0, 2]
# (0.7327428827681605, 0.39992518270623534) [3, 3, 2, 3, 1, 3, 2, 3]
# (0.722534684149509, 0.4192718207399735) [3, 3, 2, 3, 2, 0, 1, 1]
# (0.7289549526184942, 0.4207182248071947) [3, 3, 2, 3, 2, 0, 2, 1]
# (0.7375334340319472, 0.41171415849300463) [3, 3, 2, 3, 2, 1, 0, 1]
# (0.7422416038796121, 0.4160186352984043) [3, 3, 2, 3, 2, 1, 2, 0]
# (0.7480772434482518, 0.41416814561911286) [3, 3, 2, 3, 2, 1, 2, 1]
# (0.7432114779874119, 0.43394686600032917) [3, 3, 2, 3, 2, 2, 2, 3]
# (0.7243511911903955, 0.4303831690488198) [3, 3, 2, 3, 2, 3, 1, 3]
# (0.727506091071583, 0.4309057997488791) [3, 3, 2, 3, 2, 3, 2, 0]
# (0.7279244785731002, 0.42433658539226815) [3, 3, 2, 3, 2, 3, 3, 0]
# (0.6964012862625831, 0.42033991387933956) [3, 3, 2, 3, 3, 0, 2, 3]
# (0.6988891003311399, 0.4302321459130719) [3, 3, 2, 3, 3, 1, 2, 0]
# (0.7011993764147156, 0.4247003495387306) [3, 3, 2, 3, 3, 1, 3, 1]
# (0.7063045670731085, 0.4313354148854467) [3, 3, 2, 3, 3, 2, 1, 0]
# (0.7119059839379083, 0.40722388013571065) [3, 3, 2, 3, 3, 3, 1, 0]
# (0.715116121274671, 0.40717058596157507) [3, 3, 2, 3, 3, 3, 1, 1]
# (0.7075523558280907, 0.42060488077011216) [3, 3, 2, 3, 3, 3, 3, 2]
# (0.633959739754303, 0.2640186737640693) [3, 3, 3, 0, 0, 0, 2, 1]
# (0.6553355836762184, 0.2519329822316839) [3, 3, 3, 0, 0, 1, 1, 1]
# (0.6418635747390532, 0.2631036998455789) [3, 3, 3, 0, 0, 1, 3, 1]
# (0.6459739647937762, 0.2737602228654491) [3, 3, 3, 0, 0, 2, 3, 3]
# (0.6314663700650356, 0.27260179904321413) [3, 3, 3, 0, 0, 3, 0, 2]
# (0.6261052835588863, 0.2772352793199211) [3, 3, 3, 0, 0, 3, 1, 0]
# (0.62687909141043, 0.2856023245783498) [3, 3, 3, 0, 1, 0, 0, 1]
# (0.6308700481234216, 0.28720313531364094) [3, 3, 3, 0, 1, 0, 0, 2]
# (0.6396604409019727, 0.29369008312256184) [3, 3, 3, 0, 1, 0, 2, 2]
# (0.635525718383644, 0.31169885783806084) [3, 3, 3, 0, 1, 1, 2, 1]
# (0.6453985386960589, 0.2992893879524291) [3, 3, 3, 0, 1, 2, 0, 1]
# (0.6452552612353821, 0.3039543145470114) [3, 3, 3, 0, 1, 2, 0, 2]
# (0.6432987127648133, 0.3123203113785138) [3, 3, 3, 0, 1, 2, 1, 1]
# (0.6468355568772672, 0.3105381915830324) [3, 3, 3, 0, 1, 2, 1, 2]
# (0.6557505744512068, 0.30743304451999653) [3, 3, 3, 0, 1, 2, 2, 3]
# (0.6535672104721909, 0.3028216126981036) [3, 3, 3, 0, 1, 2, 3, 2]
# (0.6410995685942968, 0.28747020476874485) [3, 3, 3, 0, 1, 3, 0, 1]
# (0.6481788710108495, 0.28866627968764247) [3, 3, 3, 0, 1, 3, 0, 2]
# (0.6461515587463804, 0.28349363684778994) [3, 3, 3, 0, 1, 3, 0, 3]
# (0.6465019541258531, 0.28215338048006855) [3, 3, 3, 0, 1, 3, 0, 3]
# (0.6430049817082856, 0.2901004644849371) [3, 3, 3, 0, 1, 3, 3, 0]
# (0.6573149339557331, 0.2841698531848148) [3, 3, 3, 0, 2, 0, 0, 0]
# (0.6591764043053228, 0.28761749316814056) [3, 3, 3, 0, 2, 0, 0, 1]
# (0.6563351938863462, 0.2853624203405508) [3, 3, 3, 0, 2, 0, 0, 1]
# (0.6604522811868647, 0.2825356735530027) [3, 3, 3, 0, 2, 0, 0, 3]
# (0.6693785348976822, 0.2836175289491043) [3, 3, 3, 0, 2, 0, 1, 1]
# (0.6599876043798559, 0.2918578580535022) [3, 3, 3, 0, 2, 0, 3, 0]
# (0.6570820677202103, 0.2951944345122687) [3, 3, 3, 0, 2, 0, 3, 1]
# (0.658049632646473, 0.30150943152629106) [3, 3, 3, 0, 2, 1, 0, 3]
# (0.6600235030290984, 0.30172795185217416) [3, 3, 3, 0, 2, 1, 0, 3]
# (0.6707401022105862, 0.2996805717629716) [3, 3, 3, 0, 2, 1, 3, 1]
# (0.6788840473334858, 0.29694213670874214) [3, 3, 3, 0, 2, 2, 0, 1]
# (0.6803443002820797, 0.2976702789483505) [3, 3, 3, 0, 2, 2, 3, 0]
# (0.6847595731435671, 0.28407676565857576) [3, 3, 3, 0, 2, 3, 1, 1]
# (0.6848365223131541, 0.26077372907080154) [3, 3, 3, 0, 3, 1, 2, 1]
# (0.6785296056000837, 0.26317143789085806) [3, 3, 3, 0, 3, 1, 3, 2]
# (0.6769571522682317, 0.26817086654011746) [3, 3, 3, 0, 3, 2, 0, 3]
# (0.6781764465334322, 0.27597127942483624) [3, 3, 3, 0, 3, 2, 3, 3]
# (0.6568594938016451, 0.26936622844248925) [3, 3, 3, 0, 3, 3, 0, 0]
# (0.6672952114858989, 0.28052226261425206) [3, 3, 3, 0, 3, 3, 2, 1]
# (0.6948853308764673, 0.25605394174900586) [3, 3, 3, 1, 0, 0, 0, 2]
# (0.6962805448435269, 0.25292803418012166) [3, 3, 3, 1, 0, 0, 1, 0]
# (0.6956987470168209, 0.2570484042018387) [3, 3, 3, 1, 0, 0, 1, 3]
# (0.7007544005819908, 0.2646909731721694) [3, 3, 3, 1, 0, 0, 2, 2]
# (0.6979834529184632, 0.2654566627998327) [3, 3, 3, 1, 0, 0, 2, 3]
# (0.6909193131573924, 0.2596648438290845) [3, 3, 3, 1, 0, 0, 3, 0]
# (0.6910705974315781, 0.2594346509114901) [3, 3, 3, 1, 0, 0, 3, 0]
# (0.700333939704775, 0.2760716780903174) [3, 3, 3, 1, 0, 1, 2, 3]
# (0.7012121334558177, 0.27484588924235975) [3, 3, 3, 1, 0, 1, 2, 3]
# (0.709539544241262, 0.28108048462001534) [3, 3, 3, 1, 0, 2, 1, 2]
# (0.7074105102034233, 0.27905470252499787) [3, 3, 3, 1, 0, 2, 1, 2]
# (0.7144939441879091, 0.26791471151960755) [3, 3, 3, 1, 0, 2, 3, 0]
# (0.7123988506774913, 0.25126888809465575) [3, 3, 3, 1, 0, 3, 1, 0]
# (0.7126029383701075, 0.25034858308622) [3, 3, 3, 1, 0, 3, 1, 0]
# (0.7170266632158782, 0.25901688451348515) [3, 3, 3, 1, 0, 3, 2, 1]
# (0.7093424824060143, 0.2581812173385488) [3, 3, 3, 1, 0, 3, 3, 3]
# (0.7223680886464713, 0.25122904921795564) [3, 3, 3, 1, 1, 0, 0, 0]
# (0.728878843593415, 0.26401761788663103) [3, 3, 3, 1, 1, 0, 2, 1]
# (0.7300335362256967, 0.25722369956500457) [3, 3, 3, 1, 1, 0, 3, 3]
# (0.7418248342277681, 0.2527581597544222) [3, 3, 3, 1, 1, 1, 0, 3]
# (0.7407100673431899, 0.2615916731406437) [3, 3, 3, 1, 1, 1, 3, 3]
# (0.7350068813964826, 0.26857188489831674) [3, 3, 3, 1, 1, 2, 0, 0]
# (0.7363657959031679, 0.2731031463562279) [3, 3, 3, 1, 1, 2, 0, 1]
# (0.7493894311396059, 0.2693177614644293) [3, 3, 3, 1, 1, 2, 1, 1]
# (0.7499598391318306, 0.2784027130673027) [3, 3, 3, 1, 1, 2, 2, 2]
# (0.7375817459803082, 0.2779410356540869) [3, 3, 3, 1, 1, 2, 3, 1]
# (0.7214461202370188, 0.2781365173190725) [3, 3, 3, 1, 1, 3, 1, 1]
# (0.7345575932690127, 0.2824081042888351) [3, 3, 3, 1, 2, 1, 0, 0]
# (0.7450274908522416, 0.28218360683942867) [3, 3, 3, 1, 2, 1, 1, 0]
# (0.7498787312635683, 0.29411333242767645) [3, 3, 3, 1, 2, 1, 2, 2]
# (0.7497615468764666, 0.295785948417004) [3, 3, 3, 1, 2, 1, 2, 2]
# (0.7354283918004821, 0.3043237717705264) [3, 3, 3, 1, 2, 2, 0, 1]
# (0.7443227405224369, 0.3051737017836066) [3, 3, 3, 1, 2, 2, 2, 0]
# (0.7274668366065034, 0.298492329184898) [3, 3, 3, 1, 2, 3, 3, 0]
# (0.7288093785844882, 0.303556480894562) [3, 3, 3, 1, 2, 3, 3, 3]
# (0.6940301505801848, 0.2846786526308229) [3, 3, 3, 1, 3, 0, 0, 3]
# (0.6998242433693137, 0.284982579063247) [3, 3, 3, 1, 3, 0, 1, 1]
# (0.7027285660060164, 0.29301305069581607) [3, 3, 3, 1, 3, 0, 2, 2]
# (0.6920217059111841, 0.29591561317142856) [3, 3, 3, 1, 3, 0, 3, 2]
# (0.6984324454079288, 0.2973752721148749) [3, 3, 3, 1, 3, 1, 3, 0]
# (0.7081323125631626, 0.3009101810186202) [3, 3, 3, 1, 3, 2, 0, 2]
# (0.7055226596445786, 0.30213581917670784) [3, 3, 3, 1, 3, 2, 0, 3]
# (0.7157763748914462, 0.3018667179184804) [3, 3, 3, 1, 3, 2, 3, 2]
# (0.7177061674786829, 0.3022437166983385) [3, 3, 3, 1, 3, 2, 3, 2]
# (0.7153856033334722, 0.2874203754682243) [3, 3, 3, 1, 3, 3, 1, 2]
# (0.6980885105602022, 0.320784596893513) [3, 3, 3, 2, 0, 0, 2, 0]
# (0.7027502472929926, 0.3260850311909048) [3, 3, 3, 2, 0, 0, 2, 2]
# (0.6904945255764676, 0.32492666879190846) [3, 3, 3, 2, 0, 0, 3, 1]
# (0.6941786960666579, 0.32897294359446005) [3, 3, 3, 2, 0, 1, 0, 1]
# (0.7079797467936645, 0.3315195394971445) [3, 3, 3, 2, 0, 2, 0, 1]
# (0.708838933977525, 0.3289347754947012) [3, 3, 3, 2, 0, 2, 0, 1]
# (0.7133717570171552, 0.33830650401302653) [3, 3, 3, 2, 0, 2, 2, 0]
# (0.7127867379949638, 0.3331469277026661) [3, 3, 3, 2, 0, 2, 3, 3]
# (0.704662325545725, 0.31355524181404626) [3, 3, 3, 2, 0, 3, 0, 0]
# (0.7183154719922932, 0.32514968024876745) [3, 3, 3, 2, 0, 3, 2, 2]
# (0.7068890828313076, 0.320414391205325) [3, 3, 3, 2, 0, 3, 3, 0]
# (0.7215418243212323, 0.31306868826699386) [3, 3, 3, 2, 1, 0, 0, 0]
# (0.7403166430693123, 0.3257031143881155) [3, 3, 3, 2, 1, 1, 3, 2]
# (0.7467014568540518, 0.34164297540077593) [3, 3, 3, 2, 1, 2, 2, 2]
# (0.7223187544956529, 0.3436890676393085) [3, 3, 3, 2, 1, 3, 1, 1]
# (0.7288278724593777, 0.3386312806955669) [3, 3, 3, 2, 1, 3, 2, 0]
# (0.732558242473363, 0.335450205054471) [3, 3, 3, 2, 1, 3, 3, 2]
# (0.7197777650068605, 0.3548564454837496) [3, 3, 3, 2, 2, 0, 1, 0]
# (0.7429704572606104, 0.34622113143318456) [3, 3, 3, 2, 2, 1, 1, 0]
# (0.7490469360780947, 0.35632288376480636) [3, 3, 3, 2, 2, 1, 2, 2]
# (0.7405497608856245, 0.3653223874936006) [3, 3, 3, 2, 2, 2, 0, 2]
# (0.7380739508867138, 0.37300884853490834) [3, 3, 3, 2, 2, 2, 3, 1]
# (0.7408312860610555, 0.37435881254539194) [3, 3, 3, 2, 2, 2, 3, 2]
# (0.7254899885050757, 0.35939327036308655) [3, 3, 3, 2, 2, 3, 0, 1]
# (0.7255267819417215, 0.37241356792172287) [3, 3, 3, 2, 2, 3, 1, 2]
# (0.7330117548069701, 0.36044116916902547) [3, 3, 3, 2, 2, 3, 3, 1]
# (0.7012716761792901, 0.35493946742426186) [3, 3, 3, 2, 3, 0, 2, 1]
# (0.688463693643695, 0.3568054077560112) [3, 3, 3, 2, 3, 0, 3, 1]
# (0.6897432149550602, 0.36161540195455666) [3, 3, 3, 2, 3, 1, 0, 0]
# (0.6919396359530254, 0.3746543703362629) [3, 3, 3, 2, 3, 1, 1, 2]
# (0.702529605173, 0.36375052508113337) [3, 3, 3, 2, 3, 1, 3, 2]
# (0.7008493594311346, 0.3667330709230444) [3, 3, 3, 2, 3, 1, 3, 2]
# (0.703282505226072, 0.3639397461111309) [3, 3, 3, 2, 3, 2, 0, 3]
# (0.7036283738904623, 0.36794569185630976) [3, 3, 3, 2, 3, 2, 1, 0]
# (0.707915855442549, 0.368876149686587) [3, 3, 3, 2, 3, 2, 1, 3]
# (0.7166659823907816, 0.3612222686933233) [3, 3, 3, 2, 3, 2, 3, 1]
# (0.7073509570531115, 0.34493456426408287) [3, 3, 3, 2, 3, 3, 0, 3]
# (0.7149106794287093, 0.3475643943389335) [3, 3, 3, 2, 3, 3, 1, 1]
# (0.7109493847789026, 0.3550944304282787) [3, 3, 3, 2, 3, 3, 2, 0]
# (0.627412475066665, 0.31608438160494035) [3, 3, 3, 3, 0, 0, 0, 0]
# (0.6322637576902114, 0.3259272135334844) [3, 3, 3, 3, 0, 0, 1, 2]
# (0.6335179870277716, 0.32080745266396304) [3, 3, 3, 3, 0, 0, 2, 0]
# (0.6386090061280553, 0.3141930804445894) [3, 3, 3, 3, 0, 0, 3, 1]
# (0.646468728754821, 0.31952071098520174) [3, 3, 3, 3, 0, 1, 0, 2]
# (0.6514293976574405, 0.31452859398704713) [3, 3, 3, 3, 0, 1, 1, 0]
# (0.6508020125598213, 0.32819014474635466) [3, 3, 3, 3, 0, 2, 1, 0]
# (0.652089212918091, 0.33021015231548945) [3, 3, 3, 3, 0, 2, 1, 0]
# (0.6536909700052819, 0.32947097143166293) [3, 3, 3, 3, 0, 2, 1, 1]
# (0.6484420045256272, 0.3374021844552658) [3, 3, 3, 3, 0, 2, 2, 0]
# (0.6556091139873244, 0.33744223343599467) [3, 3, 3, 3, 0, 2, 2, 1]
# (0.653621613639946, 0.34119535922522926) [3, 3, 3, 3, 0, 2, 2, 2]
# (0.6295525384276008, 0.3311416574596362) [3, 3, 3, 3, 0, 3, 0, 1]
# (0.6325065355849467, 0.32825491594486356) [3, 3, 3, 3, 0, 3, 0, 1]
# (0.6370487149162435, 0.3428836662968531) [3, 3, 3, 3, 0, 3, 2, 2]
# (0.6394873878440525, 0.3302001407370828) [3, 3, 3, 3, 0, 3, 3, 1]
# (0.6374279210520789, 0.3357212558733126) [3, 3, 3, 3, 0, 3, 3, 2]
# (0.6378628974804655, 0.34987444400671786) [3, 3, 3, 3, 1, 0, 1, 2]
# (0.6324389040419379, 0.35830747237317895) [3, 3, 3, 3, 1, 0, 3, 2]
# (0.6333227130516562, 0.3629821077242227) [3, 3, 3, 3, 1, 1, 3, 0]
# (0.6381991315053296, 0.3610607604959244) [3, 3, 3, 3, 1, 1, 3, 1]
# (0.6377810598859648, 0.36034951301356544) [3, 3, 3, 3, 1, 1, 3, 1]
# (0.6467431300279624, 0.3702103525103856) [3, 3, 3, 3, 1, 2, 1, 3]
# (0.6494475636249113, 0.37311847106883367) [3, 3, 3, 3, 1, 2, 2, 1]
# (0.6535705341092617, 0.35271942086964625) [3, 3, 3, 3, 1, 3, 2, 1]
# (0.6411153035853171, 0.35865266851743616) [3, 3, 3, 3, 1, 3, 3, 1]
# (0.6596475578950812, 0.3476046607293022) [3, 3, 3, 3, 2, 0, 0, 0]
# (0.669238510772954, 0.35911574988636874) [3, 3, 3, 3, 2, 0, 2, 2]
# (0.6637332570870296, 0.35979593785870134) [3, 3, 3, 3, 2, 1, 0, 1]
# (0.662667320677877, 0.3668319296786898) [3, 3, 3, 3, 2, 1, 0, 2]
# (0.6588854641622961, 0.37448042653062974) [3, 3, 3, 3, 2, 1, 1, 1]
# (0.6683008250999743, 0.36330260302691464) [3, 3, 3, 3, 2, 1, 3, 2]
# (0.6726471648066475, 0.36613882858264535) [3, 3, 3, 3, 2, 2, 0, 3]
# (0.673486558582403, 0.35664851340174053) [3, 3, 3, 3, 2, 3, 3, 1]
# (0.66218040481619, 0.3139674087629919) [3, 3, 3, 3, 3, 0, 0, 1]
# (0.6632916138629592, 0.3178090813020604) [3, 3, 3, 3, 3, 0, 0, 2]
# (0.6601300196271686, 0.31997273098233137) [3, 3, 3, 3, 3, 0, 0, 3]
# (0.6700313923934498, 0.3263800683084118) [3, 3, 3, 3, 3, 0, 2, 2]
# (0.6732365662337003, 0.31504168726579507) [3, 3, 3, 3, 3, 1, 0, 0]
# (0.6721804739397619, 0.31721611862937704) [3, 3, 3, 3, 3, 1, 0, 1]
# (0.6828275492239587, 0.3166185310820204) [3, 3, 3, 3, 3, 1, 1, 3]
# (0.6743852010978499, 0.33398602991520243) [3, 3, 3, 3, 3, 2, 0, 1]
# (0.6787363865654656, 0.3281949527636365) [3, 3, 3, 3, 3, 2, 0, 3]
# (0.6829480718913273, 0.32918645917302514) [3, 3, 3, 3, 3, 2, 1, 0]
# (0.6597627973602039, 0.3311327735961609) [3, 3, 3, 3, 3, 3, 0, 0]
# (0.6697936018375246, 0.33404679803156834) [3, 3, 3, 3, 3, 3, 3, 2]
# (0.666406582241498, 0.3349087947472116) [3, 3, 3, 3, 3, 3, 3, 3]

# %%
# add the 4 initial triangles with infinite points and point p[0]
p = mesh.vertices[4]
init_hedges = []
for i in range(4):
    init_hedges += mesh.add_triangle([mesh.vertices[i], mesh.vertices[(i+1)%4], mesh.vertices[4]], out=True)
# stick edges together
for i in range(4):
    init_hedges[3*i + 1].twin = init_hedges[(3*i + 5) % 12]
    init_hedges[(3*i + 5) % 12].twin = init_hedges[3*i + 1]

# %%
def draw_mesh(mesh):
    for he in mesh.halfedges:
        # if he.visited:
        #     continue
        a, b = he.vertex.coords, he.next.vertex.coords
        # plt.plot(*np.clip((a, b), -0.1, 1.1).T, 'r-')
        plt.plot(*zip(a, b), 'r-', linewidth=0.4)
        # plt.arrow(a[0], a[1], b[0]-a[0], b[1]-a[1], head_width=0.5, head_length=1, fc='r', ec='k')
    for p in mesh.vertices:
        plt.plot(*p.coords, 'ko', markersize=2)
    plt.show()

# draw_mesh(mesh)

# %%
vertices = mesh.vertices[5:]
mesh.vertices = mesh.vertices[:5]

# %%
# p = vertices[0]
# interior, boundary = Cavity(mesh, p, 5)
# print('bdrv', boundary.vertices)
# print('int', interior.halfedges)
# ball = Ball(boundary, p)
# print('ballv', ball.vertices)
# print('ballh', ball.halfedges)

# %%
# draw_mesh(ball)
# mesh.rem_mesh(boundary)
# mesh.rem_mesh(interior)
# mesh.add_mesh(ball)
# print(mesh.vertices, end='\n\n')
# print(mesh.halfedges, end='\n\n')
# print(mesh.faces)

# %%
def f():
    for i in range(len(vertices)):
        p = vertices[i]
        interior, boundary = Cavity(mesh, p, 5+i)
        # print('bdr', boundary.vertices)
        # print('bdrv', boundary.vertices)
        # print('inth', interior.halfedges)
        ball = Ball(boundary, p)
        # print('ballv', ball.vertices)
        # print('ballh', ball.halfedges)
        # draw_mesh(ball)
        mesh.rem_mesh(boundary)
        mesh.rem_mesh(interior)
        mesh.add_mesh(ball)
        # print('he', len(mesh.halfedges), mesh.halfedges, end='\n')
        # print('meshv', mesh.vertices, end='\n\n')
    # draw_mesh(mesh)


# p = vertices[5]
# interior, boundary = Cavity(mesh, p, 5)
# ball = Ball(boundary, p)
# mesh.rem_mesh(boundary)
# mesh.rem_mesh(interior)
# mesh.add_mesh(ball)
# draw_mesh(mesh)

# %%
# %lprun -f Cavity -f check_triangle -f check_vertex -f expand f()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 7.61841 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_59404\2777674375.py
# Function: Cavity at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def Cavity(mesh, p, ind):
#      2                                               # find a triangle containing p
#      3                                               # def check_triangle(halfedge):
#      4                                               #     # print(halfedge.vertex.coords)
#      5                                               #     # print(halfedge.next.vertex.coords)
#      6                                               #     # print(halfedge.prev.vertex.coords)
#      7                                               #     a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
#      8                                               #     res = incircle(a, b, c, p.coords)
#      9                                               #     if np.isnan(res):
#     10                                               #         # number of None in [a, b, c]
#     11                                               #         k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
#     12                                               #         if k == 0:
#     13                                               #             # do orient2d test instead
#     14                                               #             a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
#     15                                               #             # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
#     16                                               #             res1 = orient2d(a, b, p.coords)
#     17                                               #             return res1 >= 0
#     18                                               #         elif k == 1:
#     19                                               #             # find index of non infinite point in [a, b, c]
#     20                                               #             d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
#     21                                               #             quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
#     22                                               #             if np.isnan(quadrant[1]):
#     23                                               #                 return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
#     24                                               #             else:
#     25                                               #                 return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
#     26                                               #         else:
#     27                                               #             print('Error: 3 infinite points in triangle')
#     28                                               #             print(a, b, c)
#     29
#     30                                               #     return res >= 0
#     31
#     32                                               # def check_vertex(vertex):
#     33                                               #     halfedge = vertex.halfedge
#     34                                               #     if not halfedge:
#     35                                               #         # print('no edge for vertex', vertex)
#     36                                               #         return None
#     37                                               #     while True:
#     38                                               #         if check_triangle(halfedge):
#     39                                               #             return halfedge
#     40                                               #         if halfedge.twin == None:
#     41                                               #             break
#     42                                               #         halfedge = halfedge.twin.next # clockwise
#     43                                               #         if halfedge == vertex.halfedge:
#     44                                               #             break
#     45                                               #         if halfedge.vertex != vertex:
#     46                                               #             print('not good', halfedge, halfedge.vertex, vertex)
#     47                                               #             break
#     48                                               #     return None
#     49
#     50                                               # def expand(init_hedge):
#     51                                               #     interior = TriangularMesh(faces={init_hedge.facet})
#     52                                               #     boundary = TriangularMesh()
#     53
#     54                                               #     visited = []
#     55                                               #     stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
#     56                                               #     while stack:
#     57                                               #         hedge = stack.popleft()
#     58                                               #         if hedge.twin == None:
#     59                                               #             boundary.halfedges.add(hedge)
#     60                                               #             # boundary.vertices.append(hedge.vertex)
#     61                                               #             continue
#     62                                               #         if hedge.twin.facet.visited or not check_triangle(hedge.twin, p):
#     63                                               #             boundary.halfedges.add(hedge)
#     64                                               #             # boundary.vertices.append(hedge.vertex)
#     65                                               #             continue
#     66                                               #         hedge.twin.facet.visited = True
#     67                                               #         visited.append(hedge.twin.facet)
#     68                                               #         interior.halfedges.update({hedge, hedge.twin})
#     69                                               #         interior.faces.add(hedge.twin.facet)
#     70
#     71                                               #         stack.append(hedge.twin.next)
#     72                                               #         stack.append(hedge.twin.prev)
#     73
#     74                                               #     for face in visited:
#     75                                               #         face.visited = False
#     76
#     77                                               #     # print('inbdr', boundary.vertices)
#     78                                               #     return interior, boundary
#     79
#     80      9999      52900.0      5.3      0.1      i = 3
#     81     85241     384226.0      4.5      0.5      while True:
#     82     85241    1295477.0     15.2      1.7          u = mesh.vertices[(ind + (-1)**i * i // 2)%len(mesh.vertices)]
#     83     85241   55312583.0    648.9     72.6          init_hedge = check_vertex(u, p)
#     84                                                   # print(u.coords)
#     85     85241     368731.0      4.3      0.5          if init_hedge:
#     86      9999      40991.0      4.1      0.1              break
#     87     75242     388137.0      5.2      0.5          i += 2
#     88
#     89                                               # print(init_hedge.vertex.coords, init_hedge.next.vertex.coords, init_hedge.prev.vertex.coords)
#     90
#     91      9999   18296049.0   1829.8     24.0      res = expand(init_hedge, p)
#     92      9999      45022.0      4.5      0.1      return res
#
# Total time: 2.42277 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_59404\2926192597.py
# Function: check_triangle at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def check_triangle(halfedge, p):
#      2                                               # print(halfedge.vertex.coords)
#      3                                               # print(halfedge.next.vertex.coords)
#      4                                               # print(halfedge.prev.vertex.coords)
#      5    587105    5962790.0     10.2     24.6      a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
#      6    587105    5039548.0      8.6     20.8      res = incircle(a, b, c, p.coords)
#      7    587105    9475714.0     16.1     39.1      if np.isnan(res):
#      8                                                   # number of None in [a, b, c]
#      9      7852      87688.0     11.2      0.4          k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
#     10      7852      36559.0      4.7      0.2          if k == 0:
#     11                                                       # do orient2d test instead
#     12      6907     173730.0     25.2      0.7              a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
#     13                                                       # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
#     14      6907      51565.0      7.5      0.2              res1 = orient2d(a, b, p.coords)
#     15      6907      36029.0      5.2      0.1              return res1 >= 0
#     16       945       4213.0      4.5      0.0          elif k == 1:
#     17                                                       # find index of non infinite point in [a, b, c]
#     18       945      19380.0     20.5      0.1              d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
#     19       945      90016.0     95.3      0.4              quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
#     20       945      17316.0     18.3      0.1              if np.isnan(quadrant[1]):
#     21       411       3945.0      9.6      0.0                  return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
#     22                                                       else:
#     23       534       4850.0      9.1      0.0                  return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
#     24                                                   else:
#     25                                                       print('Error: 3 infinite points in triangle')
#     26                                                       print(a, b, c)
#     27
#     28    579253    3224405.0      5.6     13.3      return res >= 0
#
# Total time: 1.50246 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_59404\3550155769.py
# Function: expand at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def expand(init_hedge, p):
#      2      9999     600869.0     60.1      4.0      interior = TriangularMesh(faces={init_hedge.facet})
#      3      9999     434428.0     43.4      2.9      boundary = TriangularMesh()
#      4
#      5      9999      45081.0      4.5      0.3      visited = []
#      6      9999     131367.0     13.1      0.9      stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
#      7    124652     729414.0      5.9      4.9      while stack:
#      8    114653     628335.0      5.5      4.2          hedge = stack.popleft()
#      9    114653     599707.0      5.2      4.0          if hedge.twin == None:
#     10       352       2115.0      6.0      0.0              boundary.halfedges.add(hedge)
#     11                                                       # boundary.vertices.append(hedge.vertex)
#     12       352       1395.0      4.0      0.0              continue
#     13    114301    8788212.0     76.9     58.5          if hedge.twin.facet.visited or not check_triangle(hedge.twin, p):
#     14     71973     467226.0      6.5      3.1              boundary.halfedges.add(hedge)
#     15                                                       # boundary.vertices.append(hedge.vertex)
#     16     71973     284324.0      4.0      1.9              continue
#     17     42328     238666.0      5.6      1.6          hedge.twin.facet.visited = True
#     18     42328     290594.0      6.9      1.9          visited.append(hedge.twin.facet)
#     19     42328     471130.0     11.1      3.1          interior.halfedges.update({hedge, hedge.twin})
#     20     42328     298055.0      7.0      2.0          interior.faces.add(hedge.twin.facet)
#     21
#     22     42328     269817.0      6.4      1.8          stack.append(hedge.twin.next)
#     23     42328     240255.0      5.7      1.6          stack.append(hedge.twin.prev)
#     24
#     25     52327     246903.0      4.7      1.6      for face in visited:
#     26     42328     201872.0      4.8      1.3          face.visited = False
#     27
#     28                                               # print('inbdr', boundary.vertices)
#     29      9999      54812.0      5.5      0.4      return interior, boundary
#
# Total time: 4.524 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_59404\4024425845.py
# Function: check_vertex at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def check_vertex(vertex, p):
#      2     85241     431999.0      5.1      1.0      halfedge = vertex.halfedge
#      3     85241     384635.0      4.5      0.9      if not halfedge:
#      4                                                   # print('no edge for vertex', vertex)
#      5                                                   return None
#      6    472804    2247020.0      4.8      5.0      while True:
#      7    472804   32036372.0     67.8     70.8          if check_triangle(halfedge, p):
#      8      9999      46013.0      4.6      0.1              return halfedge
#      9    462805    2476364.0      5.4      5.5          if halfedge.twin == None:
#     10                                                       break
#     11    462805    2514972.0      5.4      5.6          halfedge = halfedge.twin.next # clockwise
#     12    462805    2309345.0      5.0      5.1          if halfedge == vertex.halfedge:
#     13     75242     297951.0      4.0      0.7              break
#     14    387563    2157210.0      5.6      4.8          if halfedge.vertex != vertex:
#     15                                                       print('not good', halfedge, halfedge.vertex, vertex)
#     16                                                       break
#     17     75242     338076.0      4.5      0.7      return None

# %%
# %timeit np.isnan(([2, 3], [4, 5]))
# Out:
# 1.65 μs ± 139 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit ([2, 3], [4, 5]) == ([2, 3], [4, 5])
# Out:
# 272 ns ± 22.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from line_profiler import LineProfiler
def check_triangle_wrapper():
	for vertex in mesh.vertices:
		for halfedge in vertex.halfedges:
			check_triangle(halfedge, vertex)

profiler = LineProfiler()
profiler.add_function(check_triangle_wrapper)
profiler.add_function(f)
profiler.run('f()')
profiler.print_stats()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[430], line 5
#       3 profiler.add_function(check_triangle)
#       4 profiler.add_function(f)
# ----> 5 profiler.run('f()')
#       6 profiler.print_stats()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\line_profiler\line_profiler.py:178, in LineProfiler.run(self, cmd)
#     176 import __main__
#     177 main_dict = __main__.__dict__
# --> 178 return self.runctx(cmd, main_dict, main_dict)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\line_profiler\line_profiler.py:185, in LineProfiler.runctx(self, cmd, globals, locals)
#     183 self.enable_by_count()
#     184 try:
# --> 185     exec(cmd, globals, locals)
#     186 finally:
#     187     self.disable_by_count()
#
# File <string>:1
#
# Cell In[427], line 4, in f()
#       2 for i in range(len(vertices)):
#       3     p = vertices[i]
# ----> 4     interior, boundary = Cavity(mesh, p, 5+i)
#       5     # print('bdr', boundary.vertices)
#       6     # print('bdrv', boundary.vertices)
#       7     # print('inth', interior.halfedges)
#       8     ball = Ball(boundary, p)
#
# Cell In[419], line 83, in Cavity(mesh, p, ind)
#      81 while True:
#      82     u = mesh.vertices[(ind + (-1)**i * i // 2)%len(mesh.vertices)]
# ---> 83     init_hedge = check_vertex(u)
#      84     # print(u.coords)
#      85     if init_hedge:
#
# Cell In[417], line 7, in check_vertex(vertex)
#       5     return None
#       6 while True:
# ----> 7     if check_triangle(halfedge):
#       8         return halfedge
#       9     if halfedge.twin == None:
#
# TypeError: check_triangle() missing 1 required positional argument: 'p'

# %%
test_p = points
test_p = [Vertex(p, index=i) for i, p in enumerate(test_p)]
test_e = [Halfedge(vertex=p) for p in test_p]
test_e = [Halfedge(vertex=p, next=test_e[(i+1)%len(test_e)], prev=test_e[(i-1)%len(test_e)]) for i, p in enumerate(test_p)]
test_mesh = TriangularMesh()
test_mesh.vertices = test_p
test_mesh.halfedges = test_e
# plot points
plt.plot(*zip(*map(lambda x: x.coords, test_mesh.vertices)), 'ko')
# plot edges
for hedge in test_mesh.halfedges:
    # draw arrow
    plt.arrow(*hedge.vertex.coords, hedge.next.vertex.coords[0] - hedge.vertex.coords[0], hedge.next.vertex.coords[1] - hedge.vertex.coords[1], head_width=0.1)
plt.show()

# %%
print(test_mesh.halfedges[0].coords)

# %%
ball = Ball(test_mesh, Vertex((1, 1)), 0)
# plot points
plt.plot(*zip(*map(lambda x: x.coords, ball.vertices)), 'bo')
# plot edges
for abc in ball.halfedges:
    print(abc.vertex.coords, abc.next.vertex.coords)
    plt.plot(*zip(abc.vertex.coords, abc.next.vertex.coords), 'g-')
plt.show()

# %%
def DL(points):
    
    # sort points according to Hilbert curve
    depth = 8
    O = np.array([0.5, 0.5])
    R = np.array([0.5, 0])
    B = np.array([0, 0.5])
    indices = [Hilbert(point, depth, O, R, B) for point in points]
    indices = sorted(range(len(indices)), key=lambda i: indices[i])
    mesh = TriangularMesh()
    # create super triangle
    A = Vertex((border[0] - 1, border[2] - 1))
    B = Vertex((border[1] + 1, border[2] - 1))
    C = Vertex((border[0] + border[1], border[3] + 1))
    super_triangle = Face()
    super_triangle.halfedge = Halfedge(vertex=A, next=Halfedge(vertex=B, next=Halfedge(vertex=C, next=Halfedge(vertex=A, facet=super_triangle))))
    super_triangle.index = 0
    mesh.add_mesh(TriangularMesh(vertices=[A, B, C], faces=[super_triangle], halfedges=[super_triangle.halfedge, super_triangle.halfedge.next, super_triangle.halfedge.next.next, super_triangle.halfedge.next.next.next]))
    for i in indices:
        cavity = Cavity(mesh, Vertex(points[i]), i)
        mesh.add_mesh(Ball(cavity, Vertex(points[i]), i))
    return mesh

# %%
orient2d((0., 0.), (0.5, 0.), (np.inf, -0.1))

# %%
# %timeit incircle(np.array([0., 0.]), np.array([1., 0.]), np.array([0., 1.]), np.array([0.5, -0.1]))

# %%
# %timeit incircle((0., 0.), (1., 0.), (0., 1.), (0.5, -0.1))

# %%
def test(a, b, c, p):
    # if one of the points has index -1, do orient2d instead of incircle
    if -1 in [a.index, b.index, c.index]:
        return orient2d(a.coords, b.coords, c.coords)

# %%
import math
sys.float_info.max/1e139

# %%
# %timeit incircle((0., 0.), (1., 0.), (0., 1.0), (0.5, -0.15))

# %%
# %timeit incircle((np.float64(0.), np.float64(0.)), (np.float64(1.), np.float64(0.)), (np.float64(0.), np.float64(1.0)), (np.float64(0.5), np.float64(-0.15)))

# %%
a = [(0., 0.), (1., 0.), (0., 1.0), (0.5, -0.15)]
# a = [[0., 0.], [1., 0.], [0., 1.0], [0.5, -0.15]]
# a = [(np.float64(0.), np.float64(0.)), (np.float64(1.), np.float64(0.)), (np.float64(0.), np.float64(1.0)), (np.float64(0.5), np.float64(-0.15))]
# a = [np.array([0., 0.]), np.array([1., 0.]), np.array([0., 1.0]), np.array([0.5, -0.15])]
# a = np.array([[0., 0.], [1., 0.], [0., 1.0], [0.5, -0.15]])
# %timeit incircle(a[0], a[1], a[2], a[3])

# %%
arr = np.random.rand(10000000, 2)
# %timeit arr2 = list(map(tuple, arr.tolist()))

# %%
# %timeit incircle((np.float32(0.), np.float32(0.)), (np.float32(1.), np.float32(0.)), (np.float32(0.), np.float32(1.0)), (np.float32(0.5), np.float32(-0.15)))

# %%
# %timeit incircle((np.float16(0.), np.float16(0.)), (np.float16(1.), np.float16(0.)), (np.float16(0.), np.float16(1.0)), (np.float16(0.5), np.float16(-0.15)))

# %%
# %timeit incircle([0., 0.], [1., 0.], [0., 1.], [0.5, -0.1])

# %%
a = list(map(tuple, np.random.rand(2, 10).T))

# %%
# %timeit incircle(a[0], a[1], a[2], a[3])

# %%
points

# %%
np.random.rand(10, 2)

# %%
b = sorted(np.random.rand(100, 2), key=lambda x: Hilbert(x, depth, np.array([0.5, 0.5]), np.array([0.5, 0.]), np.array([0., 0.5])))

# %%
insort(b, np.array([0.51, 0.49]), key=lambda x: Hilbert(x, depth, np.array([0.5, 0.5]), np.array([0.5, 0.]), np.array([0., 0.5])))

# %%
for i, p in enumerate(b):
    plt.plot(p[0], p[1], 'ko')
    # write index
    plt.text(p[0], p[1], str(i))
plt.plot(b[-1][0], b[-1][1], 'ro')
plt.show()

# %%
class test:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def __repr__(self):
        return str(self.a-self.b)

l = [] 
for i in range(10):
    l.append(test(4*i**2, 3*i))

print(l[3].b)
