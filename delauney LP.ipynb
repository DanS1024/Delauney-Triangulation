# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pygame as pg
from scipy.spatial import Delaunay
import time
from geompreds import orient2d, incircle
import gmsh
import sys
from bisect import bisect
from collections import deque
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# %load_ext line_profiler

# %%
class TriangularMesh:
    def __init__(self, vertices=None, faces=None, halfedges=None):
        self.vertices = [] if vertices == None else vertices
        self.faces = set() if faces == None else faces
        self.halfedges = set() if halfedges == None else halfedges
        self.version = int(sys.version.split('.')[1]) >= 10

    def sort_vertices(self):
        self.vertices.sort(key=lambda x: x.Hilbert)

    def add_triangle(self, vertices, halfedges=None, out=False):
        halfedges = [Halfedge() for _ in range(3)] if halfedges is None else halfedges
        face = Face(halfedge=halfedges[0])
        for i in range(3):
            halfedges[i].next = halfedges[i-2]
            halfedges[i].prev = halfedges[i-1]
            halfedges[i].vertex = vertices[i]
            halfedges[i].facet = face
            vertices[i].halfedge = halfedges[i]
        self.halfedges.update(halfedges)
        self.faces.add(face)
        if out:
            return halfedges
        # return halfedges
    
    # def rem_halfedge(self, halfedge):
    #     self.halfedges.remove(halfedge)
    #     del halfedge
    
    # def add_Hvertex(self, coords, halfedge, Hilbert, index=None):
    #     if self.version:
    #         ind = bisect(self.vertices, Vertex(Hilbert=Hilbert), key=lambda x: x.Hilbert)
    #         self.vertices.insert(ind, Vertex(coords, halfedge, Hilbert, index))
    #     else:
    #         self.vertices.append(Vertex(coords, halfedge, Hilbert, index))
    #         self.vertices.sort(key=lambda x: x.Hilbert)
    #         ind = self.vertices.index(Vertex(coords, halfedge, Hilbert, index))
    #     return ind
    
    # def add_Hvertices(self, vertices):
    #     self.vertices += vertices
    #     self.vertices.sort(key=lambda x: x.Hilbert)
    #     return list(filter(lambda i: self.vertices[i] in vertices, range(len(self.vertices))))
    
    def add_mesh(self, mesh):
        self.vertices += mesh.vertices
        self.faces.update(mesh.faces)
        self.halfedges.update(mesh.halfedges)

    def rem_mesh(self, mesh):
        # self.vertices.difference_update(mesh.vertices)
        self.faces.difference_update(mesh.faces)
        self.halfedges.difference_update(mesh.halfedges)

    def __repr__(self):
        return f"Vertices: {len(self.vertices)}, Faces: {len(self.faces)}, Halfedges: {len(self.halfedges)}"

class Vertex:
    def __init__(self, coords=None, halfedge=None, Hilbert=None, next=None, prev=None, index=None):
        self.coords = coords
        self.halfedge = halfedge
        self.Hilbert = Hilbert
        self.next = next
        self.prev = prev
        self.index = index
        self.vel = (0., 0.)
        self.acc = (0., 0.)

    def __repr__(self):
        return f"({self.coords[0]:.4g}, {self.coords[1]:.4g})"

class Face:
    def __init__(self, halfedge=None, visited=False, index=None):
        self.halfedge = halfedge # halfedge going ccw around this facet
        self.visited = visited
        self.index = index
    
    def __repr__(self):
        return f"[{self.halfedge.vertex} {self.halfedge.next.vertex} {self.halfedge.prev.vertex}]"

class Halfedge:
    def __init__(self, next=None, prev=None, twin=None, vertex=None, facet=None, index=None):
        self.next = next
        self.prev = prev
        self.twin = twin
        self.vertex = vertex
        self.facet = facet
        self.index = index

    def __repr__(self):
        return f"{self.vertex} -> {self.next.vertex}"

# %%
input_file = '' if '-i' not in sys.argv else sys.argv[sys.argv.index('-i') + 1]
output_file = 'triangles.dat' if '-o' not in sys.argv else sys.argv[sys.argv.index('-o') + 1]

# %%
points = np.random.rand(2, 1000).T if input_file == '' else np.loadtxt(input_file, skiprows=1)
N = len(points)
border = [min(points[:, 0]), max(points[:, 0]), min(points[:, 1]), max(points[:, 1])]

# %%
start = time.time()
tri = Delaunay(points)
print('Time:', time.time() - start)
# Out:
# Time: 0.004574775695800781

# %%
# expected result
plt.triplot(points[:,0], points[:,1], tri.simplices, 'r-', linewidth=0.5)
plt.plot(points[:,0], points[:,1], 'ko', markersize=2)
plt.show()

# %%
def Hilbert(point, depth, O, R, B):
    point, O, R, B = map(np.array, [point, O, R, B])
    index = [0] * depth
    for i in range(depth):
        dotR = np.dot(point-O, R) > 0.
        dotB = np.dot(point-O, B) > 0.
        R /= 2.
        B /= 2.
        if dotR:
            if dotB:
                index[i] = 2
                O += R + B
            else:
                index[i] = 3
                O += R - B
                R, B = B, R
        else:
            if dotB:
                index[i] = 1
                O -= R - B
            else:
                index[i] = 0
                O -= R + B
                R, B = B, R
    return index

# %%
def Ball(boundary, p):
    # connect p to all vertices of the cavity
    new_mesh = TriangularMesh(vertices=[p])
    hedges = sorted(boundary.halfedges, key=lambda hedge: hedge.next.vertex.coords)
    next_bdry_hedges = sorted(boundary.halfedges, key=lambda hedge: hedge.vertex.coords)
    for hedge in hedges:
        new_mesh.add_triangle([p, hedge.vertex, hedge.next.vertex], [Halfedge(), hedge, Halfedge()])
    for i, hedge in enumerate(hedges):
        hedge.next.twin = next_bdry_hedges[i].next.next
        next_bdry_hedges[i].next.next.twin = hedge.next

    return new_mesh

# %%
def check_triangle(halfedge, p):
    # print(halfedge.vertex.coords)
    # print(halfedge.next.vertex.coords)
    # print(halfedge.prev.vertex.coords)
    # a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords

    # check for infinite points

    coords, quadrant = [], 0
    for v in [halfedge.vertex, halfedge.next.vertex, halfedge.prev.vertex]:
        if v.index >= 0:
            coords.append(v.coords)
        else:
            quadrant -= v.index

    if len(coords) == 3:
        return incircle(*coords, p.coords) >= 0
    elif len(coords) == 2:
        if halfedge.next.vertex.index < 0:
            coords = [coords[1], coords[0]]
        return orient2d(*coords, p.coords) >= 0
    else:
        if quadrant == 3:
            return p.coords[1] >= coords[0][1]
        elif quadrant == 6:
            return p.coords[0] <= coords[0][0]
        elif quadrant == 12:
            return p.coords[1] <= coords[0][1]
        elif quadrant == 9:
            return p.coords[0] >= coords[0][0]
        
    print('error')
    return False

    



    a = halfedge.vertex.coords
    b = halfedge.next.vertex.coords
    c = halfedge.prev.vertex.coords
    res = incircle(a, b, c, p.coords)
    if np.isnan(res):
        # number of None in [a, b, c]
        k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
        if k == 0:
            # do orient2d test instead
            a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
            # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
            res1 = orient2d(a, b, p.coords)
            return res1 >= 0
        elif k == 1:
            # find index of non infinite point in [a, b, c]
            d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
            quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
            if np.isnan(quadrant[1]):
                return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
            else:
                return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
        else:
            print('Error: 3 infinite points in triangle')
            print(a, b, c)

    return res >= 0

# %%
def check_vertex(vertex, p):
    halfedge = vertex.halfedge
    if not halfedge:
        # print('no edge for vertex', vertex)
        return None
    while True:
        if check_triangle(halfedge, p):
            return halfedge
        if halfedge.twin == None:
            break
        halfedge = halfedge.twin.next # clockwise
        if halfedge == vertex.halfedge:
            break
        if halfedge.vertex != vertex:
            print('not good', halfedge, halfedge.vertex, vertex)
            break
    return None

# %%
def expand(init_hedge, p):
    interior = TriangularMesh(faces={init_hedge.facet})
    boundary = TriangularMesh()

    # visited = []
    stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
    while stack:
        hedge = stack.popleft()
        if hedge.twin == None:
            boundary.halfedges.add(hedge)
            # boundary.vertices.append(hedge.vertex)
            continue
        if not check_triangle(hedge.twin, p):
            boundary.halfedges.add(hedge)
            # boundary.vertices.append(hedge.vertex)
            continue
        # hedge.twin.facet.visited = True
        # visited.append(hedge.twin.facet)
        interior.halfedges.update({hedge, hedge.twin})
        interior.faces.add(hedge.twin.facet)

        stack.append(hedge.twin.next)
        stack.append(hedge.twin.prev)

    # for face in visited:
    #     face.visited = False
    
    # print('inbdr', boundary.vertices)
    return interior, boundary

# %%
def Cavity(mesh, p, ind):
    # find a triangle containing p
    # def check_triangle(halfedge):
    #     # print(halfedge.vertex.coords)
    #     # print(halfedge.next.vertex.coords)
    #     # print(halfedge.prev.vertex.coords)
    #     a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
    #     res = incircle(a, b, c, p.coords)
    #     if np.isnan(res):
    #         # number of None in [a, b, c]
    #         k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
    #         if k == 0:
    #             # do orient2d test instead
    #             a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
    #             # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
    #             res1 = orient2d(a, b, p.coords)
    #             return res1 >= 0
    #         elif k == 1:
    #             # find index of non infinite point in [a, b, c]
    #             d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
    #             quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
    #             if np.isnan(quadrant[1]):
    #                 return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
    #             else:
    #                 return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
    #         else:
    #             print('Error: 3 infinite points in triangle')
    #             print(a, b, c)

    #     return res >= 0

    # def check_vertex(vertex):
    #     halfedge = vertex.halfedge
    #     if not halfedge:
    #         # print('no edge for vertex', vertex)
    #         return None
    #     while True:
    #         if check_triangle(halfedge):
    #             return halfedge
    #         if halfedge.twin == None:
    #             break
    #         halfedge = halfedge.twin.next # clockwise
    #         if halfedge == vertex.halfedge:
    #             break
    #         if halfedge.vertex != vertex:
    #             print('not good', halfedge, halfedge.vertex, vertex)
    #             break
    #     return None
    
    # def expand(init_hedge):
    #     interior = TriangularMesh(faces={init_hedge.facet})
    #     boundary = TriangularMesh()

    #     visited = []
    #     stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
    #     while stack:
    #         hedge = stack.popleft()
    #         if hedge.twin == None:
    #             boundary.halfedges.add(hedge)
    #             # boundary.vertices.append(hedge.vertex)
    #             continue
    #         if hedge.twin.facet.visited or not check_triangle(hedge.twin, p):
    #             boundary.halfedges.add(hedge)
    #             # boundary.vertices.append(hedge.vertex)
    #             continue
    #         hedge.twin.facet.visited = True
    #         visited.append(hedge.twin.facet)
    #         interior.halfedges.update({hedge, hedge.twin})
    #         interior.faces.add(hedge.twin.facet)

    #         stack.append(hedge.twin.next)
    #         stack.append(hedge.twin.prev)

    #     for face in visited:
    #         face.visited = False
        
    #     # print('inbdr', boundary.vertices)
    #     return interior, boundary
    
    i = -1
    while True:
        # u = mesh.vertices[(ind + (-1)**i * i // 2)%len(mesh.vertices)]
        u = mesh.vertices[i]
        init_hedge = check_vertex(u, p)
        # print(u.coords)
        if init_hedge:
            break
        i -= 1
    
    # print(init_hedge.vertex.coords, init_hedge.next.vertex.coords, init_hedge.prev.vertex.coords)

    res = expand(init_hedge, p)
    return res

# %%
depth = 8
O, R, B = (0.5, 0.5), (0.5, 0), (0, 0.5)
mesh = TriangularMesh()
for i, p in enumerate(points):
    mesh.vertices.append(Vertex(tuple(p.tolist()), Hilbert=Hilbert(p, depth, O, R, B), index=i))

# %%
# add points at +-infinity
infite_pts = [(np.inf, np.inf), (-np.inf, np.inf), (-np.inf, -np.inf), (np.inf, -np.inf)] # keep order!
for i, p in enumerate(infite_pts):
    mesh.vertices.append(Vertex(p, Hilbert = [-1]*depth, index=-(1 << i)))
mesh.sort_vertices()
for p in mesh.vertices:
    print(p.coords, p.Hilbert)
# Out:
# (inf, inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (-inf, inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (-inf, -inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (inf, -inf) [-1, -1, -1, -1, -1, -1, -1, -1]
# (0.01990017010249656, 0.007189197747736964) [0, 0, 0, 0, 0, 1, 0, 2]
# (0.02402154292018044, 0.0034725526615272395) [0, 0, 0, 0, 0, 1, 1, 0]
# (0.06843655456957187, 0.020686194799562685) [0, 0, 0, 1, 0, 1, 0, 2]
# (0.0878744280879471, 0.019253999133145516) [0, 0, 0, 1, 0, 2, 3, 0]
# (0.09521032922350148, 0.006713072007039522) [0, 0, 0, 1, 1, 0, 0, 3]
# (0.1006729711889025, 0.03329834672015697) [0, 0, 0, 1, 2, 0, 0, 1]
# (0.06410748714038317, 0.08163607361967018) [0, 0, 0, 2, 0, 1, 0, 0]
# (0.06270468077691527, 0.08356073554573229) [0, 0, 0, 2, 0, 1, 0, 3]
# (0.08685674772907537, 0.07671467864182013) [0, 0, 0, 2, 0, 3, 2, 3]
# (0.08761492627706902, 0.11731528841735939) [0, 0, 0, 2, 3, 2, 2, 0]
# (0.015512166860213283, 0.08318048262723576) [0, 0, 0, 3, 0, 3, 3, 2]
# (0.003388462531727532, 0.1483171421343389) [0, 0, 1, 0, 0, 1, 0, 3]
# (0.020680651283482065, 0.14711025196292993) [0, 0, 1, 0, 0, 2, 0, 2]
# (0.05567852643576143, 0.12975588896080115) [0, 0, 1, 0, 1, 1, 1, 3]
# (0.05239801470906824, 0.15363683736146994) [0, 0, 1, 0, 1, 2, 3, 2]
# (0.05878103466917517, 0.16240846347078353) [0, 0, 1, 0, 2, 1, 1, 2]
# (0.0459183270333523, 0.17599502833196812) [0, 0, 1, 0, 2, 3, 3, 2]
# (0.031146554178644537, 0.18974956968282386) [0, 0, 1, 1, 0, 1, 1, 1]
# (0.033779725712962616, 0.18908043003583452) [0, 0, 1, 1, 3, 0, 0, 0]
# (0.07335301312493636, 0.24895915890105658) [0, 0, 1, 2, 1, 1, 2, 1]
# (0.08291156538552269, 0.1470405040191305) [0, 0, 1, 3, 0, 2, 0, 2]
# (0.103693700952451, 0.16934130737338016) [0, 0, 1, 3, 2, 0, 2, 1]
# (0.07509425663555924, 0.1679476679786973) [0, 0, 1, 3, 3, 0, 2, 1]
# (0.08840459402875156, 0.18152880158450535) [0, 0, 1, 3, 3, 2, 2, 0]
# (0.1326265272260655, 0.13906102147869615) [0, 0, 2, 0, 0, 0, 3, 2]
# (0.129157081859958, 0.14262322270241168) [0, 0, 2, 0, 0, 1, 0, 1]
# (0.1647093411124969, 0.14920024468610782) [0, 0, 2, 0, 1, 3, 2, 0]
# (0.17743695020500094, 0.1820343188277006) [0, 0, 2, 0, 2, 2, 3, 3]
# (0.163106826473298, 0.17724704425014315) [0, 0, 2, 0, 2, 3, 0, 2]
# (0.15608511599195762, 0.1842042037085755) [0, 0, 2, 0, 3, 2, 2, 2]
# (0.14187707481520462, 0.16608907411718543) [0, 0, 2, 0, 3, 3, 3, 0]
# (0.14901406733455724, 0.19936594413520692) [0, 0, 2, 1, 0, 1, 2, 3]
# (0.1624260300283369, 0.18915055700118977) [0, 0, 2, 1, 3, 0, 0, 1]
# (0.1684672972307093, 0.19313175709064856) [0, 0, 2, 1, 3, 0, 3, 2]
# (0.1849916414220818, 0.19988000357699032) [0, 0, 2, 1, 3, 1, 2, 2]
# (0.17743989133272708, 0.1969014803118807) [0, 0, 2, 1, 3, 1, 3, 3]
# (0.20217190771583182, 0.19498448007685176) [0, 0, 2, 2, 0, 0, 3, 2]
# (0.22597699846698271, 0.23867816977621625) [0, 0, 2, 2, 2, 1, 0, 2]
# (0.2311650703848298, 0.24600760163858304) [0, 0, 2, 2, 2, 1, 2, 3]
# (0.2232237091617051, 0.12562811728848855) [0, 0, 2, 3, 1, 0, 0, 1]
# (0.18772631174502497, 0.1645668652797595) [0, 0, 2, 3, 3, 0, 3, 0]
# (0.2114714620992857, 0.1850106459234251) [0, 0, 2, 3, 3, 2, 2, 1]
# (0.168499551017934, 0.054626822753756965) [0, 0, 3, 0, 2, 1, 3, 2]
# (0.20501997435167774, 8.130320029764437e-05) [0, 0, 3, 1, 0, 3, 0, 0]
# (0.2138742069699292, 0.08154197697379562) [0, 0, 3, 2, 0, 2, 3, 0]
# (0.21349333412443183, 0.07112600869610453) [0, 0, 3, 2, 0, 3, 2, 0]
# (0.2257443998105404, 0.08725334479461622) [0, 0, 3, 2, 1, 3, 1, 3]
# (0.1967952477371262, 0.09455819746629879) [0, 0, 3, 2, 3, 0, 1, 0]
# (0.1302621254707682, 0.0663136696016392) [0, 0, 3, 3, 0, 0, 0, 1]
# (0.13287951496928552, 0.06467076478390887) [0, 0, 3, 3, 0, 0, 3, 0]
# (0.1431031723737346, 0.08494696459692042) [0, 0, 3, 3, 0, 2, 0, 1]
# (0.14231450169957338, 0.12200788929762585) [0, 0, 3, 3, 1, 2, 1, 1]
# (0.1639146480620144, 0.11038746083511264) [0, 0, 3, 3, 2, 1, 0, 1]
# (0.17473749955478524, 0.06838390963918883) [0, 0, 3, 3, 3, 1, 0, 1]
# (0.18228414784182934, 0.08367675258994123) [0, 0, 3, 3, 3, 2, 1, 3]
# (0.27634282899904594, 0.012460977560251218) [0, 1, 0, 0, 0, 3, 2, 3]
# (0.2870222276565879, 0.032862614544237445) [0, 1, 0, 0, 2, 0, 0, 1]
# (0.3122489701608988, 0.056011960947909945) [0, 1, 0, 0, 2, 2, 2, 1]
# (0.2790914017949475, 0.0381414287427263) [0, 1, 0, 0, 3, 3, 1, 2]
# (0.263669351524475, 0.0936464493110648) [0, 1, 0, 1, 0, 3, 2, 2]
# (0.25922810725746803, 0.10616410759074957) [0, 1, 0, 1, 1, 0, 2, 3]
# (0.27922885325039304, 0.11719800121032065) [0, 1, 0, 1, 1, 2, 2, 3]
# (0.2951253447441622, 0.10973496198230337) [0, 1, 0, 1, 2, 1, 3, 1]
# (0.3110848937518983, 0.11040809468953328) [0, 1, 0, 1, 2, 2, 3, 1]
# (0.29807267818799366, 0.06976273901391816) [0, 1, 0, 1, 3, 1, 0, 1]
# (0.31402601562449173, 0.11009299586667254) [0, 1, 0, 2, 1, 1, 0, 0]
# (0.3402967807914413, 0.020723656258184064) [0, 1, 0, 3, 0, 2, 3, 2]
# (0.3587521099871608, 0.04511519780990392) [0, 1, 0, 3, 2, 0, 2, 2]
# (0.39265370755615403, 0.0255946515087494) [0, 1, 1, 0, 0, 2, 3, 0]
# (0.41491974753455485, 0.05197950669977147) [0, 1, 1, 0, 2, 1, 3, 3]
# (0.4296009393624731, 0.0492773510456308) [0, 1, 1, 0, 2, 2, 0, 1]
# (0.43196514584043455, 0.05225096266570417) [0, 1, 1, 0, 2, 2, 3, 3]
# (0.4313971806574647, 0.04287932831821406) [0, 1, 1, 0, 2, 3, 2, 0]
# (0.4532976690608763, 0.02209434741522498) [0, 1, 1, 1, 0, 2, 0, 3]
# (0.48643749031303707, 0.0163707395550009) [0, 1, 1, 1, 1, 2, 0, 0]
# (0.47000695492775846, 0.024443589214573125) [0, 1, 1, 1, 1, 3, 1, 0]
# (0.48024407673683667, 0.0385221034820914) [0, 1, 1, 1, 2, 0, 3, 3]
# (0.49406565029454685, 0.06213488865574179) [0, 1, 1, 1, 2, 2, 2, 3]
# (0.47682489258832184, 0.050464378333282656) [0, 1, 1, 1, 2, 3, 3, 0]
# (0.44056160623202356, 0.05333897420149614) [0, 1, 1, 1, 3, 1, 0, 3]
# (0.4475407926555893, 0.04744885661758791) [0, 1, 1, 1, 3, 1, 3, 0]
# (0.4635791902217741, 0.043473168799562645) [0, 1, 1, 1, 3, 3, 2, 3]
# (0.4662995427511274, 0.07787030897609648) [0, 1, 1, 2, 0, 3, 2, 2]
# (0.4934236024748091, 0.11410274512754093) [0, 1, 1, 2, 2, 2, 1, 3]
# (0.3844816132584641, 0.12359268304466609) [0, 1, 1, 3, 1, 1, 2, 1]
# (0.4151512373158217, 0.08233384194965598) [0, 1, 1, 3, 3, 3, 3, 3]
# (0.3848792689489319, 0.13804343313714418) [0, 1, 2, 0, 0, 0, 2, 1]
# (0.3885698122002108, 0.1582073897689149) [0, 1, 2, 0, 1, 0, 1, 1]
# (0.4224723047709966, 0.1725774643194018) [0, 1, 2, 0, 2, 2, 0, 0]
# (0.41985089115824237, 0.1464055830682266) [0, 1, 2, 0, 3, 3, 3, 2]
# (0.4440103798550441, 0.13989746854253926) [0, 1, 2, 1, 0, 0, 3, 2]
# (0.4593632467161891, 0.12571028230832926) [0, 1, 2, 1, 0, 3, 0, 3]
# (0.49504526322105635, 0.16474370880129918) [0, 1, 2, 1, 2, 1, 2, 0]
# (0.48476828653893156, 0.17179714151623116) [0, 1, 2, 1, 2, 1, 3, 1]
# (0.49170712203508404, 0.16997000040654098) [0, 1, 2, 1, 2, 1, 3, 2]
# (0.49593268741003027, 0.1783081772643248) [0, 1, 2, 1, 2, 2, 1, 3]
# (0.44112916603300556, 0.17450282893289826) [0, 1, 2, 1, 3, 1, 0, 0]
# (0.46279737322726877, 0.1832584957025919) [0, 1, 2, 1, 3, 2, 2, 0]
# (0.4452726158760514, 0.21297635415751737) [0, 1, 2, 2, 0, 1, 1, 3]
# (0.48865266585867095, 0.2012339176695468) [0, 1, 2, 2, 1, 1, 3, 2]
# (0.491765818984952, 0.24010597963926905) [0, 1, 2, 2, 2, 2, 0, 2]
# (0.37929086517084776, 0.24320586527950616) [0, 1, 2, 3, 1, 1, 1, 3]
# (0.3998867747705557, 0.24709106475901854) [0, 1, 2, 3, 1, 2, 2, 1]
# (0.4170458646970998, 0.24059101256460969) [0, 1, 2, 3, 2, 1, 3, 3]
# (0.41768036553854015, 0.18923113924938662) [0, 1, 2, 3, 3, 0, 3, 0]
# (0.2981303395407554, 0.1469876851717684) [0, 1, 3, 0, 1, 2, 0, 1]
# (0.30004561264890994, 0.16196312785876832) [0, 1, 3, 0, 2, 1, 0, 1]
# (0.2952155758378504, 0.1865379765911026) [0, 1, 3, 0, 2, 3, 2, 2]
# (0.26022528524819744, 0.1776383175136499) [0, 1, 3, 0, 3, 1, 3, 3]
# (0.2687570128708481, 0.18165210806982612) [0, 1, 3, 0, 3, 2, 1, 0]
# (0.2507817721335176, 0.23401129423785927) [0, 1, 3, 1, 1, 0, 3, 1]
# (0.25010900109532863, 0.23833663796741067) [0, 1, 3, 1, 1, 1, 0, 3]
# (0.3123388692291903, 0.22664840355318217) [0, 1, 3, 1, 2, 3, 2, 1]
# (0.3726090012445572, 0.21927822681374531) [0, 1, 3, 2, 2, 3, 1, 1]
# (0.320692133002934, 0.1548294908566309) [0, 1, 3, 3, 0, 1, 2, 1]
# (0.3315887585943663, 0.15382070876039944) [0, 1, 3, 3, 0, 2, 1, 1]
# (0.3505209819110954, 0.14392793558358696) [0, 1, 3, 3, 1, 3, 0, 1]
# (0.330842726726591, 0.17548238886310152) [0, 1, 3, 3, 3, 2, 0, 0]
# (0.26529131926544225, 0.27272326582122985) [0, 2, 0, 0, 0, 1, 3, 2]
# (0.28795120963025767, 0.25982620713510185) [0, 2, 0, 0, 1, 0, 1, 3]
# (0.31075006024002405, 0.2623600501213139) [0, 2, 0, 0, 1, 1, 2, 2]
# (0.2901870781955025, 0.26728624107981724) [0, 2, 0, 0, 1, 3, 3, 0]
# (0.2532459139852242, 0.3030645600586601) [0, 2, 0, 0, 3, 1, 0, 3]
# (0.2802768929075409, 0.32801939433968774) [0, 2, 0, 1, 0, 1, 2, 2]
# (0.2718755627674526, 0.3224354070908829) [0, 2, 0, 1, 0, 1, 3, 3]
# (0.27006226658496413, 0.34280548389660104) [0, 2, 0, 1, 0, 2, 3, 2]
# (0.26637912178270906, 0.3487309677000483) [0, 2, 0, 1, 1, 3, 0, 1]
# (0.29022419464506577, 0.3675950991116107) [0, 2, 0, 1, 2, 1, 2, 0]
# (0.3266509930231417, 0.35477561684837566) [0, 2, 0, 2, 1, 0, 2, 1]
# (0.31651773182621745, 0.358680678640791) [0, 2, 0, 2, 1, 0, 3, 2]
# (0.3201734661660397, 0.3532905069421852) [0, 2, 0, 2, 1, 0, 3, 3]
# (0.33899517088075226, 0.34957983870486375) [0, 2, 0, 2, 1, 3, 1, 3]
# (0.37237665096645045, 0.31591021771752814) [0, 2, 0, 2, 3, 1, 1, 1]
# (0.3641267044678269, 0.3348741606291157) [0, 2, 0, 2, 3, 2, 0, 2]
# (0.36112314848006344, 0.3363954191341749) [0, 2, 0, 2, 3, 2, 3, 0]
# (0.32166146354453373, 0.27945619456595217) [0, 2, 0, 3, 0, 1, 2, 1]
# (0.33538186150168836, 0.2703099847382978) [0, 2, 0, 3, 0, 2, 0, 2]
# (0.34528440647970704, 0.2956013525212807) [0, 2, 0, 3, 2, 0, 1, 1]
# (0.35823695460631677, 0.28623675969237894) [0, 2, 0, 3, 2, 0, 3, 2]
# (0.3612198990632144, 0.30940742834957435) [0, 2, 0, 3, 2, 2, 3, 1]
# (0.3257461025626943, 0.3048240652210459) [0, 2, 0, 3, 3, 1, 2, 3]
# (0.3401115241496241, 0.2947022373321725) [0, 2, 0, 3, 3, 3, 2, 2]
# (0.40579233424624117, 0.25635921559853225) [0, 2, 1, 0, 0, 1, 1, 2]
# (0.40492155200579927, 0.2913394832864419) [0, 2, 1, 0, 1, 3, 2, 1]
# (0.42499596476660273, 0.3122617797005155) [0, 2, 1, 0, 2, 2, 1, 1]
# (0.44348677234715883, 0.2587020940692203) [0, 2, 1, 1, 0, 0, 3, 3]
# (0.45569472510404807, 0.2645746244342734) [0, 2, 1, 1, 0, 3, 3, 1]
# (0.47373599236651043, 0.2961527533944547) [0, 2, 1, 1, 2, 0, 1, 2]
# (0.4879916765312926, 0.28862934662132067) [0, 2, 1, 1, 2, 1, 0, 1]
# (0.4951489077282848, 0.3009538732832232) [0, 2, 1, 1, 2, 2, 1, 3]
# (0.498810225096611, 0.30716041827243445) [0, 2, 1, 1, 2, 2, 2, 1]
# (0.47643206617120404, 0.3000675781730645) [0, 2, 1, 1, 2, 3, 0, 1]
# (0.480972361425122, 0.3235815900709982) [0, 2, 1, 2, 1, 0, 2, 3]
# (0.4945502055957973, 0.3345539702008772) [0, 2, 1, 2, 1, 2, 1, 3]
# (0.48695306396076354, 0.3372503771429475) [0, 2, 1, 2, 1, 2, 3, 0]
# (0.4703521667055498, 0.35029388750914503) [0, 2, 1, 2, 2, 0, 0, 3]
# (0.48124450045458433, 0.3472039248210027) [0, 2, 1, 2, 2, 0, 3, 1]
# (0.4966260589343845, 0.36223300455630536) [0, 2, 1, 2, 2, 2, 1, 1]
# (0.4349952218593879, 0.33882664458949274) [0, 2, 1, 3, 3, 2, 2, 1]
# (0.3981139844528476, 0.4129434115894012) [0, 2, 2, 0, 1, 3, 0, 2]
# (0.49300466993437586, 0.38102379160201705) [0, 2, 2, 1, 1, 1, 1, 3]
# (0.466335604806828, 0.4397588752375078) [0, 2, 2, 2, 0, 3, 1, 1]
# (0.3816327943638975, 0.4375529272904678) [0, 2, 2, 3, 0, 0, 0, 1]
# (0.37566904893461495, 0.45579813103790723) [0, 2, 2, 3, 0, 3, 0, 0]
# (0.26501613682441205, 0.38908253264156734) [0, 2, 3, 0, 0, 0, 2, 2]
# (0.25072397557702075, 0.40183178583699286) [0, 2, 3, 0, 0, 1, 1, 0]
# (0.3056095847979191, 0.3848432174829839) [0, 2, 3, 0, 1, 1, 2, 0]
# (0.3052623805609377, 0.4357415695622049) [0, 2, 3, 0, 2, 2, 2, 3]
# (0.28837982423884556, 0.4805608248622183) [0, 2, 3, 1, 2, 0, 3, 2]
# (0.30928669926853847, 0.4917691928164649) [0, 2, 3, 1, 2, 2, 3, 2]
# (0.3077855318595274, 0.44875413311542667) [0, 2, 3, 1, 3, 1, 2, 0]
# (0.298048921174185, 0.4544916329106764) [0, 2, 3, 1, 3, 2, 0, 0]
# (0.3308604707529116, 0.4604287505052401) [0, 2, 3, 2, 0, 2, 0, 1]
# (0.32487548253322795, 0.46130055558979677) [0, 2, 3, 2, 0, 3, 2, 3]
# (0.3727218102920773, 0.49863080409177696) [0, 2, 3, 2, 2, 2, 2, 2]
# (0.364145597375759, 0.461540375690758) [0, 2, 3, 2, 3, 2, 3, 3]
# (0.32062043544162455, 0.40486437180604873) [0, 2, 3, 3, 0, 1, 2, 1]
# (0.363697489269017, 0.3953926032562035) [0, 2, 3, 3, 1, 2, 0, 2]
# (0.36197548857662587, 0.40822767005372795) [0, 2, 3, 3, 2, 1, 0, 0]
# (0.3568418986798718, 0.43586706488562776) [0, 2, 3, 3, 2, 3, 2, 2]
# (0.015456378348361888, 0.25135262316334195) [0, 3, 0, 0, 0, 0, 3, 1]
# (0.009756817199470746, 0.2700475008689054) [0, 3, 0, 0, 0, 3, 3, 3]
# (0.00397301251124349, 0.29736617146681377) [0, 3, 0, 0, 1, 1, 0, 1]
# (0.0249519084795774, 0.3115260221714119) [0, 3, 0, 0, 1, 2, 2, 1]
# (0.08421444895432995, 0.31176194303199856) [0, 3, 0, 1, 3, 2, 1, 2]
# (0.07039124392116702, 0.3427592676524899) [0, 3, 0, 2, 0, 1, 2, 1]
# (0.1242444055199382, 0.3609926978328196) [0, 3, 0, 2, 2, 2, 1, 1]
# (0.0691061874041039, 0.3540603916473928) [0, 3, 0, 2, 3, 0, 3, 3]
# (0.08716406502666185, 0.3720988742203071) [0, 3, 0, 2, 3, 2, 2, 1]
# (0.010333413063762564, 0.35101356407633877) [0, 3, 0, 3, 1, 0, 1, 3]
# (0.01198169164566909, 0.35591578497529974) [0, 3, 0, 3, 1, 0, 2, 2]
# (0.047966673671569704, 0.3657825130853807) [0, 3, 0, 3, 2, 2, 0, 3]
# (0.04797775549776573, 0.3701015925583213) [0, 3, 0, 3, 2, 2, 1, 0]
# (0.009441701993618046, 0.3856517030844191) [0, 3, 1, 0, 0, 0, 2, 0]
# (0.010964259637993412, 0.388262583976716) [0, 3, 1, 0, 0, 0, 2, 3]
# (0.04383395004342594, 0.38139428190113067) [0, 3, 1, 0, 1, 0, 3, 2]
# (0.056912771363135106, 0.3980145394824125) [0, 3, 1, 0, 1, 2, 1, 3]
# (0.010802001579663711, 0.4122103091015923) [0, 3, 1, 0, 3, 0, 1, 3]
# (0.0184271144074607, 0.4074134249852114) [0, 3, 1, 0, 3, 3, 0, 0]
# (0.027418501500416137, 0.41804494309947604) [0, 3, 1, 0, 3, 3, 2, 2]
# (0.052175546278947604, 0.44281037896420516) [0, 3, 1, 1, 3, 1, 0, 2]
# (0.09804927814639852, 0.4445097520131194) [0, 3, 1, 2, 3, 0, 0, 2]
# (0.11292937836050554, 0.44800535716830914) [0, 3, 1, 2, 3, 1, 3, 0]
# (0.1097443565544648, 0.4626398402591455) [0, 3, 1, 2, 3, 2, 3, 0]
# (0.10534036778586664, 0.3954825944119561) [0, 3, 1, 3, 1, 3, 3, 3]
# (0.10341222480791556, 0.4342785277681691) [0, 3, 1, 3, 2, 3, 2, 1]
# (0.15080001673453491, 0.3959149230379133) [0, 3, 2, 0, 0, 2, 3, 3]
# (0.18656004613733246, 0.40023464529963804) [0, 3, 2, 0, 1, 2, 2, 1]
# (0.17644203576630513, 0.4277963083649352) [0, 3, 2, 0, 2, 2, 0, 2]
# (0.13687406056182372, 0.4484656527884895) [0, 3, 2, 1, 0, 0, 2, 3]
# (0.1768133954811485, 0.45720257541462683) [0, 3, 2, 1, 3, 2, 0, 2]
# (0.16194427325169236, 0.46421690347554) [0, 3, 2, 1, 3, 3, 1, 3]
# (0.20662105326839764, 0.4492610877223645) [0, 3, 2, 2, 0, 1, 3, 1]
# (0.20418927208432547, 0.49061821322379984) [0, 3, 2, 2, 1, 2, 0, 3]
# (0.22719179988613025, 0.3814536254083828) [0, 3, 2, 3, 1, 0, 3, 3]
# (0.23575274197159124, 0.38023468671836314) [0, 3, 2, 3, 1, 1, 0, 1]
# (0.21961053277691445, 0.39655614044020127) [0, 3, 2, 3, 1, 3, 0, 3]
# (0.23893838171377857, 0.41241218032274585) [0, 3, 2, 3, 2, 1, 0, 2]
# (0.23860603206728537, 0.43696056540245476) [0, 3, 2, 3, 2, 2, 3, 2]
# (0.21097285299226765, 0.4078532733988365) [0, 3, 2, 3, 3, 3, 1, 0]
# (0.13533180587876936, 0.2849900687182415) [0, 3, 3, 0, 1, 0, 1, 0]
# (0.1873076829301903, 0.26649653778413485) [0, 3, 3, 0, 3, 2, 1, 1]
# (0.1831375553093042, 0.27053001441957736) [0, 3, 3, 0, 3, 2, 1, 3]
# (0.20280117670249553, 0.2650533510753358) [0, 3, 3, 1, 0, 0, 2, 2]
# (0.19019099624048008, 0.2823464621767843) [0, 3, 3, 1, 3, 0, 0, 0]
# (0.21779157499307666, 0.2821374056571383) [0, 3, 3, 1, 3, 3, 1, 1]
# (0.20287592527201948, 0.32407168151066446) [0, 3, 3, 2, 0, 0, 2, 1]
# (0.23522607938449358, 0.3312262022666046) [0, 3, 3, 2, 1, 2, 0, 0]
# (0.2293085987474096, 0.35639093040813297) [0, 3, 3, 2, 2, 0, 2, 1]
# (0.21144024260263106, 0.3543125856836661) [0, 3, 3, 2, 3, 3, 2, 0]
# (0.13611767925577123, 0.344190599785567) [0, 3, 3, 3, 1, 0, 1, 0]
# (0.14800030507800366, 0.35575598691581833) [0, 3, 3, 3, 1, 3, 3, 2]
# (0.17330293660832252, 0.3489625556648248) [0, 3, 3, 3, 2, 3, 0, 1]
# (0.1747752624134168, 0.35339860793490907) [0, 3, 3, 3, 2, 3, 3, 0]
# (0.180923165561111, 0.31604752656377855) [0, 3, 3, 3, 3, 1, 1, 0]
# (0.042920965619438256, 0.5117020898931002) [1, 0, 0, 0, 1, 0, 2, 0]
# (0.044943673788580996, 0.5163801395011457) [1, 0, 0, 0, 1, 3, 3, 1]
# (0.03662398174026682, 0.5345071144056489) [1, 0, 0, 0, 2, 0, 0, 1]
# (0.0011092588874300757, 0.5450244426136949) [1, 0, 0, 0, 3, 0, 3, 1]
# (0.005814317724377127, 0.5619443433902876) [1, 0, 0, 0, 3, 1, 1, 2]
# (0.04912825330997139, 0.5838526398937558) [1, 0, 0, 1, 3, 2, 0, 1]
# (0.033838181409233004, 0.5869697478290203) [1, 0, 0, 1, 3, 3, 1, 0]
# (0.07592341993917973, 0.5928492040168116) [1, 0, 0, 2, 0, 3, 2, 2]
# (0.10222842553467393, 0.598494786453858) [1, 0, 0, 2, 2, 0, 1, 3]
# (0.10666714281177125, 0.6156790745182004) [1, 0, 0, 2, 2, 1, 3, 2]
# (0.11238451746721267, 0.6055483092324524) [1, 0, 0, 2, 2, 3, 3, 1]
# (0.1045203589409931, 0.5646539514575054) [1, 0, 0, 2, 3, 0, 3, 0]
# (0.10582521632569486, 0.562626093691908) [1, 0, 0, 2, 3, 0, 3, 1]
# (0.11364665317622302, 0.5721614177834798) [1, 0, 0, 2, 3, 1, 3, 3]
# (0.12218967730720665, 0.5782358141517331) [1, 0, 0, 2, 3, 2, 1, 1]
# (0.06770481976518439, 0.5182040315949152) [1, 0, 0, 3, 0, 1, 0, 1]
# (0.09391858072240655, 0.5344475897361904) [1, 0, 0, 3, 2, 0, 0, 0]
# (0.09025970345298218, 0.5566110660114582) [1, 0, 0, 3, 3, 2, 2, 3]
# (0.1377738551662363, 0.5334484104008858) [1, 0, 1, 0, 1, 0, 1, 1]
# (0.16942288051291232, 0.5319540031088283) [1, 0, 1, 0, 2, 0, 1, 1]
# (0.1747438106215946, 0.5239127077329012) [1, 0, 1, 0, 3, 2, 3, 0]
# (0.21646995844965577, 0.5271291925996137) [1, 0, 1, 1, 0, 2, 2, 3]
# (0.2442283583558723, 0.500684429092913) [1, 0, 1, 1, 1, 1, 1, 0]
# (0.2157827720078197, 0.5378648761641969) [1, 0, 1, 1, 3, 3, 1, 2]
# (0.19903942933701801, 0.569832655131575) [1, 0, 1, 2, 0, 0, 1, 3]
# (0.21178670606715755, 0.6142966777082378) [1, 0, 1, 2, 3, 2, 3, 3]
# (0.1773939545555333, 0.6047127391367402) [1, 0, 1, 3, 2, 3, 3, 3]
# (0.15052172493011107, 0.6398330463542515) [1, 0, 2, 0, 0, 1, 2, 3]
# (0.14377976198418263, 0.6328898160579606) [1, 0, 2, 0, 0, 1, 3, 0]
# (0.1474784856747685, 0.6410271897840842) [1, 0, 2, 0, 0, 2, 0, 3]
# (0.15571857497938546, 0.6740466693910598) [1, 0, 2, 0, 1, 2, 3, 1]
# (0.18539433051202703, 0.6650025722953148) [1, 0, 2, 0, 2, 3, 2, 1]
# (0.17800933762193072, 0.6697977903342296) [1, 0, 2, 0, 2, 3, 3, 2]
# (0.22990263104041608, 0.6666628329147479) [1, 0, 2, 1, 2, 0, 2, 0]
# (0.23713577700025557, 0.6580415386047428) [1, 0, 2, 1, 2, 1, 0, 0]
# (0.24826069587054445, 0.6626765496253492) [1, 0, 2, 1, 2, 1, 1, 2]
# (0.24360314399771554, 0.6868966084686486) [1, 0, 2, 1, 2, 2, 2, 3]
# (0.1988137431468454, 0.662724551834451) [1, 0, 2, 1, 3, 0, 1, 3]
# (0.21347141083119048, 0.6653503904166602) [1, 0, 2, 1, 3, 3, 2, 0]
# (0.21630933791117257, 0.6677762899291937) [1, 0, 2, 1, 3, 3, 2, 1]
# (0.19260071982447857, 0.6930363054603741) [1, 0, 2, 2, 0, 0, 0, 2]
# (0.23582638023529046, 0.7093739892675547) [1, 0, 2, 2, 1, 2, 0, 1]
# (0.22121460618640965, 0.7307089481236556) [1, 0, 2, 2, 2, 0, 1, 1]
# (0.2291359738646932, 0.7366159913767106) [1, 0, 2, 2, 2, 3, 3, 0]
# (0.21279966651637627, 0.7264055689981906) [1, 0, 2, 2, 3, 3, 1, 3]
# (0.16715489850294163, 0.7248636753929691) [1, 0, 2, 3, 2, 0, 1, 3]
# (0.17770807432397795, 0.7124227575896503) [1, 0, 2, 3, 3, 2, 3, 3]
# (0.009847527987822957, 0.6331424087671027) [1, 0, 3, 0, 0, 0, 2, 0]
# (0.061762470074094744, 0.6571415250837055) [1, 0, 3, 0, 2, 1, 1, 1]
# (0.06085065860054084, 0.6628789131944867) [1, 0, 3, 0, 2, 1, 1, 2]
# (0.047749474397292824, 0.6790174907592055) [1, 0, 3, 0, 2, 2, 0, 1]
# (0.005259279557619401, 0.65691079110906) [1, 0, 3, 0, 3, 0, 0, 3]
# (0.01536267171598904, 0.6721748245535286) [1, 0, 3, 0, 3, 1, 3, 1]
# (0.04102601721046617, 0.7263991365250507) [1, 0, 3, 1, 2, 0, 1, 3]
# (0.05447631409284437, 0.7130305585388054) [1, 0, 3, 1, 3, 2, 3, 3]
# (0.09964908231631009, 0.7287410517012698) [1, 0, 3, 2, 2, 0, 3, 3]
# (0.10403569318673644, 0.692032155957643) [1, 0, 3, 2, 3, 0, 3, 3]
# (0.06483707753802215, 0.655190209062211) [1, 0, 3, 3, 0, 1, 1, 1]
# (0.10191141227378431, 0.6843642526898446) [1, 0, 3, 3, 2, 3, 2, 1]
# (0.005030935827002314, 0.7541800826420685) [1, 1, 0, 0, 0, 0, 0, 2]
# (0.012488355450957722, 0.7967471078530959) [1, 1, 0, 0, 1, 0, 2, 2]
# (0.013248626770951177, 0.8011358908691344) [1, 1, 0, 0, 1, 1, 3, 2]
# (0.01765463398032463, 0.7965120078943833) [1, 1, 0, 0, 1, 3, 3, 1]
# (0.03683906016204952, 0.7762006976260433) [1, 1, 0, 0, 3, 3, 1, 3]
# (0.07191101913081688, 0.7702737434552951) [1, 1, 0, 1, 0, 1, 3, 3]
# (0.11260794080777325, 0.7516438917464912) [1, 1, 0, 1, 1, 1, 0, 0]
# (0.09548850000691733, 0.7766987130872405) [1, 1, 0, 1, 1, 3, 1, 0]
# (0.10055404595489636, 0.7860218499656157) [1, 1, 0, 1, 2, 0, 0, 2]
# (0.0771765110420124, 0.8239832576088818) [1, 1, 0, 2, 0, 0, 2, 1]
# (0.10402073465232342, 0.8173380576728297) [1, 1, 0, 2, 1, 0, 3, 3]
# (0.11176790125378144, 0.8391793104673514) [1, 1, 0, 2, 1, 2, 3, 0]
# (0.09656256073026737, 0.861114868635365) [1, 1, 0, 2, 2, 3, 0, 0]
# (0.0766815353712571, 0.8632935380600925) [1, 1, 0, 2, 3, 1, 3, 2]
# (0.00593087096806777, 0.8157819114065828) [1, 1, 0, 3, 0, 0, 0, 1]
# (0.011453524972204088, 0.8664487502922188) [1, 1, 0, 3, 1, 1, 3, 3]
# (0.02696497442577328, 0.8561024134327183) [1, 1, 0, 3, 1, 3, 2, 3]
# (0.04390445905579132, 0.8746714738259382) [1, 1, 0, 3, 2, 1, 2, 2]
# (0.034775345110169886, 0.829207110299169) [1, 1, 0, 3, 3, 3, 0, 0]
# (0.053075544664426655, 0.8946332489648319) [1, 1, 1, 0, 1, 2, 0, 2]
# (0.05520277905343007, 0.8982431794660056) [1, 1, 1, 0, 1, 2, 1, 3]
# (0.05477990998145443, 0.928813623189096) [1, 1, 1, 0, 2, 2, 1, 3]
# (0.031854392587689184, 0.9311747188863236) [1, 1, 1, 0, 2, 3, 1, 0]
# (0.007352907730378222, 0.9368868600546199) [1, 1, 1, 0, 3, 1, 1, 2]
# (0.023498790020233362, 0.9297191174812733) [1, 1, 1, 0, 3, 2, 2, 0]
# (0.019542508312777818, 0.9190631258684323) [1, 1, 1, 0, 3, 3, 3, 2]
# (0.011956512752120507, 0.9448821265916806) [1, 1, 1, 1, 0, 0, 3, 2]
# (0.02754802043090776, 0.9657157932225573) [1, 1, 1, 1, 0, 2, 2, 2]
# (0.0024441214715458237, 0.976105790120862) [1, 1, 1, 1, 1, 0, 0, 1]
# (0.02596268997398765, 0.9802917400642683) [1, 1, 1, 1, 1, 3, 2, 0]
# (0.05818785395221704, 0.94812517962672) [1, 1, 1, 1, 3, 1, 2, 0]
# (0.04536675138714774, 0.9618987106924046) [1, 1, 1, 1, 3, 3, 2, 3]
# (0.0761940988113593, 0.9668099737625786) [1, 1, 1, 2, 0, 3, 2, 2]
# (0.07526713678153141, 0.9948621005661158) [1, 1, 1, 2, 1, 1, 2, 3]
# (0.07823628949962891, 0.9863780783212671) [1, 1, 1, 2, 1, 2, 0, 0]
# (0.07602387867174554, 0.8845107750629303) [1, 1, 1, 3, 0, 0, 2, 1]
# (0.0794129480731749, 0.8994333912244935) [1, 1, 1, 3, 0, 2, 1, 0]
# (0.0830045668566437, 0.8800298649249685) [1, 1, 1, 3, 0, 3, 0, 2]
# (0.10341138312790554, 0.8884362951303146) [1, 1, 1, 3, 1, 0, 2, 1]
# (0.10865643401028247, 0.9306077599087864) [1, 1, 1, 3, 2, 3, 2, 3]
# (0.08026980312446574, 0.9081940386326315) [1, 1, 1, 3, 3, 3, 0, 0]
# (0.1255156196996301, 0.8781489477944195) [1, 1, 2, 0, 0, 0, 0, 0]
# (0.1345084437375057, 0.8796426818886455) [1, 1, 2, 0, 0, 0, 1, 3]
# (0.139569474675863, 0.9060747113119758) [1, 1, 2, 0, 0, 1, 2, 2]
# (0.18509594153816422, 0.8917136358745734) [1, 1, 2, 0, 1, 2, 1, 1]
# (0.16574573965677952, 0.9292980533254503) [1, 1, 2, 0, 2, 3, 3, 3]
# (0.1414069498738766, 0.9220336047030565) [1, 1, 2, 0, 3, 2, 0, 0]
# (0.15132273462123857, 0.9071757321675175) [1, 1, 2, 0, 3, 3, 1, 0]
# (0.1447997971423588, 0.953924335091804) [1, 1, 2, 1, 0, 2, 0, 3]
# (0.15038172466555622, 0.9945533196181078) [1, 1, 2, 1, 1, 2, 2, 0]
# (0.20397354787463962, 0.9995748527005147) [1, 1, 2, 2, 1, 2, 1, 1]
# (0.20569494576344893, 0.877299913236456) [1, 1, 2, 3, 0, 3, 0, 0]
# (0.23505600549640504, 0.9361211348054557) [1, 1, 2, 3, 2, 2, 3, 1]
# (0.16855292004276656, 0.7964706855922898) [1, 1, 3, 0, 2, 0, 2, 2]
# (0.22837737492878263, 0.7871792825585885) [1, 1, 3, 1, 2, 0, 3, 3]
# (0.20754135571114718, 0.787335219478398) [1, 1, 3, 1, 3, 3, 0, 2]
# (0.19949375975751826, 0.8261222007303899) [1, 1, 3, 2, 0, 0, 2, 2]
# (0.1918483935664712, 0.8342649854627395) [1, 1, 3, 2, 0, 1, 0, 2]
# (0.19911057667237586, 0.841350599933357) [1, 1, 3, 2, 0, 1, 2, 1]
# (0.2142755311241118, 0.8378253072193409) [1, 1, 3, 2, 0, 2, 2, 0]
# (0.2026584675478429, 0.8527961162818064) [1, 1, 3, 2, 3, 0, 2, 1]
# (0.18933457203382387, 0.8728376354441764) [1, 1, 3, 2, 3, 1, 1, 1]
# (0.17716097913833972, 0.8130835648900816) [1, 1, 3, 3, 3, 1, 0, 3]
# (0.18183285164375051, 0.8167035485737895) [1, 1, 3, 3, 3, 1, 1, 3]
# (0.16004356566998668, 0.8332508644242812) [1, 1, 3, 3, 3, 3, 0, 3]
# (0.2655922831813782, 0.7697974972287535) [1, 2, 0, 0, 0, 3, 3, 2]
# (0.292888766700242, 0.8069565260005948) [1, 2, 0, 0, 2, 1, 2, 0]
# (0.29545695717662646, 0.7609274673925585) [1, 2, 0, 0, 3, 0, 2, 3]
# (0.32133794378046954, 0.7579654480936908) [1, 2, 0, 1, 0, 0, 2, 0]
# (0.320737471152612, 0.7703530587927404) [1, 2, 0, 1, 0, 1, 3, 3]
# (0.3319371592084168, 0.7571072811628631) [1, 2, 0, 1, 0, 3, 0, 1]
# (0.3352755601102748, 0.8102382040549293) [1, 2, 0, 1, 3, 2, 1, 2]
# (0.26767273524445223, 0.8156651433357442) [1, 2, 0, 3, 0, 1, 0, 0]
# (0.296646968349922, 0.8547640754226478) [1, 2, 0, 3, 2, 0, 2, 1]
# (0.26625378910186526, 0.8824733911192285) [1, 2, 1, 0, 0, 3, 0, 1]
# (0.3102129334057858, 0.9088885048454095) [1, 2, 1, 0, 2, 1, 1, 1]
# (0.3044925770614223, 0.9283716496607559) [1, 2, 1, 0, 2, 2, 0, 2]
# (0.26973156135469123, 0.9150940648468056) [1, 2, 1, 0, 3, 3, 3, 3]
# (0.27989709748480995, 0.9458689947426517) [1, 2, 1, 1, 0, 1, 2, 1]
# (0.27393548965211956, 0.9761485293572538) [1, 2, 1, 1, 1, 3, 1, 3]
# (0.29393469828216323, 0.9749501386946218) [1, 2, 1, 1, 2, 0, 1, 2]
# (0.30527445699181843, 0.9816870946819277) [1, 2, 1, 1, 2, 3, 2, 3]
# (0.333023186501644, 0.9450672870589051) [1, 2, 1, 2, 0, 1, 0, 2]
# (0.3433985172957166, 0.9692511362395575) [1, 2, 1, 2, 1, 3, 1, 1]
# (0.3737241773178307, 0.9780723443069224) [1, 2, 1, 2, 2, 3, 2, 1]
# (0.3667315465263761, 0.9539030416265021) [1, 2, 1, 2, 3, 2, 0, 3]
# (0.3645411315043886, 0.9621297160731604) [1, 2, 1, 2, 3, 2, 3, 3]
# (0.3225627099237568, 0.8870516080680745) [1, 2, 1, 3, 0, 0, 2, 3]
# (0.3261899181788115, 0.8912159305282591) [1, 2, 1, 3, 0, 1, 3, 1]
# (0.3650777922721903, 0.9179903493281218) [1, 2, 1, 3, 2, 1, 3, 2]
# (0.4059410570646733, 0.8849928927556249) [1, 2, 2, 0, 0, 3, 2, 1]
# (0.42312424003847726, 0.8790360584558635) [1, 2, 2, 0, 1, 1, 0, 1]
# (0.4310967255394489, 0.9285548302162737) [1, 2, 2, 0, 2, 2, 1, 3]
# (0.41221666508269184, 0.9242562123517493) [1, 2, 2, 0, 2, 3, 0, 1]
# (0.37567310647050844, 0.9069879854228402) [1, 2, 2, 0, 3, 0, 0, 0]
# (0.396307402908063, 0.961592033594942) [1, 2, 2, 1, 0, 2, 3, 3]
# (0.39205862524776924, 0.9861211043450996) [1, 2, 2, 1, 1, 2, 0, 0]
# (0.4159233984970846, 0.9784512648585253) [1, 2, 2, 1, 2, 0, 2, 0]
# (0.4074870022381498, 0.9770079816325778) [1, 2, 2, 1, 2, 0, 3, 0]
# (0.41228476850472995, 0.9774087601835743) [1, 2, 2, 1, 2, 0, 3, 3]
# (0.43302897967766363, 0.9894447723048608) [1, 2, 2, 1, 2, 2, 3, 3]
# (0.4227332426318088, 0.941092977556344) [1, 2, 2, 1, 3, 1, 0, 0]
# (0.42310841890266726, 0.9528106017698027) [1, 2, 2, 1, 3, 1, 3, 1]
# (0.4525997366228517, 0.9686436667310736) [1, 2, 2, 2, 0, 3, 2, 2]
# (0.4691019012331603, 0.9526445701551534) [1, 2, 2, 2, 3, 0, 1, 1]
# (0.4886291157606012, 0.9637788816251143) [1, 2, 2, 2, 3, 2, 3, 3]
# (0.47411267086520736, 0.8810266162724855) [1, 2, 2, 3, 1, 0, 0, 2]
# (0.49589223224456735, 0.8851936707989587) [1, 2, 2, 3, 1, 1, 2, 0]
# (0.4921773442405917, 0.8962967893538277) [1, 2, 2, 3, 1, 2, 0, 2]
# (0.4662906799844383, 0.9138563885416036) [1, 2, 2, 3, 3, 3, 1, 2]
# (0.38918726612397514, 0.7646205742994671) [1, 2, 3, 0, 0, 0, 2, 2]
# (0.39573331179782856, 0.8005625913233388) [1, 2, 3, 0, 1, 2, 0, 1]
# (0.39226229188170914, 0.8041230861462738) [1, 2, 3, 0, 1, 2, 0, 3]
# (0.420890535132602, 0.7941565851124923) [1, 2, 3, 0, 2, 0, 2, 2]
# (0.46114706015161633, 0.7580828186341905) [1, 2, 3, 1, 0, 3, 2, 0]
# (0.4379915348694946, 0.7835756819959163) [1, 2, 3, 1, 3, 0, 0, 0]
# (0.4406309015698856, 0.7984441307340563) [1, 2, 3, 1, 3, 1, 0, 0]
# (0.4535598614927282, 0.8062206563819684) [1, 2, 3, 1, 3, 2, 1, 0]
# (0.44086456904964233, 0.8224894568635575) [1, 2, 3, 2, 0, 0, 3, 0]
# (0.44676583132909364, 0.853100680678753) [1, 2, 3, 2, 3, 0, 2, 0]
# (0.4598551713540169, 0.8449347845781308) [1, 2, 3, 2, 3, 3, 0, 3]
# (0.38316237062852854, 0.8374212261309046) [1, 2, 3, 3, 0, 3, 2, 0]
# (0.3809501012267813, 0.8622884775201447) [1, 2, 3, 3, 1, 1, 0, 1]
# (0.3909732314018768, 0.8566709208217016) [1, 2, 3, 3, 1, 3, 3, 1]
# (0.4324858378901555, 0.8445857845456971) [1, 2, 3, 3, 2, 3, 1, 0]
# (0.4083558661035176, 0.8143381869272229) [1, 2, 3, 3, 3, 0, 0, 0]
# (0.2800225355593514, 0.5046239223986302) [1, 3, 0, 0, 0, 3, 1, 2]
# (0.3032865970641696, 0.516587829269827) [1, 3, 0, 0, 1, 2, 0, 3]
# (0.28219236975894446, 0.5485039291223838) [1, 3, 0, 0, 2, 3, 0, 0]
# (0.28393710317541887, 0.5577233297241984) [1, 3, 0, 0, 2, 3, 1, 0]
# (0.2502225539152979, 0.557074286980146) [1, 3, 0, 0, 3, 1, 1, 0]
# (0.26855777072846065, 0.5538562708323184) [1, 3, 0, 0, 3, 2, 0, 3]
# (0.2801299924080386, 0.5580380195696482) [1, 3, 0, 0, 3, 2, 2, 3]
# (0.2610970797441561, 0.5791851448051564) [1, 3, 0, 1, 0, 3, 3, 0]
# (0.29939535306315634, 0.5878909391598331) [1, 3, 0, 1, 3, 2, 3, 0]
# (0.32244782677529227, 0.5672039775897089) [1, 3, 0, 2, 0, 0, 3, 3]
# (0.31761222493175656, 0.6038502115763607) [1, 3, 0, 2, 1, 0, 3, 3]
# (0.3701974002550704, 0.564629130378233) [1, 3, 0, 2, 3, 1, 1, 0]
# (0.3451562513353824, 0.5306297090265013) [1, 3, 0, 3, 1, 3, 1, 1]
# (0.34438715437583867, 0.5388537119519476) [1, 3, 0, 3, 2, 0, 0, 3]
# (0.35494342202757256, 0.5394447696472041) [1, 3, 0, 3, 2, 0, 2, 0]
# (0.36671343814969515, 0.561109130299519) [1, 3, 0, 3, 2, 2, 3, 2]
# (0.32310786100861333, 0.5434377590276362) [1, 3, 0, 3, 3, 0, 2, 3]
# (0.33671896115961397, 0.560350431636834) [1, 3, 0, 3, 3, 2, 2, 1]
# (0.3378837733702593, 0.5502407611882542) [1, 3, 0, 3, 3, 2, 3, 0]
# (0.3892298807479091, 0.5144670328906785) [1, 3, 1, 0, 0, 0, 2, 2]
# (0.3840165386363371, 0.5005385291610682) [1, 3, 1, 0, 0, 0, 3, 0]
# (0.39580133694768693, 0.515908646955053) [1, 3, 1, 0, 0, 2, 0, 3]
# (0.39195758259997127, 0.5323512358140805) [1, 3, 1, 0, 1, 3, 0, 0]
# (0.4131363866267458, 0.5135894490494155) [1, 3, 1, 0, 3, 0, 1, 2]
# (0.41520865986700817, 0.5282845673505083) [1, 3, 1, 0, 3, 3, 2, 1]
# (0.493582819502309, 0.5195731653739368) [1, 3, 1, 1, 1, 2, 1, 3]
# (0.44489352125832515, 0.548074829291685) [1, 3, 1, 1, 3, 1, 0, 1]
# (0.47920663401708274, 0.5675543618084408) [1, 3, 1, 2, 1, 0, 3, 3]
# (0.4940071282892018, 0.571894502412457) [1, 3, 1, 2, 1, 1, 2, 0]
# (0.4493449232217207, 0.6101052915072644) [1, 3, 1, 2, 3, 1, 3, 1]
# (0.4142379310707971, 0.5944413201404183) [1, 3, 1, 3, 2, 0, 1, 0]
# (0.4089866404476562, 0.6076938008720089) [1, 3, 1, 3, 2, 0, 3, 1]
# (0.4065705979338998, 0.5659054037363117) [1, 3, 1, 3, 3, 0, 0, 0]
# (0.4305874803285731, 0.5854131121106957) [1, 3, 1, 3, 3, 2, 1, 3]
# (0.40405289387674437, 0.6453736408394393) [1, 3, 2, 0, 0, 2, 1, 2]
# (0.44102316987879586, 0.6333868431792058) [1, 3, 2, 1, 0, 0, 3, 0]
# (0.4613570464279727, 0.6446097078991823) [1, 3, 2, 1, 0, 2, 3, 3]
# (0.4600312709348069, 0.6404275690958525) [1, 3, 2, 1, 0, 3, 3, 2]
# (0.49567832145815616, 0.6341738358783167) [1, 3, 2, 1, 1, 1, 2, 0]
# (0.4499749145366204, 0.6830733405833561) [1, 3, 2, 1, 3, 1, 2, 3]
# (0.4686250378257073, 0.6716775883298768) [1, 3, 2, 1, 3, 3, 2, 2]
# (0.45622068867115906, 0.7385890841858705) [1, 3, 2, 2, 3, 2, 0, 3]
# (0.4657868053674492, 0.7449042160557771) [1, 3, 2, 2, 3, 2, 2, 3]
# (0.40056810029535217, 0.7012964059901418) [1, 3, 2, 3, 0, 1, 2, 3]
# (0.4176390963334342, 0.7334397924834634) [1, 3, 2, 3, 2, 0, 2, 3]
# (0.26638171376780273, 0.6558969485365165) [1, 3, 3, 0, 0, 2, 1, 1]
# (0.27585465817915034, 0.6447268539805838) [1, 3, 3, 0, 0, 2, 3, 3]
# (0.280125375348685, 0.6263998819599549) [1, 3, 3, 0, 0, 3, 1, 1]
# (0.2974086528309504, 0.6616215891063352) [1, 3, 3, 0, 2, 1, 0, 1]
# (0.277322886865904, 0.6762488447980268) [1, 3, 3, 0, 3, 2, 3, 3]
# (0.2658248269383109, 0.7494110343629212) [1, 3, 3, 1, 1, 2, 1, 1]
# (0.26659958349142565, 0.7295038667752556) [1, 3, 3, 1, 1, 3, 3, 0]
# (0.3139981652338236, 0.7021799426490024) [1, 3, 3, 2, 0, 0, 1, 1]
# (0.31489676610094053, 0.7038990710966108) [1, 3, 3, 2, 0, 3, 0, 0]
# (0.34192868371027585, 0.7223763507770957) [1, 3, 3, 2, 1, 3, 1, 1]
# (0.36657436577595137, 0.6994488647123612) [1, 3, 3, 2, 3, 1, 3, 2]
# (0.3686055961719561, 0.6414008936982394) [1, 3, 3, 3, 1, 2, 1, 0]
# (0.3465962265278737, 0.6514637037089861) [1, 3, 3, 3, 1, 3, 1, 0]
# (0.35479003836763545, 0.6771636579053087) [1, 3, 3, 3, 2, 3, 3, 3]
# (0.3410353476683492, 0.662910959672184) [1, 3, 3, 3, 3, 3, 1, 2]
# (0.5429455158299279, 0.5146533034159335) [2, 0, 0, 0, 1, 0, 2, 1]
# (0.5524606401234164, 0.5004114168409485) [2, 0, 0, 0, 1, 1, 0, 3]
# (0.5429823824087617, 0.5258515769348363) [2, 0, 0, 0, 1, 3, 2, 3]
# (0.5367017732037992, 0.54336499508041) [2, 0, 0, 0, 2, 0, 1, 2]
# (0.5572608907843511, 0.5554100679956647) [2, 0, 0, 0, 2, 2, 2, 0]
# (0.5442951370318487, 0.5996909112085951) [2, 0, 0, 1, 2, 0, 1, 2]
# (0.5707598368829206, 0.5707563386039095) [2, 0, 0, 2, 0, 0, 2, 0]
# (0.5756215575785794, 0.5809546037562051) [2, 0, 0, 2, 0, 3, 3, 1]
# (0.5927544860223025, 0.5951742595977341) [2, 0, 0, 2, 1, 3, 1, 1]
# (0.6088204046773555, 0.6236458255027603) [2, 0, 0, 2, 2, 1, 2, 2]
# (0.618855445989807, 0.6148162141721227) [2, 0, 0, 2, 2, 2, 3, 3]
# (0.619583621587099, 0.5985739743976739) [2, 0, 0, 2, 2, 3, 1, 3]
# (0.6069593889382221, 0.5896628503726179) [2, 0, 0, 2, 3, 3, 2, 3]
# (0.5817821129963511, 0.5199884813490503) [2, 0, 0, 3, 0, 2, 0, 3]
# (0.6210917623869097, 0.5169654147184297) [2, 0, 0, 3, 1, 2, 1, 0]
# (0.611205645418391, 0.5288798608210519) [2, 0, 0, 3, 1, 2, 3, 1]
# (0.5952229679782071, 0.5357361053309503) [2, 0, 0, 3, 2, 0, 0, 3]
# (0.6166111408659616, 0.5335072521354624) [2, 0, 0, 3, 2, 1, 0, 3]
# (0.5713862827711975, 0.5405967645054365) [2, 0, 0, 3, 3, 0, 2, 0]
# (0.6547791629329971, 0.5062367521153535) [2, 0, 1, 0, 0, 1, 1, 2]
# (0.6680454704802758, 0.5127190471054139) [2, 0, 1, 0, 3, 0, 2, 2]
# (0.6838707467819131, 0.5057183690816627) [2, 0, 1, 0, 3, 1, 1, 2]
# (0.7493092437943715, 0.5165340670258313) [2, 0, 1, 1, 1, 2, 1, 1]
# (0.7225188971352916, 0.518555852299382) [2, 0, 1, 1, 1, 3, 0, 0]
# (0.737982406290478, 0.5364574195012024) [2, 0, 1, 1, 2, 1, 0, 1]
# (0.7256845164986865, 0.5799199106932724) [2, 0, 1, 2, 1, 3, 0, 1]
# (0.740207324479384, 0.6170232832998864) [2, 0, 1, 2, 2, 2, 0, 2]
# (0.7085077265008654, 0.6172433624984773) [2, 0, 1, 2, 3, 2, 1, 3]
# (0.6424398424691674, 0.5818460220130179) [2, 0, 1, 3, 0, 2, 0, 0]
# (0.6263821184663699, 0.5888895954695398) [2, 0, 1, 3, 0, 3, 1, 0]
# (0.6610761048410795, 0.6066851342000356) [2, 0, 1, 3, 2, 0, 3, 2]
# (0.6510217581254251, 0.6308429493756497) [2, 0, 2, 0, 0, 1, 1, 3]
# (0.6436250412050493, 0.64868284010677) [2, 0, 2, 0, 0, 2, 3, 0]
# (0.7213410800690897, 0.6373580900888289) [2, 0, 2, 1, 1, 0, 1, 1]
# (0.7440336589807783, 0.6655436066532917) [2, 0, 2, 1, 2, 1, 2, 0]
# (0.7001954133961998, 0.7392036639281993) [2, 0, 2, 2, 3, 1, 3, 2]
# (0.716650459698317, 0.7425325238666608) [2, 0, 2, 2, 3, 2, 2, 3]
# (0.6375914866272098, 0.7427406568905841) [2, 0, 2, 3, 1, 1, 2, 3]
# (0.666587653176086, 0.6903934561150802) [2, 0, 2, 3, 3, 0, 3, 0]
# (0.5530874734466402, 0.6622470480361872) [2, 0, 3, 0, 2, 1, 0, 2]
# (0.5220372863017823, 0.7074738846556335) [2, 0, 3, 1, 0, 2, 0, 2]
# (0.5067880421871809, 0.746938050975368) [2, 0, 3, 1, 1, 1, 1, 2]
# (0.5580010546733938, 0.7292800031835497) [2, 0, 3, 1, 2, 3, 2, 0]
# (0.5439759578179028, 0.7054435156352865) [2, 0, 3, 1, 3, 3, 3, 1]
# (0.546219839842691, 0.7050965203144356) [2, 0, 3, 1, 3, 3, 3, 1]
# (0.5628970086074838, 0.6988179674101245) [2, 0, 3, 2, 0, 0, 1, 0]
# (0.5665037506132862, 0.7190383858831642) [2, 0, 3, 2, 1, 0, 0, 3]
# (0.5981259806400089, 0.7369226623516442) [2, 0, 3, 2, 2, 1, 0, 1]
# (0.6046419011589406, 0.7015112114182591) [2, 0, 3, 2, 3, 0, 2, 1]
# (0.5735062125223046, 0.6401861175509284) [2, 0, 3, 3, 0, 0, 2, 3]
# (0.6025785891448621, 0.6361916487367264) [2, 0, 3, 3, 1, 0, 2, 0]
# (0.5240994133620538, 0.753235149302808) [2, 1, 0, 0, 0, 1, 1, 0]
# (0.5563079013356099, 0.7640525086120195) [2, 1, 0, 0, 3, 1, 2, 3]
# (0.5318799210302115, 0.7741156201737169) [2, 1, 0, 0, 3, 3, 1, 0]
# (0.604541054985954, 0.7779125726915957) [2, 1, 0, 1, 1, 3, 2, 1]
# (0.6076527424292629, 0.7714703144965466) [2, 1, 0, 1, 1, 3, 3, 2]
# (0.6076151729167755, 0.7819661767693539) [2, 1, 0, 1, 2, 0, 3, 1]
# (0.60185684962048, 0.7863623880837745) [2, 1, 0, 1, 2, 0, 3, 3]
# (0.6120524702427277, 0.8740656689942881) [2, 1, 0, 2, 2, 2, 3, 1]
# (0.6083224023861953, 0.861164458875994) [2, 1, 0, 2, 2, 3, 3, 1]
# (0.5312447163091165, 0.8177326241442763) [2, 1, 0, 3, 0, 1, 1, 2]
# (0.5064052114332247, 0.8556947885015533) [2, 1, 0, 3, 1, 0, 3, 2]
# (0.5572659858123226, 0.8688114903422615) [2, 1, 0, 3, 2, 2, 2, 0]
# (0.5579579194983654, 0.8206173882889708) [2, 1, 0, 3, 3, 1, 2, 0]
# (0.5080913013564529, 0.9030161120794691) [2, 1, 1, 0, 0, 1, 2, 1]
# (0.527711976118668, 0.883295429157258) [2, 1, 1, 0, 0, 3, 2, 1]
# (0.5543139302941434, 0.8878199619828738) [2, 1, 1, 0, 1, 1, 3, 2]
# (0.5119910032005983, 0.9191076061498874) [2, 1, 1, 0, 3, 0, 2, 2]
# (0.5099922242838159, 0.92869502204187) [2, 1, 1, 0, 3, 1, 3, 3]
# (0.5141467136747521, 0.9520426137937276) [2, 1, 1, 1, 0, 0, 2, 2]
# (0.5177399597059277, 0.942982025701587) [2, 1, 1, 1, 0, 1, 0, 1]
# (0.5094817012220589, 0.9844020596339955) [2, 1, 1, 1, 1, 1, 3, 0]
# (0.5303326500365086, 0.9727718565229193) [2, 1, 1, 1, 1, 3, 1, 2]
# (0.5437156375101084, 0.9828753138416032) [2, 1, 1, 1, 2, 0, 2, 2]
# (0.5846604780281613, 0.9534197508175161) [2, 1, 1, 2, 0, 2, 0, 3]
# (0.5846495797986015, 0.9968966352641635) [2, 1, 1, 2, 1, 2, 1, 2]
# (0.6079154462489954, 0.9820730237961638) [2, 1, 1, 2, 2, 0, 2, 2]
# (0.614639670837234, 0.9764340877679717) [2, 1, 1, 2, 2, 3, 0, 2]
# (0.5860892218082702, 0.8782373075544189) [2, 1, 1, 3, 0, 3, 1, 0]
# (0.6236627397590127, 0.8783235844307786) [2, 1, 1, 3, 1, 1, 1, 1]
# (0.6094389585815712, 0.8837144626358835) [2, 1, 1, 3, 1, 1, 3, 0]
# (0.6794469705732294, 0.9010874180410421) [2, 1, 2, 0, 1, 2, 3, 3]
# (0.6685845865756722, 0.8921572906703795) [2, 1, 2, 0, 1, 3, 3, 1]
# (0.6747804800254384, 0.9154440758713545) [2, 1, 2, 0, 2, 1, 3, 0]
# (0.6652012600302215, 0.9319726353422129) [2, 1, 2, 0, 2, 3, 2, 0]
# (0.6379217758148911, 0.9519639254983243) [2, 1, 2, 1, 0, 0, 2, 2]
# (0.6823527148111551, 0.9387306702709041) [2, 1, 2, 1, 3, 1, 1, 0]
# (0.6601891081855394, 0.9670396614994262) [2, 1, 2, 1, 3, 3, 1, 2]
# (0.6698505472140045, 0.9682862405827094) [2, 1, 2, 1, 3, 3, 2, 2]
# (0.7071274177428347, 0.9394105965869324) [2, 1, 2, 2, 0, 1, 0, 3]
# (0.7103388521607545, 0.9589867003574789) [2, 1, 2, 2, 0, 2, 0, 2]
# (0.6910855259913347, 0.9579524873522302) [2, 1, 2, 2, 0, 3, 0, 3]
# (0.6969746894279584, 0.9998241432370997) [2, 1, 2, 2, 1, 1, 2, 1]
# (0.7085591348453468, 0.9832077967547648) [2, 1, 2, 2, 1, 3, 3, 2]
# (0.7276512145544416, 0.9761065058642847) [2, 1, 2, 2, 2, 0, 1, 3]
# (0.7455036246086949, 0.9588603148998077) [2, 1, 2, 2, 3, 2, 1, 3]
# (0.7469918496415928, 0.8758079071569272) [2, 1, 2, 3, 1, 1, 1, 1]
# (0.7443198518872234, 0.8951551531533967) [2, 1, 2, 3, 1, 2, 1, 3]
# (0.7239817874034791, 0.9140252508201477) [2, 1, 2, 3, 2, 0, 0, 2]
# (0.6452247208678765, 0.7763436329909755) [2, 1, 3, 0, 0, 2, 3, 3]
# (0.6281442071384282, 0.7834157407198383) [2, 1, 3, 0, 1, 0, 0, 0]
# (0.6292458124938499, 0.8099412728587103) [2, 1, 3, 0, 1, 1, 1, 2]
# (0.6592814816878219, 0.7501305323061255) [2, 1, 3, 0, 3, 0, 0, 0]
# (0.6960025868627561, 0.754533552273596) [2, 1, 3, 1, 0, 0, 1, 3]
# (0.7070198992206683, 0.7665733328057359) [2, 1, 3, 1, 0, 2, 0, 0]
# (0.7419381952898745, 0.7782580075851702) [2, 1, 3, 1, 1, 2, 3, 2]
# (0.7220001983883987, 0.7816154389863763) [2, 1, 3, 1, 2, 0, 0, 0]
# (0.6918999625135455, 0.8071464851306869) [2, 1, 3, 1, 3, 1, 1, 3]
# (0.7062814795777491, 0.8116357906228369) [2, 1, 3, 1, 3, 2, 1, 1]
# (0.7117670403071766, 0.784039614194323) [2, 1, 3, 1, 3, 3, 1, 0]
# (0.7412974149393141, 0.8254309622517759) [2, 1, 3, 2, 1, 1, 3, 2]
# (0.6982635457072186, 0.8469413585261729) [2, 1, 3, 2, 3, 0, 1, 0]
# (0.6848045410308821, 0.871181374404691) [2, 1, 3, 3, 2, 2, 2, 2]
# (0.6601335186834061, 0.8423806837095157) [2, 1, 3, 3, 3, 3, 1, 1]
# (0.6709136579681778, 0.8300873286959466) [2, 1, 3, 3, 3, 3, 3, 1]
# (0.7665995900429814, 0.7509280121496579) [2, 2, 0, 0, 0, 1, 0, 0]
# (0.7539979569280896, 0.7760924861560986) [2, 2, 0, 0, 0, 3, 1, 3]
# (0.8587306123321968, 0.7738133323175735) [2, 2, 0, 1, 1, 3, 2, 3]
# (0.845665724788325, 0.7843801719938825) [2, 2, 0, 1, 2, 0, 0, 0]
# (0.8454507459669676, 0.7916993960206591) [2, 2, 0, 1, 2, 0, 1, 0]
# (0.8411934956544722, 0.7927865862899828) [2, 2, 0, 1, 3, 3, 2, 1]
# (0.8536682087462749, 0.8175592623300331) [2, 2, 0, 2, 1, 0, 3, 3]
# (0.859968465553932, 0.8146788267619205) [2, 2, 0, 2, 1, 1, 0, 0]
# (0.8303177613082932, 0.8660475551456233) [2, 2, 0, 2, 3, 2, 0, 3]
# (0.7708164695098593, 0.8714786222315287) [2, 2, 0, 3, 1, 2, 1, 2]
# (0.7866195688931201, 0.8663878661367911) [2, 2, 0, 3, 2, 1, 0, 2]
# (0.8054445528780168, 0.829443446739387) [2, 2, 0, 3, 3, 2, 1, 0]
# (0.7590327850794315, 0.8754637527006458) [2, 2, 1, 0, 0, 0, 1, 0]
# (0.7911727168325327, 0.9128122242137581) [2, 2, 1, 0, 2, 0, 3, 3]
# (0.8118802554289732, 0.9140074996473811) [2, 2, 1, 0, 2, 1, 1, 2]
# (0.7858410067495184, 0.9355185784385013) [2, 2, 1, 0, 2, 3, 1, 2]
# (0.7566048338289754, 0.9187747804819166) [2, 2, 1, 0, 3, 0, 3, 2]
# (0.7645757937317865, 0.921937970786872) [2, 2, 1, 0, 3, 1, 3, 1]
# (0.7772183176039561, 0.9287177829893328) [2, 2, 1, 0, 3, 2, 3, 3]
# (0.7595721677874467, 0.9652121503205845) [2, 2, 1, 1, 0, 3, 2, 1]
# (0.7585091655452586, 0.9765118157235863) [2, 2, 1, 1, 1, 0, 1, 3]
# (0.7577597333964063, 0.9845746291605199) [2, 2, 1, 1, 1, 1, 0, 1]
# (0.8248811239396769, 0.9449416829627642) [2, 2, 1, 2, 0, 0, 3, 2]
# (0.8151412966147581, 0.9946956040669533) [2, 2, 1, 2, 1, 1, 1, 0]
# (0.8629626022042027, 0.9933667057552911) [2, 2, 1, 2, 2, 2, 1, 0]
# (0.8680892301100923, 0.9599215792376729) [2, 2, 1, 2, 3, 2, 1, 3]
# (0.8643717183387907, 0.8949254201630836) [2, 2, 1, 3, 1, 2, 0, 2]
# (0.8830094716759456, 0.8788610657513909) [2, 2, 2, 0, 0, 0, 1, 0]
# (0.9350699966391783, 0.8786907012885906) [2, 2, 2, 0, 1, 1, 1, 1]
# (0.9290295101158356, 0.904032233349744) [2, 2, 2, 0, 1, 2, 3, 2]
# (0.9234516749929467, 0.916070792105568) [2, 2, 2, 0, 2, 1, 3, 0]
# (0.8997599875276386, 0.9337744213544316) [2, 2, 2, 0, 3, 2, 2, 1]
# (0.9000459028017284, 0.955759279521212) [2, 2, 2, 1, 0, 2, 1, 0]
# (0.8927734064906071, 0.986289322714518) [2, 2, 2, 1, 1, 2, 0, 0]
# (0.9251848752944084, 0.9486364916189954) [2, 2, 2, 1, 3, 1, 3, 0]
# (0.9416057312358914, 0.941989449080023) [2, 2, 2, 2, 0, 0, 0, 2]
# (0.9822584103657712, 0.9727528702891992) [2, 2, 2, 2, 2, 0, 1, 2]
# (0.9683552938760877, 0.9049080808982717) [2, 2, 2, 3, 0, 2, 2, 2]
# (0.9932417460185773, 0.8979507055106705) [2, 2, 2, 3, 1, 2, 1, 3]
# (0.9633468119869104, 0.9064072636424633) [2, 2, 2, 3, 3, 3, 1, 0]
# (0.8902482277302355, 0.8040940802542538) [2, 2, 3, 0, 1, 1, 3, 2]
# (0.904092140869584, 0.8102466551146611) [2, 2, 3, 0, 1, 2, 2, 2]
# (0.9358684070454996, 0.8016730760093281) [2, 2, 3, 0, 2, 2, 3, 2]
# (0.9120941983136858, 0.7765527751885503) [2, 2, 3, 0, 3, 3, 1, 3]
# (0.9861897683592861, 0.77648102022463) [2, 2, 3, 1, 1, 2, 3, 0]
# (0.9797491636504608, 0.8124225235916447) [2, 2, 3, 1, 2, 3, 2, 1]
# (0.9570073948310435, 0.8067985039846882) [2, 2, 3, 1, 3, 2, 1, 0]
# (0.9553777244739298, 0.808273193756346) [2, 2, 3, 1, 3, 2, 1, 0]
# (0.9778466315649319, 0.8542249084444501) [2, 2, 3, 2, 2, 0, 2, 0]
# (0.9404823893749478, 0.8614784866214924) [2, 2, 3, 2, 3, 1, 0, 0]
# (0.9637362849057294, 0.8612779617139855) [2, 2, 3, 2, 3, 2, 3, 0]
# (0.9040431306984339, 0.8420782456089243) [2, 2, 3, 3, 0, 2, 2, 2]
# (0.7522784765100119, 0.5064459784546947) [2, 3, 0, 0, 0, 0, 0, 1]
# (0.7549759003617448, 0.5091384779148811) [2, 3, 0, 0, 0, 0, 3, 3]
# (0.7664361367254112, 0.5168148713782977) [2, 3, 0, 0, 0, 2, 0, 0]
# (0.7666118257975058, 0.5260664571021716) [2, 3, 0, 0, 0, 2, 1, 0]
# (0.8057690335618629, 0.5463752938442266) [2, 3, 0, 0, 2, 1, 2, 3]
# (0.7673400715133127, 0.5317800004549894) [2, 3, 0, 0, 3, 3, 0, 0]
# (0.7626218529547072, 0.5643210148934081) [2, 3, 0, 1, 0, 0, 3, 1]
# (0.7790014568672501, 0.6080904119378849) [2, 3, 0, 1, 1, 3, 2, 2]
# (0.7964200761062316, 0.6114240925892225) [2, 3, 0, 1, 2, 1, 3, 1]
# (0.8015311792842775, 0.5825773846120164) [2, 3, 0, 1, 3, 2, 0, 2]
# (0.8377331619335815, 0.5994380277658606) [2, 3, 0, 2, 1, 3, 1, 3]
# (0.8488896580967888, 0.515223900269838) [2, 3, 0, 3, 1, 0, 1, 2]
# (0.8532975714858795, 0.5185758915656273) [2, 3, 0, 3, 1, 3, 3, 0]
# (0.8579992308145838, 0.5201042683779923) [2, 3, 0, 3, 1, 3, 3, 2]
# (0.8262593725839473, 0.5534330279197555) [2, 3, 0, 3, 3, 1, 3, 2]
# (0.893822775334539, 0.5535215275632428) [2, 3, 1, 0, 1, 2, 0, 3]
# (0.9663622772352625, 0.5121665523600338) [2, 3, 1, 1, 0, 3, 2, 2]
# (0.9693108542316876, 0.511964094799261) [2, 3, 1, 1, 1, 0, 1, 1]
# (0.9840322016643878, 0.5080684096155775) [2, 3, 1, 1, 1, 0, 2, 3]
# (0.9973183882405063, 0.5076760338191258) [2, 3, 1, 1, 1, 1, 1, 2]
# (0.9862179572904354, 0.561323848841715) [2, 3, 1, 1, 2, 2, 3, 1]
# (0.946264873118213, 0.5809762248689572) [2, 3, 1, 2, 0, 1, 3, 0]
# (0.9541134059003509, 0.5844648448061077) [2, 3, 1, 2, 0, 2, 0, 3]
# (0.980722972535716, 0.5886757809768415) [2, 3, 1, 2, 1, 3, 2, 3]
# (0.9836897265422634, 0.6228820645578732) [2, 3, 1, 2, 2, 3, 2, 2]
# (0.9837459156539373, 0.6165318676889667) [2, 3, 1, 2, 2, 3, 3, 2]
# (0.881838106695134, 0.589991837155122) [2, 3, 1, 3, 0, 3, 1, 2]
# (0.8823852134280261, 0.6154756896413026) [2, 3, 1, 3, 1, 1, 0, 2]
# (0.9211126349327767, 0.5738028087435609) [2, 3, 1, 3, 3, 0, 2, 3]
# (0.9036186417824726, 0.6300297774626865) [2, 3, 2, 0, 0, 1, 1, 2]
# (0.9047032836761858, 0.6424813680836137) [2, 3, 2, 0, 0, 2, 1, 1]
# (0.8804073476904618, 0.6593889458235053) [2, 3, 2, 0, 1, 0, 0, 3]
# (0.8809809843298736, 0.6669547957126742) [2, 3, 2, 0, 1, 0, 3, 3]
# (0.9661202113540405, 0.6328127182349866) [2, 3, 2, 1, 0, 3, 2, 1]
# (0.9991689281385462, 0.6527641273180593) [2, 3, 2, 1, 1, 2, 2, 2]
# (0.9420499078036784, 0.6755367013043951) [2, 3, 2, 1, 3, 1, 0, 1]
# (0.9632408828297316, 0.6724828478978948) [2, 3, 2, 1, 3, 2, 3, 0]
# (0.9805537824619157, 0.7284641042094916) [2, 3, 2, 2, 2, 0, 2, 3]
# (0.9485392966449202, 0.7205760106366438) [2, 3, 2, 2, 3, 0, 1, 0]
# (0.960094503102093, 0.7246261840948072) [2, 3, 2, 2, 3, 3, 0, 2]
# (0.8887517160024003, 0.7306573942414123) [2, 3, 2, 3, 1, 0, 2, 2]
# (0.8878379956080334, 0.7450047372601503) [2, 3, 2, 3, 1, 1, 2, 3]
# (0.9207319169511576, 0.7251399850266538) [2, 3, 2, 3, 2, 0, 1, 2]
# (0.9282213266281341, 0.7272374995235014) [2, 3, 2, 3, 2, 3, 3, 3]
# (0.916833123174139, 0.7112087364878322) [2, 3, 2, 3, 3, 3, 2, 0]
# (0.7897909765750498, 0.6585672563341579) [2, 3, 3, 0, 2, 0, 3, 0]
# (0.7986649669228331, 0.6604406845883077) [2, 3, 3, 0, 2, 1, 0, 1]
# (0.8025095995932252, 0.6571636516481305) [2, 3, 3, 0, 2, 1, 0, 3]
# (0.7547343035638359, 0.6628436907834351) [2, 3, 3, 0, 3, 0, 0, 2]
# (0.765925932077098, 0.7313548893160217) [2, 3, 3, 1, 1, 3, 3, 1]
# (0.7937572928907956, 0.7428738800304832) [2, 3, 3, 1, 2, 1, 2, 3]
# (0.8115304217859258, 0.7053763450812001) [2, 3, 3, 1, 3, 2, 1, 1]
# (0.8285938358893739, 0.6958273142371912) [2, 3, 3, 2, 0, 1, 3, 0]
# (0.8157528157225731, 0.7475748121247988) [2, 3, 3, 2, 1, 1, 1, 1]
# (0.872644227697232, 0.718628714892746) [2, 3, 3, 2, 3, 2, 2, 2]
# (0.8621869238940718, 0.7117447626896761) [2, 3, 3, 2, 3, 2, 3, 0]
# (0.8134034465937054, 0.6280771196086865) [2, 3, 3, 3, 0, 0, 0, 0]
# (0.8276591347608963, 0.6558237301700639) [2, 3, 3, 3, 0, 1, 2, 2]
# (0.8206788109558913, 0.678042249596953) [2, 3, 3, 3, 3, 1, 3, 3]
# (0.5086506826250955, 0.027590465859172242) [3, 0, 0, 0, 0, 3, 2, 1]
# (0.5184025749465998, 0.03528543679723861) [3, 0, 0, 0, 1, 3, 0, 1]
# (0.5509562150206466, 0.06070430953751105) [3, 0, 0, 0, 2, 2, 1, 2]
# (0.5487307621456359, 0.013103688186134721) [3, 0, 0, 0, 3, 1, 3, 1]
# (0.5620438758496632, 0.017161062450076314) [3, 0, 0, 0, 3, 2, 1, 1]
# (0.5699926066390972, 0.018647155040384167) [3, 0, 0, 1, 0, 1, 0, 1]
# (0.5736583345873892, 0.02225413727180625) [3, 0, 0, 1, 0, 1, 3, 3]
# (0.5811657222543717, 0.01943837802390147) [3, 0, 0, 1, 0, 2, 0, 0]
# (0.5922220703067544, 0.00458289714041038) [3, 0, 0, 1, 0, 3, 1, 2]
# (0.6203877613522374, 0.027398579960391967) [3, 0, 0, 1, 1, 2, 2, 3]
# (0.6180531538557992, 0.04544931733237023) [3, 0, 0, 1, 2, 1, 2, 3]
# (0.5707299729980595, 0.06163759930901358) [3, 0, 0, 1, 3, 1, 2, 1]
# ...
# (0.7219478578584637, 0.22932885050957874) [3, 0, 2, 2, 2, 0, 3, 0]
# (0.7454524707236813, 0.22603861535879177) [3, 0, 2, 2, 2, 3, 1, 3]
# (0.7304580582442036, 0.12885882779752222) [3, 0, 2, 3, 1, 0, 3, 0]
# (0.7352331022074454, 0.18212355790098111) [3, 0, 2, 3, 2, 2, 3, 0]
# (0.6935459662670644, 0.17216482763225371) [3, 0, 2, 3, 3, 1, 0, 1]
# (0.6428533479510886, 0.05049154232490194) [3, 0, 3, 0, 1, 2, 0, 0]
# (0.6952654162546442, 0.005464857744303608) [3, 0, 3, 1, 0, 0, 0, 2]
# (0.717985689200951, 0.020548392222954237) [3, 0, 3, 1, 0, 2, 3, 2]
# (0.7397132838205956, 0.026943185056749308) [3, 0, 3, 1, 1, 2, 3, 3]
# (0.7278132736441306, 0.028459437136684862) [3, 0, 3, 1, 1, 3, 2, 1]
# (0.7137631310479461, 0.08421324455805779) [3, 0, 3, 2, 0, 2, 3, 3]
# (0.7368967690719339, 0.08998025285060052) [3, 0, 3, 2, 1, 2, 3, 1]
# (0.6901109100840578, 0.09432107995380756) [3, 0, 3, 2, 3, 0, 0, 0]
# (0.6981185616122766, 0.10512235394631242) [3, 0, 3, 2, 3, 0, 2, 0]
# (0.6305364566513446, 0.10649082515083996) [3, 0, 3, 3, 1, 0, 3, 2]
# (0.6344843071044209, 0.12114745102235602) [3, 0, 3, 3, 1, 1, 2, 1]
# (0.6424190694528693, 0.10136183231459472) [3, 0, 3, 3, 1, 3, 0, 1]
# (0.6599303359373073, 0.1197895867140294) [3, 0, 3, 3, 2, 1, 1, 0]
# (0.6727187904435602, 0.11657423198853989) [3, 0, 3, 3, 2, 2, 0, 3]
# (0.6751621286056919, 0.09877732460004762) [3, 0, 3, 3, 2, 3, 0, 1]
# (0.6696657539750536, 0.06856140229951646) [3, 0, 3, 3, 3, 0, 3, 2]
# (0.6566383181504934, 0.08201463305014) [3, 0, 3, 3, 3, 3, 0, 0]
# (0.6613566987766375, 0.09083207416531536) [3, 0, 3, 3, 3, 3, 1, 2]
# (0.7626321051358991, 0.06107825000075251) [3, 1, 0, 0, 3, 1, 2, 2]
# (0.7538508868857656, 0.11784773200938015) [3, 1, 0, 1, 1, 1, 1, 0]
# (0.7787124895277395, 0.1100970844729442) [3, 1, 0, 1, 1, 2, 3, 1]
# (0.7838978901489926, 0.1164170217475825) [3, 1, 0, 1, 2, 1, 0, 3]
# (0.8026901143618974, 0.1154141953177048) [3, 1, 0, 1, 2, 2, 0, 2]
# (0.8386161079395698, 0.10812703867834694) [3, 1, 0, 2, 1, 3, 2, 3]
# (0.8740397008943284, 0.0778436852847385) [3, 1, 0, 2, 3, 1, 2, 2]
# (0.8660567165064071, 0.08724608282401825) [3, 1, 0, 2, 3, 2, 3, 3]
# (0.8464223698686759, 0.08002133763251562) [3, 1, 0, 2, 3, 3, 0, 0]
# (0.8269389123758326, 0.00202597072941213) [3, 1, 0, 3, 0, 0, 1, 1]
# (0.8462097986429594, 0.018526847412182246) [3, 1, 0, 3, 1, 3, 0, 0]
# (0.8687392146722211, 0.04364447357933299) [3, 1, 0, 3, 2, 1, 2, 3]
# (0.8412478404345093, 0.03922580388204355) [3, 1, 0, 3, 3, 3, 2, 1]
# (0.8908473620730013, 0.012245421439432747) [3, 1, 1, 0, 0, 1, 3, 1]
# (0.9213964858399143, 0.05939641429379794) [3, 1, 1, 0, 2, 1, 2, 2]
# (0.9229672575459235, 0.04278772557783084) [3, 1, 1, 0, 2, 3, 3, 0]
# (0.9561414940013467, 0.013255977467617419) [3, 1, 1, 1, 0, 3, 3, 1]
# (0.98621825143418, 0.029371991337708403) [3, 1, 1, 1, 1, 2, 3, 1]
# (0.9437842111610995, 0.03410099745435746) [3, 1, 1, 1, 3, 0, 0, 3]
# (0.9919130409422889, 0.06388961947798832) [3, 1, 1, 2, 1, 1, 0, 3]
# (0.9712569725659116, 0.10636654057903439) [3, 1, 1, 2, 2, 0, 1, 1]
# (0.9864902792761309, 0.12197087677943008) [3, 1, 1, 2, 2, 2, 3, 1]
# (0.8860191829862081, 0.07440936202324977) [3, 1, 1, 3, 0, 0, 2, 1]
# (0.9062237413735114, 0.06415033593469643) [3, 1, 1, 3, 0, 1, 1, 1]
# (0.8803732731517279, 0.1109071019955078) [3, 1, 1, 3, 1, 1, 0, 1]
# (0.8974385113001595, 0.1549183226100609) [3, 1, 2, 0, 0, 2, 3, 2]
# (0.8879749150164409, 0.1512846078215837) [3, 1, 2, 0, 0, 3, 2, 3]
# (0.898611659369763, 0.183712010490235) [3, 1, 2, 0, 1, 2, 2, 1]
# (0.9051142974185385, 0.16167810692013485) [3, 1, 2, 0, 1, 3, 1, 2]
# (0.8952084812636555, 0.16618222444641728) [3, 1, 2, 0, 1, 3, 3, 3]
# (0.9093409733732799, 0.13835317980055462) [3, 1, 2, 0, 3, 0, 1, 1]
# (0.9666741750955702, 0.13557249775348168) [3, 1, 2, 1, 0, 3, 2, 1]
# (0.9471437407538225, 0.15793284729066392) [3, 1, 2, 1, 3, 0, 1, 0]
# (0.9499372270235089, 0.16914505379993972) [3, 1, 2, 1, 3, 0, 2, 2]
# (0.9734809812008971, 0.1894762663786449) [3, 1, 2, 2, 1, 0, 0, 1]
# (0.9858252697835063, 0.19374064659263834) [3, 1, 2, 2, 1, 1, 0, 1]
# (0.9904400923869643, 0.23833076059569203) [3, 1, 2, 2, 2, 2, 0, 2]
# (0.9942674185949255, 0.23467398369239223) [3, 1, 2, 2, 2, 2, 1, 0]
# (0.9990275497358991, 0.23468675873221923) [3, 1, 2, 2, 2, 2, 1, 1]
# (0.9451429762993795, 0.23503712781326025) [3, 1, 2, 2, 3, 1, 0, 1]
# (0.9540660389041951, 0.22021821315255474) [3, 1, 2, 2, 3, 3, 0, 0]
# (0.8920568587844774, 0.21491761034142542) [3, 1, 2, 3, 0, 2, 3, 1]
# (0.8863405418205101, 0.21332531455324) [3, 1, 2, 3, 0, 3, 2, 0]
# (0.8893499254971599, 0.2092100242154029) [3, 1, 2, 3, 0, 3, 3, 2]
# (0.9138918621836711, 0.24982578632195895) [3, 1, 2, 3, 2, 1, 1, 2]
# (0.9102192505027633, 0.20921636991735237) [3, 1, 2, 3, 3, 3, 0, 2]
# (0.7694691750941778, 0.1445595870994113) [3, 1, 3, 0, 0, 2, 0, 3]
# (0.7716675772082231, 0.1385276737100084) [3, 1, 3, 0, 0, 3, 3, 2]
# (0.8003060909872987, 0.12899009074326917) [3, 1, 3, 0, 1, 1, 0, 1]
# (0.7894543978923972, 0.1551323544608002) [3, 1, 3, 0, 1, 3, 2, 1]
# (0.8077118941615887, 0.16717574984988248) [3, 1, 3, 0, 2, 1, 2, 0]
# (0.7743626735682443, 0.215612223700827) [3, 1, 3, 1, 0, 2, 2, 3]
# (0.7589663864119196, 0.20722635955197855) [3, 1, 3, 1, 0, 3, 3, 3]
# (0.7588759516043928, 0.22024490425574073) [3, 1, 3, 1, 1, 0, 1, 0]
# (0.7627285921949802, 0.2418684625769436) [3, 1, 3, 1, 1, 1, 3, 2]
# (0.7669847144502325, 0.23492740840520032) [3, 1, 3, 1, 1, 2, 0, 0]
# (0.8067292619288075, 0.21889797830910163) [3, 1, 3, 1, 2, 3, 1, 0]
# (0.7817193836271545, 0.21414870151820675) [3, 1, 3, 1, 3, 3, 1, 0]
# (0.7931507920748907, 0.20740810102010165) [3, 1, 3, 1, 3, 3, 3, 2]
# (0.8226275359643135, 0.19846276784642758) [3, 1, 3, 2, 0, 0, 2, 0]
# (0.8395441498619215, 0.19821086656747333) [3, 1, 3, 2, 0, 1, 2, 0]
# (0.8224770318958726, 0.21713413540629545) [3, 1, 3, 2, 0, 3, 2, 1]
# (0.8241438938498745, 0.20452401787469654) [3, 1, 3, 2, 0, 3, 3, 0]
# (0.8590886204530885, 0.2188467127905772) [3, 1, 3, 2, 2, 0, 1, 1]
# (0.8281778668693008, 0.12716609059645778) [3, 1, 3, 3, 0, 3, 0, 0]
# (0.8411738315018009, 0.13296228221324002) [3, 1, 3, 3, 0, 3, 2, 1]
# (0.8669925046148147, 0.17599393371355454) [3, 1, 3, 3, 2, 2, 0, 2]
# (0.8525521856834649, 0.18158238217330325) [3, 1, 3, 3, 2, 3, 2, 0]
# (0.8319972289351646, 0.18222292417456776) [3, 1, 3, 3, 3, 2, 1, 0]
# (0.7551685286308365, 0.2703272169188694) [3, 2, 0, 0, 0, 1, 0, 2]
# (0.8084688505368254, 0.2562015211798345) [3, 2, 0, 0, 1, 1, 1, 3]
# (0.8035878408647896, 0.25926935625541425) [3, 2, 0, 0, 1, 1, 3, 3]
# (0.8080902467818991, 0.28016604411548707) [3, 2, 0, 0, 1, 2, 2, 3]
# (0.8051754971244128, 0.28006720194518575) [3, 2, 0, 0, 1, 2, 2, 3]
# (0.784829630840973, 0.2940175928995421) [3, 2, 0, 0, 2, 0, 1, 1]
# (0.7901220426294855, 0.28351569945932964) [3, 2, 0, 0, 2, 0, 3, 0]
# (0.7619710071834817, 0.31210321493850735) [3, 2, 0, 0, 3, 1, 2, 2]
# (0.7744743783795155, 0.3193724100765385) [3, 2, 0, 1, 0, 1, 1, 3]
# (0.7884489270114506, 0.31805120198030734) [3, 2, 0, 1, 3, 0, 0, 2]
# (0.792600840563881, 0.31836191390442903) [3, 2, 0, 1, 3, 0, 3, 3]
# (0.8087094311514488, 0.32315141001242664) [3, 2, 0, 1, 3, 1, 2, 1]
# (0.8153154369328672, 0.3233819359515082) [3, 2, 0, 2, 0, 0, 1, 0]
# (0.821915016572281, 0.3466166270718185) [3, 2, 0, 2, 1, 0, 1, 0]
# (0.8291959682096709, 0.3695101131876062) [3, 2, 0, 2, 1, 2, 1, 0]
# (0.8427540703014942, 0.35285408420554876) [3, 2, 0, 2, 1, 3, 2, 1]
# (0.8568553292794282, 0.3684006882486982) [3, 2, 0, 2, 2, 1, 2, 3]
# (0.8469524693093865, 0.33991789075223733) [3, 2, 0, 2, 3, 3, 1, 1]
# (0.8660965594609099, 0.27960002314281973) [3, 2, 0, 3, 1, 2, 3, 2]
# (0.8479719847005467, 0.3036142764957932) [3, 2, 0, 3, 2, 3, 0, 2]
# (0.8392732732449436, 0.28663627072838593) [3, 2, 0, 3, 3, 3, 1, 3]
# (0.8990326637446059, 0.2575969544265376) [3, 2, 1, 0, 0, 1, 1, 3]
# (0.8944141228127078, 0.27667401458578333) [3, 2, 1, 0, 0, 2, 3, 0]
# (0.890871654890914, 0.2811495451616054) [3, 2, 1, 0, 0, 2, 3, 1]
# (0.920948650200752, 0.30561217193548595) [3, 2, 1, 0, 2, 1, 2, 3]
# (0.9815510308219085, 0.25200070904251215) [3, 2, 1, 1, 1, 0, 3, 1]
# (0.9866038326448511, 0.2780324848395721) [3, 2, 1, 1, 1, 2, 3, 1]
# (0.9453137582814808, 0.28137712014494565) [3, 2, 1, 1, 3, 0, 1, 0]
# (0.9767579296204116, 0.35889426455766293) [3, 2, 1, 2, 2, 0, 2, 1]
# (0.944213693289231, 0.34832731887097756) [3, 2, 1, 2, 3, 0, 0, 2]
# (0.8952608179570698, 0.3652056265168936) [3, 2, 1, 3, 1, 2, 0, 2]
# (0.9244968680463076, 0.3661978496169944) [3, 2, 1, 3, 2, 2, 0, 3]
# (0.9333589232854482, 0.3182328513011039) [3, 2, 1, 3, 3, 1, 1, 3]
# (0.9243690940297088, 0.34108692270910146) [3, 2, 1, 3, 3, 2, 3, 1]
# (0.9044437114361186, 0.37917064921151133) [3, 2, 2, 0, 0, 1, 1, 2]
# (0.9262568144597574, 0.3825566481469498) [3, 2, 2, 0, 3, 1, 0, 2]
# (0.9512431632017465, 0.3998039293994975) [3, 2, 2, 1, 0, 1, 2, 3]
# (0.9666604194984942, 0.38281385408836943) [3, 2, 2, 1, 0, 3, 2, 1]
# (0.9655386849625316, 0.3875805027775133) [3, 2, 2, 1, 0, 3, 2, 2]
# (0.9849170070566062, 0.3871465532571744) [3, 2, 2, 1, 1, 1, 3, 1]
# (0.9470617930428773, 0.4102354012706282) [3, 2, 2, 1, 3, 0, 1, 3]
# (0.9407058823646446, 0.44288174069780095) [3, 2, 2, 2, 0, 0, 0, 1]
# (0.9868841172471671, 0.48655628614610047) [3, 2, 2, 2, 2, 2, 0, 0]
# (0.9410938863428759, 0.48068616131219133) [3, 2, 2, 2, 3, 0, 3, 1]
# (0.9585572051182824, 0.48904490675835977) [3, 2, 2, 2, 3, 2, 0, 2]
# (0.9595715881848988, 0.480148354427657) [3, 2, 2, 2, 3, 3, 3, 3]
# (0.9021021871400186, 0.4381520274904743) [3, 2, 2, 3, 0, 1, 1, 0]
# (0.9018900376042662, 0.4682807567593137) [3, 2, 2, 3, 0, 2, 2, 3]
# (0.9150188838070272, 0.4908531197826268) [3, 2, 2, 3, 2, 1, 3, 3]
# (0.9252086208171322, 0.4537725973829899) [3, 2, 2, 3, 3, 2, 0, 0]
# (0.8031453402410877, 0.38092904677243866) [3, 2, 3, 0, 1, 1, 0, 2]
# (0.7893250939226653, 0.4253522358323507) [3, 2, 3, 0, 2, 3, 3, 0]
# (0.757014034683504, 0.4441403789973537) [3, 2, 3, 1, 0, 0, 0, 2]
# (0.7673426119571598, 0.45762896723210256) [3, 2, 3, 1, 0, 2, 0, 1]
# (0.7781758427813589, 0.4938971377253055) [3, 2, 3, 1, 1, 2, 2, 3]
# (0.7868376252844994, 0.4848649960046889) [3, 2, 3, 1, 2, 1, 0, 1]
# (0.8087903590198424, 0.4525875069001283) [3, 2, 3, 1, 3, 1, 2, 2]
# (0.8377082292675389, 0.4388165893357988) [3, 2, 3, 2, 0, 1, 1, 0]
# (0.8166247787388423, 0.4547150889960202) [3, 2, 3, 2, 0, 3, 0, 1]
# (0.8153831907886954, 0.45916317698402054) [3, 2, 3, 2, 0, 3, 0, 3]
# (0.8246907100011593, 0.4571167672325316) [3, 2, 3, 2, 0, 3, 3, 2]
# (0.8221925541928568, 0.4870487416169659) [3, 2, 3, 2, 1, 1, 3, 0]
# (0.8297834046631428, 0.49525925879614496) [3, 2, 3, 2, 1, 2, 1, 0]
# (0.8579950952749433, 0.47434101647516125) [3, 2, 3, 2, 2, 0, 1, 2]
# (0.8485014446008676, 0.4843235113276676) [3, 2, 3, 2, 2, 0, 3, 2]
# (0.8224967196150774, 0.38724879849845095) [3, 2, 3, 3, 0, 0, 2, 3]
# (0.8413200745989039, 0.39472637538119903) [3, 2, 3, 3, 0, 2, 3, 2]
# (0.8668677780696109, 0.39952359155099926) [3, 2, 3, 3, 1, 2, 3, 3]
# (0.8724464817669719, 0.4111281857282907) [3, 2, 3, 3, 2, 1, 1, 2]
# (0.8295139642934362, 0.4066544467581402) [3, 2, 3, 3, 3, 3, 0, 0]
# (0.841721683700152, 0.4130760777162126) [3, 2, 3, 3, 3, 3, 1, 2]
# (0.5090665979665198, 0.261462657704883) [3, 3, 0, 0, 0, 0, 2, 0]
# (0.5167486799313854, 0.25795710689819007) [3, 3, 0, 0, 0, 1, 3, 0]
# (0.5304614502616987, 0.2811401106697333) [3, 3, 0, 0, 0, 2, 2, 2]
# (0.510906753319346, 0.29476757898650197) [3, 3, 0, 0, 1, 0, 2, 3]
# (0.5073890805205598, 0.3010969458493713) [3, 3, 0, 0, 1, 1, 0, 2]
# (0.5136288173829133, 0.299774265058969) [3, 3, 0, 0, 1, 1, 3, 1]
# (0.5178301137936543, 0.30098688854633815) [3, 3, 0, 0, 1, 2, 0, 3]
# (0.5219821539456754, 0.2859512839573025) [3, 3, 0, 0, 1, 3, 0, 2]
# (0.5759273838444674, 0.26389365635905515) [3, 3, 0, 1, 0, 0, 2, 2]
# (0.5705261211464386, 0.2963919952755042) [3, 3, 0, 1, 3, 0, 2, 3]
# (0.5937696953051006, 0.3457976348029653) [3, 3, 0, 2, 2, 0, 0, 0]
# (0.6081504111512467, 0.344207029151429) [3, 3, 0, 2, 2, 0, 3, 1]
# (0.6025335974474056, 0.3512548783422538) [3, 3, 0, 2, 2, 0, 3, 3]
# (0.6038276493214261, 0.36096923263709557) [3, 3, 0, 2, 2, 3, 3, 0]
# (0.5652412996314335, 0.36735640317788665) [3, 3, 0, 2, 3, 1, 1, 0]
# (0.578189892219372, 0.3743435934854271) [3, 3, 0, 2, 3, 2, 1, 1]
# (0.5800751134086836, 0.3545896821971062) [3, 3, 0, 2, 3, 3, 3, 0]
# (0.5831413850326922, 0.3586442458858593) [3, 3, 0, 2, 3, 3, 3, 2]
# (0.5284291304000546, 0.33193416358108474) [3, 3, 0, 3, 0, 2, 1, 1]
# (0.5063149038941702, 0.36112326615770396) [3, 3, 0, 3, 1, 1, 0, 1]
# (0.5277397464754437, 0.3628066585225209) [3, 3, 0, 3, 1, 2, 3, 1]
# (0.5457940046851905, 0.3672847803099589) [3, 3, 0, 3, 2, 1, 2, 3]
# (0.508453804624216, 0.38606081384074953) [3, 3, 1, 0, 0, 0, 2, 0]
# (0.5313857377801764, 0.3770019181586278) [3, 3, 1, 0, 1, 0, 0, 0]
# (0.5329168818193761, 0.4190734921535445) [3, 3, 1, 0, 2, 0, 1, 1]
# (0.5040868777967284, 0.429219850601808) [3, 3, 1, 0, 3, 1, 0, 2]
# (0.527170549127778, 0.4227298976860975) [3, 3, 1, 0, 3, 2, 3, 0]
# (0.5287192182699856, 0.4086007924811418) [3, 3, 1, 0, 3, 3, 1, 1]
# (0.5073684118388164, 0.4426275220123125) [3, 3, 1, 1, 0, 0, 0, 2]
# (0.513047181574752, 0.49714041350918403) [3, 3, 1, 1, 1, 1, 2, 2]
# (0.5765973644477789, 0.4618889825153857) [3, 3, 1, 2, 0, 3, 2, 3]
# (0.5883704665028787, 0.49548977645199843) [3, 3, 1, 2, 1, 2, 2, 0]
# (0.5994884577812051, 0.4827835761742493) [3, 3, 1, 2, 2, 0, 3, 2]
# (0.6129774308819321, 0.4414377219737995) [3, 3, 1, 2, 3, 1, 0, 1]
# (0.6101357841411374, 0.4656526380561644) [3, 3, 1, 2, 3, 2, 3, 1]
# (0.5947121871795392, 0.45915097000132954) [3, 3, 1, 2, 3, 3, 0, 3]
# (0.5716047214419788, 0.38999187955508596) [3, 3, 1, 3, 0, 0, 2, 3]
# (0.5757585846928887, 0.4241107367252597) [3, 3, 1, 3, 3, 1, 3, 1]
# (0.581518298815655, 0.4158174751912044) [3, 3, 1, 3, 3, 3, 3, 0]
# (0.6595482755639416, 0.4165932509800099) [3, 3, 2, 0, 2, 0, 1, 0]
# (0.684092718190955, 0.4181674328934072) [3, 3, 2, 0, 2, 1, 2, 2]
# (0.670971987139136, 0.42806375810875763) [3, 3, 2, 0, 2, 3, 3, 2]
# (0.6553378775224686, 0.4302420178537315) [3, 3, 2, 0, 3, 2, 2, 3]
# (0.6362069406715493, 0.4667064304669287) [3, 3, 2, 1, 0, 3, 2, 1]
# (0.6901673745404842, 0.49654578583838704) [3, 3, 2, 2, 1, 1, 1, 1]
# (0.706677032991962, 0.4894315865872365) [3, 3, 2, 2, 1, 2, 0, 3]
# (0.7110022965178573, 0.4924280899960992) [3, 3, 2, 2, 1, 2, 2, 0]
# (0.7130043917563894, 0.46948403781512316) [3, 3, 2, 2, 1, 3, 1, 0]
# (0.7281367275149726, 0.4780353907321656) [3, 3, 2, 2, 2, 0, 2, 0]
# (0.7210540966735995, 0.4798623614458629) [3, 3, 2, 2, 2, 0, 3, 0]
# (0.6988698873342111, 0.3871120191480938) [3, 3, 2, 3, 0, 0, 2, 3]
# (0.7443717534661276, 0.40374679232174804) [3, 3, 2, 3, 1, 2, 2, 3]
# (0.6878341558211047, 0.43574632627762966) [3, 3, 2, 3, 3, 1, 1, 1]
# (0.6488249661766254, 0.2704935351382731) [3, 3, 3, 0, 0, 2, 1, 3]
# (0.6444773151963844, 0.27715369380130106) [3, 3, 3, 0, 0, 2, 3, 0]
# (0.6252077789055371, 0.2781253893878767) [3, 3, 3, 0, 0, 3, 1, 1]
# (0.6382861990676322, 0.29136211252395094) [3, 3, 3, 0, 1, 0, 2, 1]
# (0.6437669833230201, 0.30363125766158083) [3, 3, 3, 0, 1, 2, 0, 3]
# (0.6577279482738729, 0.31015989949639855) [3, 3, 3, 0, 2, 1, 1, 1]
# (0.67370549334406, 0.3103593055697361) [3, 3, 3, 0, 2, 2, 1, 1]
# (0.6839869277515851, 0.29918073142332613) [3, 3, 3, 0, 2, 2, 3, 1]
# (0.6841713183978128, 0.2616384742479201) [3, 3, 3, 0, 3, 1, 2, 1]
# (0.6803844814246871, 0.2701016859531702) [3, 3, 3, 0, 3, 2, 1, 3]
# (0.6931720398288903, 0.2518093148673676) [3, 3, 3, 1, 0, 0, 0, 3]
# (0.6957211109525597, 0.2707018736314877) [3, 3, 3, 1, 0, 1, 3, 3]
# (0.7247110121931579, 0.277230664905456) [3, 3, 3, 1, 1, 3, 1, 3]
# (0.7351892178249742, 0.2907658420839454) [3, 3, 3, 1, 2, 1, 3, 0]
# (0.6951789882157395, 0.3291248105201573) [3, 3, 3, 2, 0, 1, 0, 1]
# (0.7143869400161077, 0.3170350875168573) [3, 3, 3, 2, 0, 3, 1, 3]
# (0.7458982630185733, 0.33429663730050074) [3, 3, 3, 2, 1, 2, 1, 3]
# (0.7426439014982925, 0.34666049414362754) [3, 3, 3, 2, 2, 1, 1, 0]
# (0.649413577863372, 0.326656853233827) [3, 3, 3, 3, 0, 1, 2, 3]
# (0.6393084034791688, 0.33916283398724756) [3, 3, 3, 3, 0, 3, 2, 3]
# (0.666374836078687, 0.3581071855924698) [3, 3, 3, 3, 2, 0, 2, 3]
# (0.6775826088913476, 0.32808898585877233) [3, 3, 3, 3, 3, 1, 3, 2]
# (0.6783179912905615, 0.32204239636259124) [3, 3, 3, 3, 3, 1, 3, 3]
# (0.6640570460780362, 0.34056576200895217) [3, 3, 3, 3, 3, 3, 1, 2]

# %%
# add the 4 initial triangles with infinite points and point p[0]
p = mesh.vertices[4]
init_hedges = []
for i in range(4):
    init_hedges += mesh.add_triangle([mesh.vertices[i], mesh.vertices[(i+1)%4], mesh.vertices[4]], out=True)
# stick edges together
for i in range(4):
    init_hedges[3*i + 1].twin = init_hedges[(3*i + 5) % 12]
    init_hedges[(3*i + 5) % 12].twin = init_hedges[3*i + 1]

# %%
def draw_mesh(mesh):
    for he in mesh.halfedges:
        # if he.visited:
        #     continue
        a, b = he.vertex.coords, he.next.vertex.coords
        # plt.plot(*np.clip((a, b), -0.1, 1.1).T, 'r-')
        plt.plot(*zip(a, b), 'r-', linewidth=0.4)
        # plt.arrow(a[0], a[1], b[0]-a[0], b[1]-a[1], head_width=0.5, head_length=1, fc='r', ec='k')
    for i, p in enumerate(mesh.vertices):
        if np.isinf(p.coords[0]):
            continue
        plt.plot(*p.coords, 'ko', markersize=2)
        plt.text(*p.coords, str(i), fontsize=9)
    plt.show()

# draw_mesh(mesh)

# %%
vertices = mesh.vertices[5:]
mesh.vertices = mesh.vertices[:5]

# %%
# p = vertices[0]
# interior, boundary = Cavity(mesh, p, 5)
# print('bdrv', boundary.vertices)
# print('int', interior.halfedges)
# ball = Ball(boundary, p)
# print('ballv', ball.vertices)
# print('ballh', ball.halfedges)

# %%
# draw_mesh(ball)
# mesh.rem_mesh(boundary)
# mesh.rem_mesh(interior)
# mesh.add_mesh(ball)
# print(mesh.vertices, end='\n\n')
# print(mesh.halfedges, end='\n\n')
# print(mesh.faces)

# %%
def f():
    for i in range(len(vertices)):
        p = vertices[i]
        interior, boundary = Cavity(mesh, p, 5+i)
        # print('bdr', boundary.vertices)
        # print('bdrv', boundary.vertices)
        # print('inth', interior.halfedges)
        ball = Ball(boundary, p)
        # print('ballv', ball.vertices)
        # print('ballh', ball.halfedges)
        # draw_mesh(ball)
        mesh.rem_mesh(boundary)
        mesh.rem_mesh(interior)
        mesh.add_mesh(ball)
        # print('he', len(mesh.halfedges), mesh.halfedges, end='\n')
        # print('meshv', mesh.vertices, end='\n\n')
        # draw_mesh(mesh)


# p = vertices[5]
# interior, boundary = Cavity(mesh, p, 5)
# ball = Ball(boundary, p)
# mesh.rem_mesh(boundary)
# mesh.rem_mesh(interior)
# mesh.add_mesh(ball)
# draw_mesh(mesh)

# %%
# %lprun -f Cavity -f check_triangle -f check_vertex -f expand f()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.115551 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_54668\1686837640.py
# Function: check_triangle at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def check_triangle(halfedge, p):
#      2                                               # print(halfedge.vertex.coords)
#      3                                               # print(halfedge.next.vertex.coords)
#      4                                               # print(halfedge.prev.vertex.coords)
#      5                                               # a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
#      6
#      7                                               # check for infinite points
#      8
#      9     16746      71855.0      4.3      6.2      coords, inf_idx = [], 0
#     10     66984     356456.0      5.3     30.8      for v in [halfedge.vertex, halfedge.next.vertex, halfedge.prev.vertex]:
#     11     50238     214710.0      4.3     18.6          if v.index >= 0:
#     12     48298     255685.0      5.3     22.1              coords.append(v.coords)
#     13                                                   else:
#     14      1940       9450.0      4.9      0.8              inf_idx -= v.index
#     15
#     16     16746      79282.0      4.7      6.9      if len(coords) == 3:
#     17     15110     131079.0      8.7     11.3          return incircle(*coords, p.coords) >= 0
#     18      1636       7334.0      4.5      0.6      elif len(coords) == 2:
#     19      1332       6941.0      5.2      0.6          if halfedge.next.vertex.index < 0:
#     20       454       2768.0      6.1      0.2              coords = [coords[1], coords[0]]
#     21      1332      14324.0     10.8      1.2          return orient2d(*coords, p.coords) >= 0
#     22                                               else:
#     23       304       1272.0      4.2      0.1          if inf_idx == 3:
#     24       139       1048.0      7.5      0.1              return p.coords[1] >= coords[0][1]
#     25       165        711.0      4.3      0.1          elif inf_idx == 6:
#     26        22        179.0      8.1      0.0              return p.coords[0] <= coords[0][0]
#     27       143        523.0      3.7      0.0          elif inf_idx == 12:
#     28        16        135.0      8.4      0.0              return p.coords[1] <= coords[0][1]
#     29       127        450.0      3.5      0.0          elif inf_idx == 9:
#     30       127       1303.0     10.3      0.1              return p.coords[0] >= coords[0][0]
#     31
#     32                                               print('error')
#     33                                               return False
#     34
#     35
#     36
#     37
#     38
#     39                                               a = halfedge.vertex.coords
#     40                                               b = halfedge.next.vertex.coords
#     41                                               c = halfedge.prev.vertex.coords
#     42                                               res = incircle(a, b, c, p.coords)
#     43                                               if np.isnan(res):
#     44                                                   # number of None in [a, b, c]
#     45                                                   k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
#     46                                                   if k == 0:
#     47                                                       # do orient2d test instead
#     48                                                       a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
#     49                                                       # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
#     50                                                       res1 = orient2d(a, b, p.coords)
#     51                                                       return res1 >= 0
#     52                                                   elif k == 1:
#     53                                                       # find index of non infinite point in [a, b, c]
#     54                                                       d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
#     55                                                       quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
#     56                                                       if np.isnan(quadrant[1]):
#     57                                                           return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
#     58                                                       else:
#     59                                                           return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
#     60                                                   else:
#     61                                                       print('Error: 3 infinite points in triangle')
#     62                                                       print(a, b, c)
#     63
#     64                                               return res >= 0
#
# Total time: 0.175888 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_54668\2108953529.py
# Function: expand at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def expand(init_hedge, p):
#      2       999      48096.0     48.1      2.7      interior = TriangularMesh(faces={init_hedge.facet})
#      3       999      38443.0     38.5      2.2      boundary = TriangularMesh()
#      4
#      5                                               # visited = []
#      6       999      10625.0     10.6      0.6      stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
#      7     11612      61698.0      5.3      3.5      while stack:
#      8     10613      53896.0      5.1      3.1          hedge = stack.popleft()
#      9     10613      52915.0      5.0      3.0          if hedge.twin == None:
#     10       122        728.0      6.0      0.0              boundary.halfedges.add(hedge)
#     11                                                       # boundary.vertices.append(hedge.vertex)
#     12       122        454.0      3.7      0.0              continue
#     13     10491    1314469.0    125.3     74.7          if not check_triangle(hedge.twin, p):
#     14      6683      40229.0      6.0      2.3              boundary.halfedges.add(hedge)
#     15                                                       # boundary.vertices.append(hedge.vertex)
#     16      6683      25433.0      3.8      1.4              continue
#     17                                                   # hedge.twin.facet.visited = True
#     18                                                   # visited.append(hedge.twin.facet)
#     19      3808      37068.0      9.7      2.1          interior.halfedges.update({hedge, hedge.twin})
#     20      3808      25641.0      6.7      1.5          interior.faces.add(hedge.twin.facet)
#     21
#     22      3808      22606.0      5.9      1.3          stack.append(hedge.twin.next)
#     23      3808      21635.0      5.7      1.2          stack.append(hedge.twin.prev)
#     24
#     25                                               # for face in visited:
#     26                                               #     face.visited = False
#     27
#     28                                               # print('inbdr', boundary.vertices)
#     29       999       4943.0      4.9      0.3      return interior, boundary
#
# Total time: 0.305146 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_54668\3756960693.py
# Function: Cavity at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def Cavity(mesh, p, ind):
#      2                                               # find a triangle containing p
#      3                                               # def check_triangle(halfedge):
#      4                                               #     # print(halfedge.vertex.coords)
#      5                                               #     # print(halfedge.next.vertex.coords)
#      6                                               #     # print(halfedge.prev.vertex.coords)
#      7                                               #     a, b, c = halfedge.vertex.coords, halfedge.next.vertex.coords, halfedge.prev.vertex.coords
#      8                                               #     res = incircle(a, b, c, p.coords)
#      9                                               #     if np.isnan(res):
#     10                                               #         # number of None in [a, b, c]
#     11                                               #         k = [halfedge.twin, halfedge.next.twin, halfedge.prev.twin].count(None)
#     12                                               #         if k == 0:
#     13                                               #             # do orient2d test instead
#     14                                               #             a, b = (a, b) if np.isinf(c[0]) else (b, c) if np.isinf(a[0]) else (c, a)
#     15                                               #             # return orient2d(a, b, p.coords) >= 0 or orient2d(b, c, p.coords) >= 0 or orient2d(c, a, p.coords) >= 0
#     16                                               #             res1 = orient2d(a, b, p.coords)
#     17                                               #             return res1 >= 0
#     18                                               #         elif k == 1:
#     19                                               #             # find index of non infinite point in [a, b, c]
#     20                                               #             d = a if not np.isinf(a[0]) else b if not np.isinf(b[0]) else c
#     21                                               #             quadrant = tuple(sum(x) for x in zip(a, b, c)) # (+inf, nan) (nan, +inf) (-inf, nan) (nan, -inf)
#     22                                               #             if np.isnan(quadrant[1]):
#     23                                               #                 return p.coords[0] >= d[0] if quadrant[0] > 0 else p.coords[0] <= d[0]
#     24                                               #             else:
#     25                                               #                 return p.coords[1] >= d[1] if quadrant[1] > 0 else p.coords[1] <= d[1]
#     26                                               #         else:
#     27                                               #             print('Error: 3 infinite points in triangle')
#     28                                               #             print(a, b, c)
#     29
#     30                                               #     return res >= 0
#     31
#     32                                               # def check_vertex(vertex):
#     33                                               #     halfedge = vertex.halfedge
#     34                                               #     if not halfedge:
#     35                                               #         # print('no edge for vertex', vertex)
#     36                                               #         return None
#     37                                               #     while True:
#     38                                               #         if check_triangle(halfedge):
#     39                                               #             return halfedge
#     40                                               #         if halfedge.twin == None:
#     41                                               #             break
#     42                                               #         halfedge = halfedge.twin.next # clockwise
#     43                                               #         if halfedge == vertex.halfedge:
#     44                                               #             break
#     45                                               #         if halfedge.vertex != vertex:
#     46                                               #             print('not good', halfedge, halfedge.vertex, vertex)
#     47                                               #             break
#     48                                               #     return None
#     49
#     50                                               # def expand(init_hedge):
#     51                                               #     interior = TriangularMesh(faces={init_hedge.facet})
#     52                                               #     boundary = TriangularMesh()
#     53
#     54                                               #     visited = []
#     55                                               #     stack = deque([init_hedge, init_hedge.next, init_hedge.prev])
#     56                                               #     while stack:
#     57                                               #         hedge = stack.popleft()
#     58                                               #         if hedge.twin == None:
#     59                                               #             boundary.halfedges.add(hedge)
#     60                                               #             # boundary.vertices.append(hedge.vertex)
#     61                                               #             continue
#     62                                               #         if hedge.twin.facet.visited or not check_triangle(hedge.twin, p):
#     63                                               #             boundary.halfedges.add(hedge)
#     64                                               #             # boundary.vertices.append(hedge.vertex)
#     65                                               #             continue
#     66                                               #         hedge.twin.facet.visited = True
#     67                                               #         visited.append(hedge.twin.facet)
#     68                                               #         interior.halfedges.update({hedge, hedge.twin})
#     69                                               #         interior.faces.add(hedge.twin.facet)
#     70
#     71                                               #         stack.append(hedge.twin.next)
#     72                                               #         stack.append(hedge.twin.prev)
#     73
#     74                                               #     for face in visited:
#     75                                               #         face.visited = False
#     76
#     77                                               #     # print('inbdr', boundary.vertices)
#     78                                               #     return interior, boundary
#     79
#     80       999       4710.0      4.7      0.2      i = -1
#     81      1631       6561.0      4.0      0.2      while True:
#     82                                                   # u = mesh.vertices[(ind + (-1)**i * i // 2)%len(mesh.vertices)]
#     83      1631       8034.0      4.9      0.3          u = mesh.vertices[i]
#     84      1631    1027075.0    629.7     33.7          init_hedge = check_vertex(u, p)
#     85                                                   # print(u.coords)
#     86      1631       6675.0      4.1      0.2          if init_hedge:
#     87       999       3507.0      3.5      0.1              break
#     88       632       2888.0      4.6      0.1          i -= 1
#     89
#     90                                               # print(init_hedge.vertex.coords, init_hedge.next.vertex.coords, init_hedge.prev.vertex.coords)
#     91
#     92       999    1987755.0   1989.7     65.1      res = expand(init_hedge, p)
#     93       999       4257.0      4.3      0.1      return res
#
# Total time: 0.0902284 s
# File: C:\Users\danny\AppData\Local\Temp\ipykernel_54668\4024425845.py
# Function: check_vertex at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def check_vertex(vertex, p):
#      2      1631       7389.0      4.5      0.8      halfedge = vertex.halfedge
#      3      1631       6806.0      4.2      0.8      if not halfedge:
#      4                                                   # print('no edge for vertex', vertex)
#      5                                                   return None
#      6      6255      27532.0      4.4      3.1      while True:
#      7      6255     754249.0    120.6     83.6          if check_triangle(halfedge, p):
#      8       999       4000.0      4.0      0.4              return halfedge
#      9      5256      26701.0      5.1      3.0          if halfedge.twin == None:
#     10                                                       break
#     11      5256      24169.0      4.6      2.7          halfedge = halfedge.twin.next # clockwise
#     12      5256      24493.0      4.7      2.7          if halfedge == vertex.halfedge:
#     13       632       2157.0      3.4      0.2              break
#     14      4624      22133.0      4.8      2.5          if halfedge.vertex != vertex:
#     15                                                       print('not good', halfedge, halfedge.vertex, vertex)
#     16                                                       break
#     17       632       2655.0      4.2      0.3      return None

# %%
a, b, c, d = (-np.inf, np.inf), (np.inf, np.inf), (0.876, 0.987), (0.234, 0.456)
# %timeit incircle(a, b, c, d)
# Out:
# 56.1 μs ± 11.4 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
draw_mesh(mesh)

# %%
def update():
    for p in mesh.vertices:
        p.vel = tuple(map(sum, zip(p.vel, tuple(map(lambda x: x/100000, p.acc)))))
        p.coords = tuple(map(sum, zip(p.coords, p.vel)))
        p.acc = (np.random.random()-0.5, np.random.random()-0.5)

# %%
# render with pygame
pg.init()
screen = pg.display.set_mode((800, 800))
L = 800
i = 0
def render(mesh):
    global i, L
    screen.fill((255, 255, 255))
    for he in mesh.halfedges:
        if he.index:
            continue
        if he.twin is not None:
            he.twin.index = 1
        a, b = he.vertex.coords, he.next.vertex.coords
        if np.isinf(a[0]) or np.isinf(b[0]):
            continue
        pg.draw.aaline(screen, (0, 0, 0), (a[0]*L, a[1]*L), (b[0]*L, b[1]*L), 1)
      
    # for p in mesh.vertices:
    #     if np.isinf(p.coords[0]):
    #         continue
    #     pg.draw.circle(screen, (0, 0, 0), p.coords, 2)
    pg.display.flip()
    i += 1

    for he in mesh.halfedges:
        he.index = 0

    update()

# %%
running = True
while running:
    for event in pg.event.get():
        if event.type == pg.QUIT:
            running = False
    render(mesh)
pg.quit()

# %%
# %timeit np.isnan(([2, 3], [4, 5]))
# Out:
# 1.65 μs ± 139 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit ([2, 3], [4, 5]) == ([2, 3], [4, 5])
# Out:
# 272 ns ± 22.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from line_profiler import LineProfiler
def check_triangle_wrapper():
	for vertex in mesh.vertices:
		for halfedge in vertex.halfedges:
			check_triangle(halfedge, vertex)

profiler = LineProfiler()
profiler.add_function(check_triangle_wrapper)
profiler.add_function(f)
profiler.run('f()')
profiler.print_stats()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[430], line 5
#       3 profiler.add_function(check_triangle)
#       4 profiler.add_function(f)
# ----> 5 profiler.run('f()')
#       6 profiler.print_stats()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\line_profiler\line_profiler.py:178, in LineProfiler.run(self, cmd)
#     176 import __main__
#     177 main_dict = __main__.__dict__
# --> 178 return self.runctx(cmd, main_dict, main_dict)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\line_profiler\line_profiler.py:185, in LineProfiler.runctx(self, cmd, globals, locals)
#     183 self.enable_by_count()
#     184 try:
# --> 185     exec(cmd, globals, locals)
#     186 finally:
#     187     self.disable_by_count()
#
# File <string>:1
#
# Cell In[427], line 4, in f()
#       2 for i in range(len(vertices)):
#       3     p = vertices[i]
# ----> 4     interior, boundary = Cavity(mesh, p, 5+i)
#       5     # print('bdr', boundary.vertices)
#       6     # print('bdrv', boundary.vertices)
#       7     # print('inth', interior.halfedges)
#       8     ball = Ball(boundary, p)
#
# Cell In[419], line 83, in Cavity(mesh, p, ind)
#      81 while True:
#      82     u = mesh.vertices[(ind + (-1)**i * i // 2)%len(mesh.vertices)]
# ---> 83     init_hedge = check_vertex(u)
#      84     # print(u.coords)
#      85     if init_hedge:
#
# Cell In[417], line 7, in check_vertex(vertex)
#       5     return None
#       6 while True:
# ----> 7     if check_triangle(halfedge):
#       8         return halfedge
#       9     if halfedge.twin == None:
#
# TypeError: check_triangle() missing 1 required positional argument: 'p'

# %%
test_p = points
test_p = [Vertex(p, index=i) for i, p in enumerate(test_p)]
test_e = [Halfedge(vertex=p) for p in test_p]
test_e = [Halfedge(vertex=p, next=test_e[(i+1)%len(test_e)], prev=test_e[(i-1)%len(test_e)]) for i, p in enumerate(test_p)]
test_mesh = TriangularMesh()
test_mesh.vertices = test_p
test_mesh.halfedges = test_e
# plot points
plt.plot(*zip(*map(lambda x: x.coords, test_mesh.vertices)), 'ko')
# plot edges
for hedge in test_mesh.halfedges:
    # draw arrow
    plt.arrow(*hedge.vertex.coords, hedge.next.vertex.coords[0] - hedge.vertex.coords[0], hedge.next.vertex.coords[1] - hedge.vertex.coords[1], head_width=0.1)
plt.show()

# %%
print(test_mesh.halfedges[0].coords)

# %%
ball = Ball(test_mesh, Vertex((1, 1)), 0)
# plot points
plt.plot(*zip(*map(lambda x: x.coords, ball.vertices)), 'bo')
# plot edges
for abc in ball.halfedges:
    print(abc.vertex.coords, abc.next.vertex.coords)
    plt.plot(*zip(abc.vertex.coords, abc.next.vertex.coords), 'g-')
plt.show()

# %%
def DL(points):
    
    # sort points according to Hilbert curve
    depth = 8
    O = np.array([0.5, 0.5])
    R = np.array([0.5, 0])
    B = np.array([0, 0.5])
    indices = [Hilbert(point, depth, O, R, B) for point in points]
    indices = sorted(range(len(indices)), key=lambda i: indices[i])
    mesh = TriangularMesh()
    # create super triangle
    A = Vertex((border[0] - 1, border[2] - 1))
    B = Vertex((border[1] + 1, border[2] - 1))
    C = Vertex((border[0] + border[1], border[3] + 1))
    super_triangle = Face()
    super_triangle.halfedge = Halfedge(vertex=A, next=Halfedge(vertex=B, next=Halfedge(vertex=C, next=Halfedge(vertex=A, facet=super_triangle))))
    super_triangle.index = 0
    mesh.add_mesh(TriangularMesh(vertices=[A, B, C], faces=[super_triangle], halfedges=[super_triangle.halfedge, super_triangle.halfedge.next, super_triangle.halfedge.next.next, super_triangle.halfedge.next.next.next]))
    for i in indices:
        cavity = Cavity(mesh, Vertex(points[i]), i)
        mesh.add_mesh(Ball(cavity, Vertex(points[i]), i))
    return mesh

# %%
orient2d((0., 0.), (0.5, 0.), (np.inf, -0.1))

# %%
# %timeit incircle(np.array([0., 0.]), np.array([1., 0.]), np.array([0., 1.]), np.array([0.5, -0.1]))

# %%
# %timeit incircle((0., 0.), (1., 0.), (0., 1.), (0.5, -0.1))

# %%
def test(a, b, c, p):
    # if one of the points has index -1, do orient2d instead of incircle
    if -1 in [a.index, b.index, c.index]:
        return orient2d(a.coords, b.coords, c.coords)

# %%
import math
sys.float_info.max/1e139

# %%
# %timeit incircle((0., 0.), (1., 0.), (0., 1.0), (0.5, -0.15))

# %%
# %timeit incircle((np.float64(0.), np.float64(0.)), (np.float64(1.), np.float64(0.)), (np.float64(0.), np.float64(1.0)), (np.float64(0.5), np.float64(-0.15)))

# %%
a = [(0., 0.), (1., 0.), (0., 1.0), (0.5, -0.15)]
# a = [[0., 0.], [1., 0.], [0., 1.0], [0.5, -0.15]]
# a = [(np.float64(0.), np.float64(0.)), (np.float64(1.), np.float64(0.)), (np.float64(0.), np.float64(1.0)), (np.float64(0.5), np.float64(-0.15))]
# a = [np.array([0., 0.]), np.array([1., 0.]), np.array([0., 1.0]), np.array([0.5, -0.15])]
# a = np.array([[0., 0.], [1., 0.], [0., 1.0], [0.5, -0.15]])
# %timeit incircle(a[0], a[1], a[2], a[3])

# %%
arr = np.random.rand(10000000, 2)
# %timeit arr2 = list(map(tuple, arr.tolist()))

# %%
# %timeit incircle((np.float32(0.), np.float32(0.)), (np.float32(1.), np.float32(0.)), (np.float32(0.), np.float32(1.0)), (np.float32(0.5), np.float32(-0.15)))

# %%
# %timeit incircle((np.float16(0.), np.float16(0.)), (np.float16(1.), np.float16(0.)), (np.float16(0.), np.float16(1.0)), (np.float16(0.5), np.float16(-0.15)))

# %%
# %timeit incircle([0., 0.], [1., 0.], [0., 1.], [0.5, -0.1])

# %%
a = list(map(tuple, np.random.rand(2, 10).T))

# %%
# %timeit incircle(a[0], a[1], a[2], a[3])

# %%
points

# %%
np.random.rand(10, 2)

# %%
b = sorted(np.random.rand(100, 2), key=lambda x: Hilbert(x, depth, np.array([0.5, 0.5]), np.array([0.5, 0.]), np.array([0., 0.5])))

# %%
insort(b, np.array([0.51, 0.49]), key=lambda x: Hilbert(x, depth, np.array([0.5, 0.5]), np.array([0.5, 0.]), np.array([0., 0.5])))

# %%
for i, p in enumerate(b):
    plt.plot(p[0], p[1], 'ko')
    # write index
    plt.text(p[0], p[1], str(i))
plt.plot(b[-1][0], b[-1][1], 'ro')
plt.show()

# %%
class test:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def __repr__(self):
        return str(self.a-self.b)

l = [] 
for i in range(10):
    l.append(test(4*i**2, 3*i))

print(l[3].b)
